# %%
import brightway2 as bw
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python
import csv
import stats_arrays
import scipy as sp
import pandas as pd
import pickle

# %%
bw.projects.set_current('iw_integration')

# %% [markdown]
# ## Creating ecoinvent v33 DB with and without uncertainty

# %% [markdown]
# eiv33 with uncertainty

# %%
fpei33 = r"C:\bw2-python\ecospold_ecoinvent_3.3_cut off"
if 'ecoinvent 3.3 cutoff' in bw.databases:
    print("Database has already been imported")
else:
    ei33 = bw.SingleOutputEcospold2Importer(fpei33, 'ecoinvent 3.3 cutoff')
    ei33.apply_strategies()
    ei33.statistics()
    ei33.write_database()

# %% [markdown]
# Creating a version without uncertainty

# %%
#create a copy of ei33
fpei33 = r"C:\bw2-python\ecospold_ecoinvent_3.3_cut off"
if 'ecoinvent 3.3 cutoff without uncertainty' in bw.databases:
    print("Database has already been imported")
else:
    ei33_no_uncert = bw.SingleOutputEcospold2Importer(fpei33, 'ecoinvent 3.3 cutoff without uncertainty')
    ei33_no_uncert.apply_strategies()
    ei33_no_uncert.statistics()
    ei33_no_uncert.write_database()

# %%
def remove_uncert_in_act(act):
    for exc in act.exchanges():
        exc['uncertainty type']=0
        exc.save()
    
    act.save()
    
    return act;

# %%
for act in ei33_db_no_uncert:
    remove_uncert_in_act(act)

# %% [markdown]
# ## Loading ecoinvent v33 DB with and without uncertainty

# %%
ei33_db = bw.Database('ecoinvent 3.3 cutoff')
len(ei33_db)
# Out:
# 13831

# %%
ei33_db_no_uncert = bw.Database('ecoinvent 3.3 cutoff without uncertainty')
len(ei33_db_no_uncert)
# Out:
# 13831

# %% [markdown]
# ## Loading impact categories

# %%
IW_with_uncert_beta=[m for m in bw.methods 
                     if 'IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017' in str(m)
                    and 'with uncert' in str(m)]
IW_with_uncert_beta_wo=[m for m in IW_with_uncert_beta 
                             if 'Land transformation' not in str(m) 
                             and 'Land occupation' not in str(m)
                             and 'Freshwater eutrophication' not in str(m)]
IW_with_uncert_beta
# Out:
# [('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land occupation, biodiversity, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land transformation, biodiversity, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater eutrophication, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater acidification, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Terrestrial acidification, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Human Health',
#   'Water availability, human health, GLO, with uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Marine eutrophication, GLO, with uncert')]

# %% [markdown]
# ## Creating impact categories without uncertainty

# %%
#Change a CF value for uncertainty dictionary or other value

def modify_CF_value(CF_tuple, new_CF_value):
    
    lst=list(CF_tuple)
    lst[1]=new_CF_value #value or uncertainty dictionary
    new_CF_tuple=tuple(lst)
    
    return new_CF_tuple;

# %%
#Remove CF uncertainty for several impact categories

def remove_uncert_in_impact_cat(ic_name):

    ic=bw.Method(ic_name)
    cf_list=ic.load()
    
    i=0

    for cf in cf_list:

        if type(cf[1])== dict:
            cf=modify_CF_value(cf, cf[1]['amount'])

        cf_list[i]=cf
        i=i+1

    ic.write(cf_list)
        
    return;

# %%
#Copy and rename impact category

def copy_rename_impact_cat(old_ic_name, new_ic_name):
    
    old_ic=bw.Method(old_ic_name)
    old_ic.copy(new_ic_name)
    
    return;

# %%
list_of_ic_names=IW_with_uncert_beta_to_create_no_uncert
string_to_replace='with uncert'
string_to_use_instead='no uncert'

for ic_name in list_of_ic_names:
    
    #define new ic name. Here we changed only the first name
    new_ic_name=(ic_name[0],ic_name[1],ic_name[2].replace(string_to_replace,string_to_use_instead))
    
    #copy ic
    old_ic_name=ic_name
    copy_rename_impact_cat(old_ic_name, new_ic_name)
    
    #remove CF uncertainty
    remove_uncert_in_impact_cat(new_ic_name)

# %%
IW_no_uncert=[m for m in bw.methods 
                     if 'IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017' in str(m)
             and 'no uncert' in str(m)]
IW_no_uncert
# Out:
# [('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Terrestrial acidification, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Marine eutrophication, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land transformation, biodiversity, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Human Health',
#   'Water availability, human health, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land occupation, biodiversity, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater acidification, GLO, no uncert'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater eutrophication, GLO, no uncert')]

# %% [markdown]
# ## Calculating MC results for an entire DB

# %% [markdown]
# Let's start with a simplified DB

# %%
ei33_db_no_uncert_simplified=[ei33_db_no_uncert.random() for i in range(3)]
ei33_db_no_uncert_simplified
# Out:
# ['uranium fuel element production, enriched 3.8%, for light water reactor' (kilogram, CN, None),
#  'market for natural gas, from low pressure network (<0.1 bar), at service station' (kilogram, GLO, None),
#  'heat and power co-generation, biogas, gas engine' (kilowatt hour, WECC, US only, None)]

# %%
act_rand=ei33_db.random()
act_rand.key
# Out:
# ('ecoinvent 3.3 cutoff', 'bbfe15e0827b6aa77950885c5797f0c0')

# %%
act_codes_simplified_DB=[act['code'] for act in ei33_db_no_uncert_simplified]
ei33_db_with_uncert_simplified=[act for act in ei33_db if True in [act['code']==act_code for act_code in act_codes_simplified_DB]]
ei33_db_with_uncert_simplified
# Out:
# ['heat and power co-generation, biogas, gas engine' (kilowatt hour, WECC, US only, None),
#  'market for natural gas, from low pressure network (<0.1 bar), at service station' (kilogram, GLO, None),
#  'uranium fuel element production, enriched 3.8%, for light water reactor' (kilogram, CN, None)]

# %% [markdown]
# Function for Monte with multiple impact categories, 1 activity

# %%
#list_methods_name = IW_with_uncert
#fu_tuple = (act,1)
#iterations = 10

def MC_multi_impact(fu_tuple,list_methods_name,iterations):
    
    MC_results_dict={}
    fu_dict={fu_tuple[0]:fu_tuple[1]}
    
    for ic in list_methods_name:
        print(ic)
        MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
        scores = [next(MC_results_per_IC) for _ in range(iterations)]
        MC_results_dict[ic]=scores
    
    return MC_results_dict;

# %% [markdown]
# Function for Monte Carlo, one impact category, one activity

# %%
def MC_one_IC(imp_cat_name,act,fu,iterations):
    myFirstMonteCarlo = bw.MonteCarloLCA({act:fu},imp_cat_name)
    scores = [next(myFirstMonteCarlo) for _ in range(iterations)]
    return scores;

# %% [markdown]
# Function to calculate MC results for an entire DB

# %%
def MC_multi_impact_entire_DB(DB,list_methods_name,iterations):
    
    MC_results={}
    
    number_of_activity=0
    
    for act in DB:
        
        number_of_activity=number_of_activity+1
        print(str(number_of_activity)+" - "+str(act))
        
        fu_tuple = (act,1)
        scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
        MC_results[act.key]=scores
        
    return MC_results;

# %% [markdown]
# Test on the simplified DB

# %%
#MC simulation with uncertainty LCI=0 and LCIA=1
DB=ei33_db_no_uncert_simplified
list_methods_name=IW_with_uncert_beta_wo
iterations=1000

MC_results_eiv33_simplified_it1000_LCI0_LCIA1=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)

type(MC_results_eiv33_simplified_it1000_LCI0_LCIA1),len(MC_results_eiv33_simplified_it1000_LCI0_LCIA1)
# Out:
# 1 - 'uranium fuel element production, enriched 3.8%, for light water reactor' (kilogram, CN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 2 - 'market for natural gas, from low pressure network (<0.1 bar), at service station' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 3 - 'heat and power co-generation, biogas, gas engine' (kilowatt hour, WECC, US only, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# (dict, 3)

# %%
MC_results_eiv33_simplified_it1000_LCI0_LCIA1
# Out:
# {('ecoinvent 3.3 cutoff without uncertainty',
#   '2f7d99744502bb7b4787c126d92e8569'): {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#    'Ecosystem Quality',
#    'Freshwater acidification, GLO, with uncert'): [0.05580167400999481,
#    0.02383278853216971,
#    0.002235314816481853,
#    0.0038435286009994418,
#    0.10459177699971564,
#    0.08479093139473667,
#    0.003955514252896534,
#    0.22196241500153455,
#    0.18048677093614096,
#    0.00258197907044873],
#   ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#    'Ecosystem Quality',
#    'Marine eutrophication, GLO, with uncert'): [0.000334906164184077,
#    0.00047769535157240046,
#    0.0004748798246844242,
#    0.0005499589417411172,
#    0.0007425553403581841,
#    0.00043631438255005753,
#    0.0009296175155902443,
#    0.0004983925545113518,
#    0.00036106466225823916,
#    0.0004440228605952824],
#   ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#    'Ecosystem Quality',
#    'Terrestrial acidification, GLO, with uncert'): [0.1620998619862837,
#    0.03458526732080221,
#    0.18129804411832484,
#    0.14312621400616143,
#    0.25109212808956505,
#    0.055746613850124443,
#    0.17706199446219523,
#    0.06780992279168105,
#    0.1669951456389272,
#    0.04784973658858378],
#   ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2
('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#    'Human Health',
#    'Water availability, human health, GLO, with uncert'): [3.057493741553959e-05,
#    5.3718769473248116e-05,
#    3.79399201804025e-06,
#    4.135731477245816e-05,
#    2.6281989792793267e-05,
#    2.5711914269693734e-05,
#    2.3590875156955635e-05,
#    3.639459065761864e-05,
#    2.9576788844076673e-06,
#    1.2611671334064603e-05]}}

# %%
#MC simulation with uncertainty LCI=1 and LCIA=0
DB=ei33_db_with_uncert_simplified
list_methods_name=IW_no_uncert
iterations=1000

MC_results_eiv33_simplified_it1000_LCI1_LCIA0=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)
# Out:
# 1 - 'market for isophthalic acid based unsaturated polyester resin' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 2 - 'treatment of coal gas, in power plant' (kilowatt hour, TR, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 3 - 'heat and power co-generation, wood chips, 6667 kW' (megajoule, LV, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 4 - 'market for hydropower plant, run-of-river' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 5 - 'compressed air production, 1000 kPa gauge, <30kW, average generation' (cubic meter, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 6 - 'market for fuel cell, stack solid oxide, 125kW electrical, future' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 7 - 'treatment of inert waste, sanitary landfill' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 8 - 'synthetic gas production, from wood, at fixed bed gasifier' (cubic meter, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 9 - 'carrot production' (kilogram, NL, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# 10 - 'treatment of coal gas, in power plant' (kilowatt hour, CA-NB, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land transformation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Land occupation, biodiversity, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, no uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, no uncert')
# ({'carrot production' (kilogram, NL, None): {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Freshwater acidification, GLO, no uncert'): [0.0009442354529139421,
#     0.0009849015096916036,
#     0.0009972922881675633,
#     0.0009486471207052252,
#     0.00109388831010369,
#     0.0008622795486300521,
#     0.000980302518938274,
#     0.0009870860980912438,
#     0.0008551703620123923,
#     0.0009639293716054606,
#     0.0009670212665316854,
#     0.0009637631368309557,
#     0.0009039298329259375,
#     0.0009956534935734048,
#     0.0009662020289454701,
#     0.0007765494058779488,
#     0.0009596673468092994,
#     0.0010801243783515578,
#     0.0008539509242789162,
#     0.0008512252121428479,
#     0.0009821870857436904,
#     0.0009066102821638166,
#     0.001053113301335114,
#     0.0008469637940950667,
#     0.0012964751197268444,
#     0.0011690742498878573,
#     0.0011152362456610806,
#     0.0007553158544242338,
#     0.0007326913422748541,
#     0.0009217377793339364,
#     0.0009883654399340035,
#     0.0011879560762605938,
#     0.0010640872426112306,
#     0.001032387693189184,
#     0.0008311662229570234,
#     0.000999030458525231,
#     0.0010030290172119715,
#     0.0010478101495511934,
#     0.0008659502413774734,
#     0.0010010860986616296,
#     0.0009488807811010206,
#     0.000788807014002711,
#     0.0009611216029671296,
#     0.001129070570636802,
#     0.0008722530509089727,
#     0.0010277097511192331,
#     0.0008151007116495614,
#     0.0010567845629325485,
#     0.0008542639005067322,
#     0.0009410644958001361,
#     0.0010739553356475674,
#     0.0008791076290969126,
#     0.0008501789369744794,
#     0.0009850683699013255,
#     0.0011853567063306392,
#     0.001022529149068312,
#     0.001330734263306223,
#     0.0009424801436060761,
#     0.0008682711710694055,
#     0.0007645491653125563,
#     0.0008432720149493963,
#     0.0008268212581998585,
#     0.0010595776540162642,
#     0.0010134395884032416,
#     0.0009574050248401987,
#     0.0007918586628455601,
#     0.0009800943574998036,
#     0.0008819264266214596,
#     0.0009551888824585258,
#     0.000950542554005501,
#     0.0007134680568325467,
#     0.0008640032357454378,
#     0.000740036524339723,
#     0.0008960045354422867,
#     0.0011591119594897812,
#     0.0011235481558555438,
#     0.0009152489366825273,
#     0.0012353210161224796,
#     0.0010044352899348642,
#     0.0009947784247294725,
#     0.0008929266553174651,
#     0.0008905115038135524,
#     0.0011077769467625113,
#     -4.6750791381304895e-06,
#     -3.515851852683267e-06,
#     -5.31752890140426e-06,
#     -3.585615593253968e-06,
#     -3.929585926348464e-06,
#     -3.4637998550418025e-06,
#     -6.4669998090282084e-06,
#     -4.432314435332054e-06,
#     -5.6161341274377315e-06,
#     -2.8398924909450742e-06,
#     -2.9312474270780056e-06,
#     -3.6522815615528365e-06,
#     -5.055543229577371e-06,
#     -4.317645925110665e-06,
#     -4.449851931547057e-06,
#     -3.893048026570717e-06,
#     -3.252458817853553e-06,
#     -4.195741176226743e-06,
#     -4.386867714762367e-06,
#     -5.634404277621491e-06,
#     -4.590907408841061e-06,
#     -4.775062500655106e-06,
#     -3.574772914529213e-06,
#     -6.591143673701495e-06,
#     -4.745050906412787e-06,
#     -4.188385412644953e-06,
#     -3.609605666751292e-06,
#     -4.571106108500143e-06,
#     -3.834574776314581e-06,
#     -6.188892198029844e-06,
#     -3.3749671708159435e-06,
#     -4.486106363943752e-06,
#     -7.469809083345687e-06,
#     -4.846763450233008e-06,
#     -4.8815558388262934e-06,
#     -4.397410015204937e-06,
#     -2.2701168535008266e-06,
#     -3.368380121561576e-06,
#     -3.902162479990677e-06,
#     -2.7270984498442567e-06,
#     -5.587759046927034e-06,
#     -5.0025694032416156e-06,
#     -4.307512567826806e-06,
#     -6.53369889950771e-06,
#     -2.552450499318908e-06,
#     -3.869981575001348e-06,
#     -5.185376247982099e-06,
#     -3.7629105360507137e-06,
#     -6.033259630936362e-06,
#     -3.405008507532892e-06,
#     -5.971660930424984e-06,
#     -4.713628165850887e-06,
#     -4.9718874257153695e-06,
#     -5.399570733727166e-06,
#     -4.6659852271807464e-06,
#     -3.833752469956884e-06,
#     -6.2459184787015865e-06]}},)

# %%
#MC simulation with uncertainty LCI=1 and LCIA=1
DB=ei33_db_with_uncert_simplified
list_methods_name=IW_with_uncert_beta_wo
iterations=1000

MC_results_eiv33_simplified_it1000_LCI1_LCIA1=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)

# %% [markdown]
# Calculation on the entire DB --> later....

# %%
DB=ei33_db_no_uncert
list_methods_name=IW_with_uncert_beta_wo
iterations=1000

MC_results_eiv33_it1000_LCI0_LCIA1=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)
# Out:
# 1 - 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CY, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 2 - 'electricity production, wind, 1-3MW turbine, onshore' (kilowatt hour, CN-YN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 3 - 'land use change, annual crop' (hectare, UA, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 4 - 'petroleum refinery operation' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 5 - 'nutrient supply from ammonium chloride' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 6 - 'uranium production, centrifuge, enriched 3.0%' (unit, DE, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 7 - 'market for sludge from pulp and paper production' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 8 - 'photovoltaic laminate production, single-Si wafer' (square meter, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 9 - 'market for used desktop computer' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 10 - 'magnesium-alloy production, AZ91' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 11 - 'treatment of used cable' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 12 - 'market for rape seed, for sowing' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 13 - 'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical' (megajoule, RU, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 14 - 'expansion vessel production, 80l' (unit, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 15 - 'market for transport, passenger car, medium size, diesel, EURO 3' (kilometer, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 16 - 'mine infrastructure construction, open cast, uranium' (unit, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 17 - 'heat production, light fuel oil, at boiler 10kW, non-modulating' (megajoule, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 18 - 'electricity production, hydro, aluminium industry' (kilowatt hour, IAI Area, North America, without Quebec, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 19 - 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 20 - 'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, PT, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 21 - 'heat production, softwood chips from forest, at furnace 50kW, state-of-the-art 2014' (megajoule, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 22 - 'tert-butyl amine production' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 23 - 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (kilowatt hour, DK, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 24 - 'pyrazole production' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 25 - 'market group for heat, central or small-scale, other than natural gas' (megajoule, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 26 - 'market for waste polystyrene' (kilogram, Europe without Switzerland, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 27 - 'heat and power co-generation unit construction, organic Rankine cycle, 1400kW thermal, common components, heat+el' (unit, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 28 - 'hardwood forestry, meranti, sustainable forest management' (cubic meter, MY, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 29 - 'catch crop growing, sunflower, August-October, organic fertiliser 30 kg N' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 30 - 'aluminium fluoride production' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 31 - 'market for machine operation, diesel, < 18.64 kW, high load factor' (hour, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 32 - 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, CN-HN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 33 - 'ventilation of dwellings, decentralized, 6 x 120 m3/h, polyethylene ducts' (square meter-year, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 34 - 'methyl ethyl ketone production' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 35 - 'banana production' (kilogram, EC, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 36 - 'market for mine infrastructure, gold and silver' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 37 - 'electricity voltage transformation from high to medium voltage' (kilowatt hour, PL, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 38 - 'heat production, natural gas, at diffusion absorption heat pump 4kW, future' (megajoule, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 39 - 'ethoxylated alcohol (AE7) production, coconut oil' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 40 - 'treatment of blast furnace gas, in power plant' (kilowatt hour, CN-HN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 41 - 'sawing, softwood' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 42 - 'tomato seedling production, in unheated greenhouse, for planting' (unit, ES, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 43 - 'magnesium production, pidgeon process' (kilogram, CN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 44 - 'treatment of scrap tin sheet, sanitary landfill' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 45 - 'clinker production' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 46 - 'treatment of residue from TiO2 production, chloride process, residual material landfill' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 47 - 'planing, board, hardwood, u=10%' (cubic meter, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 48 - 'isohexane production' (kilogram, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 49 - 'market for maintenance, lorry 28 metric ton' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 50 - 'market for mercury' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 51 - 'mine infrastructure construction, open cast, peat' (unit, NORDEL, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 52 - 'market for coal gas' (megajoule, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 53 - 'treatment of refinery sludge, sanitary landfill' (kilogram, Europe without Switzerland, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 54 - 'electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted' (kilowatt hour, CN-FJ, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 55 - 'ethoxylated alcohol (AE7) production, palm kernel oil' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 56 - 'peanut production' (kilogram, AR, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 57 - 'market for bitumen seal, Alu80' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 58 - 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, BG, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 59 - 'market for spent catalytic converter NOx reduction' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ...
# 144 - 'acetone cyanohydrin production' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 145 - 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, GR, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 146 - 'market for wood preservation, dipping/immersion method, water-based, outdoor use, no ground contact' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 147 - 'pentane production' (kilogram, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 148 - 'market for metal working machine, unspecified' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 149 - 'electricity production, natural gas, conventional power plant' (kilowatt hour, NO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 150 - 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, CZ, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 151 - 'hardwood forestry, birch, sustainable forest management' (cubic meter, SE, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 152 - 'grass silage production, organic' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 153 - 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' (megajoule, CZ, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 154 - 'market for used diesel-electric generating set, 18.5kW' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 155 - 'market for nitrobenzene' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 156 - 'heat and power co-generation, biogas, gas engine' (kilowatt hour, PT, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 157 - 'laser machining, metal, with YAG-laser, 200W power' (hour, RER, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 158 - 'electricity production, hard coal' (kilowatt hour, CN-HB, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 159 - 'treatment of waste polyurethane, sanitary landfill' (kilogram, Europe without Switzerland, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 160 - 'air filter production, decentralized unit, 250 m3/h' (unit, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-8f1090b1a71f> in <module>()
#       3 iterations=1000
#       4
# ----> 5 MC_results_eiv33_it1000_LCI0_LCIA1=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)
#
# <ipython-input-21-896698dddce8> in MC_multi_impact_entire_DB(DB, list_methods_name, iterations)
#      11
#      12         fu_tuple = (act,1)
# ---> 13         scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
#      14         MC_results[act]=scores
#      15
#
# <ipython-input-17-eeb51539d7b1> in MC_multi_impact(fu_tuple, list_methods_name, iterations)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# <ipython-input-17-eeb51539d7b1> in <listcomp>(.0)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\monte_carlo.py in __next__(self)
#      93             self.load_data()
#      94         self.rebuild_technosphere_matrix(self.tech_rng.next())
# ---> 95         self.rebuild_biosphere_matrix(self.bio_rng.next())
#      96         if self.lcia:
#      97             self.rebuild_characterization_matrix(self.cf_rng.next())
#
# C:\bw2-python\envs\bw2\lib\site-packages\stats_arrays\random.py in next(self)
#     188             offset += size
#     189
# --> 190         self.random_data = self.random_data[np.argsort(self.ordering)]
#     191         return self.random_data
#     192
#
# C:\bw2-python\envs\bw2\lib\site-packages\numpy\core\fromnumeric.py in argsort(a, axis, kind, order)
#     906     except AttributeError:
#     907         return _wrapit(a, 'argsort', axis, kind, order)
# --> 908     return argsort(axis, kind, order)
#     909
#     910
#
# KeyboardInterrupt:

# %% [markdown]
# ## Analysis of MC results

# %% [markdown]
# Calculating results for endpoint categories

# %%
#MC_results_dict={act:{ic_name:[MC_results]}} as the output of MC_multi_impact_entire_DB()

def calculating_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2):
    
    endpoint_1=[]
    endpoint_2=[]
    
    i=0
    
    for act in MC_results_dict:
        for ic_name in MC_results_dict[act]:
            
            if i==0:
                endpoint_1=[0 for j in range(len(MC_results_dict[act][ic_name]))]
                endpoint_2=[0 for j in range(len(MC_results_dict[act][ic_name]))]
                i=i+1
            
            if endpoint_name_1 in str(ic_name):
                endpoint_1=[x+y for x,y in zip(endpoint_1,MC_results_dict[act][ic_name])]
                
            
            if endpoint_name_2 in str(ic_name):
                endpoint_2=[x+y for x,y in zip(endpoint_2,MC_results_dict[act][ic_name])]
                
        MC_results_dict[act][(ic_name[0],endpoint_name_1,endpoint_name_1)]=endpoint_1
        MC_results_dict[act][(ic_name[0],endpoint_name_2,endpoint_name_2)]=endpoint_2
        
    return MC_results_dict;

# %% [markdown]
# Calculating statistics based on MC results

# %%
#MC_results_dict={act_key:{ic_name:[MC_results]}} as the output of MC_multi_impact_entire_DB()

def calculating_stats_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2):
    
    MC_results_stats={}
    
    for act in MC_results_dict:
        
        MC_results_stats[act]={}
        
        sum_spear_corr_endpoint_1=0
        sum_spear_corr_endpoint_2=0
        
        #Calculation stats
        for ic_name in MC_results_dict[act]:
            
            MC_results_stats[act][ic_name]={}
            
            #Regular stats
            MC_results_stats[act][ic_name]['mean']=np.mean(MC_results_dict[act][ic_name])
            MC_results_stats[act][ic_name]['variance']=np.var(MC_results_dict[act][ic_name])
            MC_results_stats[act][ic_name]['std dev']=np.std(MC_results_dict[act][ic_name])
            MC_results_stats[act][ic_name]['minimum']=min(MC_results_dict[act][ic_name])
            MC_results_stats[act][ic_name]['maximum']=max(MC_results_dict[act][ic_name])
            MC_results_stats[act][ic_name]['2.5th percentile']=np.percentile(MC_results_dict[act][ic_name],2.5)
            MC_results_stats[act][ic_name]['25th percentile']=np.percentile(MC_results_dict[act][ic_name],25)
            MC_results_stats[act][ic_name]['median']=np.percentile(MC_results_dict[act][ic_name],50)
            MC_results_stats[act][ic_name]['75th percentile']=np.percentile(MC_results_dict[act][ic_name],75)
            MC_results_stats[act][ic_name]['97.5th percentile']=np.percentile(MC_results_dict[act][ic_name],97.5)
            MC_results_stats[act][ic_name]['number of iterations']=len(MC_results_dict[act][ic_name])
            
            #Stats to measure the dispersion
            MC_results_stats[act][ic_name]['MADM']=np.percentile(abs(MC_results_dict[act][ic_name]-MC_results_stats[act][ic_name]['median']),50)
            MC_results_stats[act][ic_name]['IQR']=MC_results_stats[act][ic_name]['75th percentile']-MC_results_stats[act][ic_name]['25th percentile']
            MC_results_stats[act][ic_name]['Spread']=MC_results_stats[act][ic_name]['maximum']-MC_results_stats[act][ic_name]['minimum']
            MC_results_stats[act][ic_name]['CI95']=MC_results_stats[act][ic_name]['97.5th percentile']-MC_results_stats[act][ic_name]['2.5th percentile']
            MC_results_stats[act][ic_name]['Quartile coeff of dispersion']=MC_results_stats[act][ic_name]['IQR']/(MC_results_stats[act][ic_name]['75th percentile']+MC_results_stats[act][ic_name]['25th percentile'])
            MC_results_stats[act][ic_name]['CV']=MC_results_stats[act][ic_name]['std dev']/MC_results_stats[act][ic_name]['mean']
            MC_results_stats[act][ic_name]['CV modified']=MC_results_stats[act][ic_name]['std dev']
            /np.sqrt((MC_results_stats[act][ic_name]['maximum']-MC_results_stats[act][ic_name]['mean'])
                     *(MC_results_stats[act][ic_name]['mean']-MC_results_stats[act][ic_name]['minimum']))
            MC_results_stats[act][ic_name]['CV robust']=MC_results_stats[act][ic_name]['MADM']/MC_results_stats[act][ic_name]['median']
            MC_results_stats[act][ic_name]['IQR/spread']=MC_results_stats[act][ic_name]['IQR']/(MC_results_stats[act][ic_name]['Spread'])
            MC_results_stats[act][ic_name]['IQR/CI95']=MC_results_stats[act][ic_name]['IQR']/MC_results_stats[act][ic_name]['CI95']
            
            
            
            if endpoint_name_1 in str(ic_name) and endpoint_name_1 not in str(ic_name[2]):
                MC_results_stats[act][ic_name]['Spearmann rank correlation']=(sp.stats.spearmanr(MC_results_dict[act][ic_name],MC_results_dict[act][(ic_name[0],endpoint_name_1,endpoint_name_1)])[0],sp.stats.spearmanr(MC_results_dict[act][ic_name],MC_results_dict[act][(ic_name[0],endpoint_name_1,endpoint_name_1)])[1])
                sum_spear_corr_endpoint_1=sum_spear_corr_endpoint_1+(MC_results_stats[act][ic_name]['Spearmann rank correlation'][0])**2
            
            if endpoint_name_2 in str(ic_name) and endpoint_name_2 not in str(ic_name[2]):
                MC_results_stats[act][ic_name]['Spearmann rank correlation']=(sp.stats.spearmanr(MC_results_dict[act][ic_name],MC_results_dict[act][(ic_name[0],endpoint_name_2,endpoint_name_2)])[0],sp.stats.spearmanr(MC_results_dict[act][ic_name],MC_results_dict[act][(ic_name[0],endpoint_name_2,endpoint_name_2)])[1])
                sum_spear_corr_endpoint_2=sum_spear_corr_endpoint_2+(MC_results_stats[act][ic_name]['Spearmann rank correlation'][0])**2
        
        #calculating Contribution To Variance
        for ic_name in MC_results_dict[act]:
            
            if endpoint_name_1 in str(ic_name) and endpoint_name_1 not in str(ic_name[2]):
                MC_results_stats[act][ic_name]['Spearmann CTV midpoint to endpoint']=(MC_results_stats[act][ic_name]['Spearmann rank correlation'][0])**2/sum_spear_corr_endpoint_1
            
            if endpoint_name_2 in str(ic_name) and endpoint_name_2 not in str(ic_name[2]):
                MC_results_stats[act][ic_name]['Spearmann CTV midpoint to endpoint']=(MC_results_stats[act][ic_name]['Spearmann rank correlation'][0])**2/sum_spear_corr_endpoint_2
                
        
    return MC_results_stats;

# %%
SimplifiedDB_MC_results_dict={'LCI0 LCIA1':MC_results_eiv33_simplified_it1000_LCI0_LCIA1}
#SimplifiedDB_MC_results_dict={'LCI1 LCIA0':MC_results_eiv33_simplified_it1000_LCI1_LCIA0,'LCI0 LCIA1':MC_results_eiv33_simplified_it1000_LCI0_LCIA1}
endpoint_name_1='Human Health'
endpoint_name_2='Ecosystem Quality'

SimplifiedDB_MC_results_stats_dict={}

for uncert_setting in SimplifiedDB_MC_results_dict:
    
    MC_results_dict=SimplifiedDB_MC_results_dict[uncert_setting]
    
    MC_results_dict=calculating_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2)
    MC_results_stats=calculating_stats_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2)
    
    SimplifiedDB_MC_results_stats_dict[uncert_setting]=MC_results_stats

# %%
SimplifiedDB_MC_results_stats_dict
# Out:
# {'LCI0 LCIA1': {('ecoinvent 3.3 cutoff without uncertainty',
#    '2f7d99744502bb7b4787c126d92e8569'): {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Ecosystem Quality'): {'2.5th percentile': 70676.397396689412,
#     '25th percentile': 118632.9827250527,
#     '75th percentile': 202287.74973231557,
#     '97.5th percentile': 321193.11067760532,
#     'CI95': 250516.71328091592,
#     'CV': 0.39640788728537002,
#     'CV modified': 66519.800409165589,
#     'CV robust': 0.26672250209870557,
#     'IQR': 83654.767007262868,
#     'IQR/CI95': 0.33392888606780069,
#     'IQR/spread': 0.17586354832800816,
#     'MADM': 42206.82279517244,
#     'Quartile coeff of dispersion': 0.26067112076772953,
#     'Spread': 475679.96780797327,
#     'maximum': 521870.8175108005,
#     'mean': 167806.4502315986,
#     'median': 158242.45222307125,
#     'minimum': 46190.8497028272,
#     'number of iterations': 1000,
#     'std dev': 66519.800409165589,
#     'variance': 4424883846.4752264},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Freshwater acidification, GLO, with uncert'): {'2.5th percentile': 0.00077988879272540643,
#     '25th percentile': 0.0045424840519093729,
#     '75th percentile': 0.052514312129900979,
#     '97.5th percentile': 0.28481898036717362,
#     'CI95': 0.28403909157444823,
#     'CV': 1.8391548465859398,
#     'CV modified': 0.088744659824852051,
#     'CV robust': 0.8423134075573746,
#     'IQR': 0.047971828077991607,
#     'IQR/CI95': 0.16889164027416248,
#     'IQR/spread': 0.058750495025626008,
#     'MADM': 0.012518447680594189,
#     'Quartile coeff of dispersion': 0.84077325206151299,
#     'Spearmann CTV midpoint to endpoint': 0.28258429606948482,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.0076804276804276796, pvalue=0.80833367676258439),
#     'Spread': 0.8165348744221999,
#     'maximum': 0.8166957776031928,
#     'mean': 0.048252957052306145,
#     'median': 0.014861983162415099,
#     'minimum': 0.00016090318099295806,
#     'number of iterations': 1000,
#     'std dev': 0.088744659824852051,
#     'variance': 0.0078756146474287091},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Marine eutrophication, GLO, with uncert'): {'2.5th percentile': 0.00023734529511667437,
#     '25th percentile': 0.00038743785540542718,
#     '75th percentile': 0.00080441217229441583,
#     '97.5th percentile': 0.0013479897287735369,
#     'CI95': 0.0011106444336568626,
#     'CV': 0.48858638795652026,
#     'CV modified': 0.00030666946792079562,
#     'CV robust': 0.34731791100242071,
#     'IQR': 0.00041697431688898865,
#     'IQR/CI95': 0.37543457136509117,
#     'IQR/spread': 0.24537435128165447,
#     'MADM': 0.00018992694564021754,
#     'Quartile coeff of dispersion': 0.34985468573903494,
#     'Spearmann CTV midpoint to endpoint': 0.087080069558295059,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.0042635442635442639, pvalue=0.89288300022342915),
#     'Spread': 0.0016993394570827092,
#     'maximum': 0.0018772504824839564,
#     'mean': 0.0006276668271570562,
#     'median': 0.00054683890356260322,
#     'minimum': 0.00017791102540124724,
#     'number of iterations': 1000,
#     'std dev': 0.00030666946792079562,
#     'variance': 9.4046162554823904e-08},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Terrestrial acidification, GLO, with uncert'): {'2.5th percentile': 0.026765592286395763,
#     '25th percentile': 0.06783992207841015,
#     '75th percentile': 0.18764931848681599,
#     '97.5th percentile': 0.46689854170850337,
#     'CI95': 0.44013294942210762,
#     'CV': 0.76914659399997354,
#     'CV modified': 0.11075995227477234,
#     'CV robust': 0.47622159564837546,
#     'IQR': 0.11980939640840584,
#     'IQR/CI95': 0.27221183182425895,
#     'IQR/spread': 0.15800190377673309,
#     'MADM': 0.054938083114106723,
#     'Quartile coeff of dispersion': 0.4689410643804337,
#     'Spearmann CTV midpoint to endpoint': 0.63033563437222007,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.01147089547089547, pvalue=0.71712801031349316),
#     'Spread': 0.7582781823800316,
#     'maximum': 0.7711415472758278,
#     'mean': 0.1440036959648503,
#     'median': 0.11536243550506892,
#     'minimum': 0.012863364895796208,
#     'number of iterations': 1000,
#     'std dev': 0.11075995227477234,
#     'variance': 0.012267767027909847},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Human Health'): {'2.5th percentile': 124.09977979332308,
#     '25th percentile': 608.38256861669458,
#     '75th percentile': 2291.0740580470028,
#     '97.5th percentile': 4973.4019945714317,
#     'CI95': 4849.3022147781085,
#     'CV': 0.81917014790822396,
#     'CV modified': 1336.4007968413396,
#     'CV robust': 0.60520534380374735,
#     'IQR': 1682.6914894303081,
#     'IQR/CI95': 0.34699662238050549,
#     'IQR/spread': 0.216610192595284,
#     'MADM': 778.34364205531267,
#     'Quartile coeff of dispersion': 0.58034718435037325,
#     'Spread': 7768.293214965469,
#     'maximum': 7780.701888892869,
#     'mean': 1631.408078350853,
#     'median': 1286.0819059583678,
#     'minimum': 12.408673927399379,
#     'number of iterations': 1000,
#     'std dev': 1336.4007968413396,
#     'variance': 1785967.0897981671},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Water availability, human health, GLO, with uncert'): {'2.5th percentile': 2.9021917558152263e-05,
#     '25th percentile': 0.00018957878419504601,
#     '75th percentile': 0.00076650093300330866,
#     '97.5th percentile': 0.001719431736805424,
#     'CI95': 0.0016904098192472717,
#     'CV': 0.85226203927309097,
#     'CV modified': 0.00046212762637748254,
#     'CV robust': 0.63365330720755331,
#     'IQR': 0.0005769221488082627,
#     'IQR/CI95': 0.34129129057305307,
#     'IQR/spread': 0.21769883683657359,
#     'MADM': 0.00026512453942424577,
#     'Quartile coeff of dispersion': 0.60342473376471661,
#     'Spearmann CTV midpoint to endpoint': 1.0,
#     'Spearmann rank correlation': SpearmanrResult(correlation=0.04266103866103866, pvalue=0.17766259666855935),
#     'Spread': 0.002650092932013954,
#     'maximum': 0.002660742001670348,
#     'mean': 0.0005422365482471086,
#     'median': 0.00041840630579618229,
#     'minimum': 1.0649069656394277e-05,
#     'number of iterations': 1000,
#     'std dev': 0.00046212762637748254,
#     'variance': 2.1356194306128611e-07}},
#   ('ecoinvent 3.3 cutoff without uncertainty',
#    'b23e2c7b76af40d3493bf91dca1c4ec3'): {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Ecosystem Quality'): {'2.5th percentile': 2019.070459389367,
#     '25th percentile': 3389.4225281383897,
#     '75th percentile': 5779.528086675341,
#     '97.5th percentile': 9176.7965714570328,
#     'CI95': 7157.7261120676658,
#     'CV': 0.39641964165632848,
#     'CV modified': 1900.5685906042436,
#     'CV robust': 0.26674710314176847,
#     'IQR': 2390.1055585369513,
#     'IQR/CI95': 0.33391967240927539,
#     'IQR/spread': 0.17586112063832238,
#     'MADM': 1205.9897852848339,
#     'Quartile coeff of dispersion': 0.26067383923689147,
#     'Spread': 13590.869601317194,
#     'maximum': 14910.500446182083,
#     'mean': 4794.3350704401273,
#     'median': 4521.0979653784088,
#     'minimum': 1319.630844864888,
#     'number of iterations': 1000,
#     'std dev': 1900.5685906042436,
#     'variance': 3612160.9675914012},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Freshwater acidification, GLO, with uncert'): {'2.5th percentile': 3.0087881750338572,
#     '25th percentile': 18.153713007023615,
#     '75th percentile': 99.335756471338868,
#     '97.5th percentile': 322.70536524112396,
#     'CI95': 319.69657706609007,
#     'CV': 1.1599578955890417,
#     'CV modified': 89.214532455897285,
#     'CV robust': 0.74584801809158607,
#     'IQR': 81.182043464315257,
#     'IQR/CI95': 0.25393466583013397,
#     'IQR/spread': 0.10242083822087651,
#     'MADM': 33.660428892636062,
#     'Quartile coeff of dispersion': 0.69097293421063744,
#     'Spearmann CTV midpoint to endpoint': 0.25990511871404182,
#     'Spearmann rank correlation': SpearmanrResult(correlation=0.47478558678558674, pvalue=2.3333687332144059e-57),
#     'Spread': 792.6320939615964,
#     'maximum': 793.1866131697163,
#     'mean': 76.911871366324888,
#     'median': 45.130412733097515,
#     'minimum': 0.5545192081199837,
#     'number of iterations': 1000,
#     'std dev': 89.214532455897285,
#     'variance': 7959.2328013243496},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Marine eutrophication, GLO, with uncert'): {'2.5th percentile': 6.7652199648901474,
#     '25th percentile': 7.7928230118662096,
#     '75th percentile': 10.473952117626604,
#     '97.5th percentile': 14.752966117968274,
#     'CI95': 7.9877461530781266,
#     'CV': 0.22301467779426251,
#     'CV modified': 2.0988690341977394,
#     'CV robust': 0.14428430176279222,
#     'IQR': 2.6811291057603945,
#     'IQR/CI95': 0.33565527175988247,
#     'IQR/spread': 0.24068592673085551,
#     'MADM': 1.2801843692295138,
#     'Quartile coeff of dispersion': 0.14677626930609933,
#     'Spearmann CTV midpoint to endpoint': 0.0021927739214021185,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.043610095610095607, pvalue=0.16820233643304375),
#     'Spread': 11.139534172924613,
#     'maximum': 17.437528008004236,
#     'mean': 9.4113493109812563,
#     'median': 8.8726517964107821,
#     'minimum': 6.297993835079623,
#     'number of iterations': 1000,
#     'std dev': 2.0988690341977394,
#     'variance': 4.4052512227141509},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Terrestrial acidification, GLO, with uncert'): {'2.5th percentile': 109.40815354980008,
#     '25th percentile': 193.72628450691622,
#     '75th percentile': 347.96019209036274,
#     '97.5th percentile': 553.73811705404432,
#     'CI95': 444.32996350424423,
#     'CV': 0.42110578615579503,
#     'CV modified': 118.95050298025888,
#     'CV robust': 0.28590438769220594,
#     'IQR': 154.23390758344652,
#     'IQR/CI95': 0.34711570285980337,
#     'IQR/spread': 0.1785754169470648,
#     'MADM': 75.889327288266713,
#     'Quartile coeff of dispersion': 0.28472910852842453,
#     'Spearmann CTV midpoint to endpoint': 0.73790210736455608,
#     'Spearmann rank correlation': SpearmanrResult(correlation=0.79999907599907594, pvalue=1.2438568812154013e-223),
#     'Spread': 863.6905920212196,
#     'maximum': 930.6446219865104,
#     'mean': 282.47178474116521,
#     'median': 265.43603580497108,
#     'minimum': 66.95402996529079,
#     'number of iterations': 1000,
#     'std dev': 118.95050298025888,
#     'variance': 14149.222159256575},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Human Health'): {'2.5th percentile': 3.5455636138568649,
#     '25th percentile': 17.38222762868925,
#     '75th percentile': 65.459182066067413,
#     '97.5th percentile': 142.09688991755041,
#     'CI95': 138.55132630369354,
#     'CV': 0.81917489148035749,
#     'CV modified': 38.182872269218009,
#     'CV robust': 0.60520002291895192,
#     'IQR': 48.076954437378163,
#     'IQR/CI95': 0.34699743207074962,
#     'IQR/spread': 0.21661029014065489,
#     'MADM': 22.23815859874874,
#     'Quartile coeff of dispersion': 0.5803493037422458,
#     'Spread': 221.95138747175685,
#     'maximum': 222.30563787589196,
#     'mean': 46.61138014156721,
#     'median': 36.745138394892066,
#     'minimum': 0.3542504041351151,
#     'number of iterations': 1000,
#     'std dev': 38.182872269218009,
#     'variance': 1457.9317347274175},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Water availability, human health, GLO, with uncert'): {'2.5th percentile': 0.27273566260437421,
#     '25th percentile': 1.3370944329760963,
#     '75th percentile': 5.0353216973898007,
#     '97.5th percentile': 10.930529993657721,
#     'CI95': 10.657794331053347,
#     'CV': 0.81917489148035749,
#     'CV modified': 2.9371440207090775,
#     'CV robust': 0.6052000229189517,
#     'IQR': 3.6982272644137044,
#     'IQR/CI95': 0.34699743207074962,
#     'IQR/spread': 0.21661029014065486,
#     'MADM': 1.7106275845191332,
#     'Quartile coeff of dispersion': 0.5803493037422458,
#     'Spearmann CTV midpoint to endpoint': 1.0,
#     'Spearmann rank correlation': SpearmanrResult(correlation=1.0, pvalue=0.0),
#     'Spread': 17.073183651673602,
#     'maximum': 17.10043368276092,
#     'mean': 3.5854907801205544,
#     'median': 2.8265491072993898,
#     'minimum': 0.027250031087316544,
#     'number of iterations': 1000,
#     'std dev': 2.9371440207090775,
#     'variance': 8.6268149983870863}},
#   ('ecoinvent 3.3 cutoff without uncertainty',
#    'f7d32a5dd1597ce9ea8002bc38d45b81'): {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Ecosystem Quality'): {'2.5th percentile': 14133.707262816506,
#     '25th percentile': 23726.11545441144,
#     '75th percentile': 40456.983734371024,
#     '97.5th percentile': 64238.108636685836,
#     'CI95': 50104.401373869332,
#     'CV': 0.39641543634488485,
#     'CV modified': 13303.964454987326,
#     'CV robust': 0.26674001348213311,
#     'IQR': 16730.868279959584,
#     'IQR/CI95': 0.3339201311900144,
#     'IQR/spread': 0.17586303480301033,
#     'MADM': 8441.7881701239003,
#     'Quartile coeff of dispersion': 0.2606740480192285,
#     'Spread': 95135.78733984861,
#     'maximum': 104373.60156544247,
#     'mean': 33560.661960228921,
#     'median': 31648.000837674663,
#     'minimum': 9237.814225593862,
#     'number of iterations': 1000,
#     'std dev': 13303.964454987326,
#     'variance': 176995470.21956623},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Freshwater acidification, GLO, with uncert'): {'2.5th percentile': 0.00011158210816939165,
#     '25th percentile': 0.00058247318945404991,
#     '75th percentile': 0.0052911546219059366,
#     '97.5th percentile': 0.024277902980613303,
#     'CI95': 0.02416632087244391,
#     'CV': 1.4940123001024042,
#     'CV modified': 0.0066069862520208994,
#     'CV robust': 0.79806727618472384,
#     'IQR': 0.004708681432451887,
#     'IQR/CI95': 0.19484477828898841,
#     'IQR/spread': 0.093712078746023914,
#     'MADM': 0.0013570871690670298,
#     'Quartile coeff of dispersion': 0.80166493071709177,
#     'Spearmann CTV midpoint to endpoint': 0.59523191449551149,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.078561078561078565, pvalue=0.012953184362426139),
#     'Spread': 0.050246259558634224,
#     'maximum': 0.050286900345989496,
#     'mean': 0.0044223104800194995,
#     'median': 0.0017004671279779587,
#     'minimum': 4.0640787355274014e-05,
#     'number of iterations': 1000,
#     'std dev': 0.0066069862520208994,
#     'variance': 4.365226733439317e-05},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Marine eutrophication, GLO, with uncert'): {'2.5th percentile': 4.2628629394185227e-05,
#     '25th percentile': 0.00011290697927831204,
#     '75th percentile': 0.00048596920572837633,
#     '97.5th percentile': 0.0013085716260666453,
#     'CI95': 0.00126594299667246,
#     'CV': 0.97519905367869852,
#     'CV modified': 0.00034902051958702289,
#     'CV robust': 0.618798602369942,
#     'IQR': 0.00037306222645006428,
#     'IQR/CI95': 0.29469117284953661,
#     'IQR/spread': 0.18222004412189638,
#     'MADM': 0.00013476889074013062,
#     'Quartile coeff of dispersion': 0.62293715427321228,
#     'Spearmann CTV midpoint to endpoint': 0.0088298734371332049,
#     'Spearmann rank correlation': SpearmanrResult(correlation=0.0095684495684495684, pvalue=0.76249242578188925),
#     'Spread': 0.00204731717768932,
#     'maximum': 0.002072480840701799,
#     'mean': 0.00035789669634156109,
#     'median': 0.00021779120092381933,
#     'minimum': 2.516366301247841e-05,
#     'number of iterations': 1000,
#     'std dev': 0.00034902051958702289,
#     'variance': 1.2181532309279544e-07},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Ecosystem Quality',
#     'Terrestrial acidification, GLO, with uncert'): {'2.5th percentile': 0.004976863292006601,
#     '25th percentile': 0.011198414278438516,
#     '75th percentile': 0.025712343626362065,
#     '97.5th percentile': 0.047714628475863295,
#     'CI95': 0.042737765183856691,
#     'CV': 0.59099442556607518,
#     'CV modified': 0.011561871925477933,
#     'CV robust': 0.4096255437423284,
#     'IQR': 0.014513929347923549,
#     'IQR/CI95': 0.33960431214606157,
#     'IQR/spread': 0.16172078445669852,
#     'MADM': 0.0070190468790718033,
#     'Quartile coeff of dispersion': 0.39321677938333199,
#     'Spearmann CTV midpoint to endpoint': 0.3959382120673553,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.064073440073440069, pvalue=0.042792698939739172),
#     'Spread': 0.08974683988012512,
#     'maximum': 0.09173417919840862,
#     'mean': 0.019563419594700183,
#     'median': 0.017135276318332036,
#     'minimum': 0.001987339318283498,
#     'number of iterations': 1000,
#     'std dev': 0.011561871925477933,
#     'variance': 0.00013367688242115481},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Human Health'): {'2.5th percentile': 24.818988511686271,
#     '25th percentile': 121.67596745683403,
#     '75th percentile': 458.21446527859518,
#     '97.5th percentile': 994.67885022098085,
#     'CI95': 969.85986170929459,
#     'CV': 0.81917387848382039,
#     'CV modified': 267.28009417757306,
#     'CV robust': 0.60520157862176704,
#     'IQR': 336.53849782176115,
#     'IQR/CI95': 0.34699703648797364,
#     'IQR/spread': 0.21661024036565493,
#     'MADM': 155.66759394295383,
#     'Quartile coeff of dispersion': 0.58034842243259499,
#     'Spread': 1553.659223375857,
#     'maximum': 1556.1395925891547,
#     'mean': 326.28005017966666,
#     'median': 257.21610690021254,
#     'minimum': 2.4803692132978044,
#     'number of iterations': 1000,
#     'std dev': 267.28009417757306,
#     'variance': 71438.648743572325},
#    ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#     'Human Health',
#     'Water availability, human health, GLO, with uncert'): {'2.5th percentile': 1.8862923400584739e-06,
#     '25th percentile': 1.1093046514382336e-05,
#     '75th percentile': 4.2438516846760325e-05,
#     '97.5th percentile': 9.414561544465497e-05,
#     'CI95': 9.2259323104596489e-05,
#     'CV': 0.83592535157716763,
#     'CV modified': 2.5025592129826411e-05,
#     'CV robust': 0.59924440856305661,
#     'IQR': 3.134547033237799e-05,
#     'IQR/CI95': 0.33975395957372156,
#     'IQR/spread': 0.20554790703980938,
#     'MADM': 1.384333544324925e-05,
#     'Quartile coeff of dispersion': 0.58555118446495713,
#     'Spearmann CTV midpoint to endpoint': 1.0,
#     'Spearmann rank correlation': SpearmanrResult(correlation=-0.044842472842472843, pvalue=0.15648797439544501),
#     'Spread': 0.00015249715155847912,
#     'maximum': 0.00015285856608824092,
#     'mean': 2.9937592014179031e-05,
#     'median': 2.3101317668436049e-05,
#     'minimum': 3.6141452976180875e-07,
#     'number of iterations': 1000,
#     'std dev': 2.5025592129826411e-05,
#     'variance': 6.262802614484297e-10}}}}

# %% [markdown]
# ## Saving Python object with pickle

# %%
def pickle_save(file_path_root,object_name_to_save,file_name):
    
    complete_file_path=file_path_root+'\\'+file_name+'.p'
    
    pickle.dump( object_name_to_save, open( complete_file_path, "wb" ) )

# %%
file_path_root=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Pickle Python object saved'
object_name_to_save=MC_results_eiv33_simplified_it1000_LCI0_LCIA1
file_name='MC_results_eiv33_simplified_it1000_LCI0_LCIA1'

pickle_save(file_path_root,object_name_to_save,file_name)

# %% [markdown]
# ## Loading Python object with pickle

# %%
def pickle_load(file_path_root,file_name):
    
    complete_file_path=file_path_root+'\\'+file_name+'.p'
    
    return pickle.load( open( complete_file_path, "rb" ) );

# %%
file_path_root=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Pickle Python object saved'
object_name_to_save=MC_results_eiv33_simplified_it1000_LCI0_LCIA1
file_name='MC_results_eiv33_simplified_it1000_LCI0_LCIA1'

MC_results_eiv33_simplified_it1000_LCI0_LCIA1_loadtest=pickle_load(file_path_root,file_name)

# %% [markdown]
# # Test on a simplified DB

# %% [markdown]
# To create random DB from different version of ecoinvent

# %%
def create_simplified_random_db(complete_db,number_of_act):
    simplified_db=[complete_db.random() for i in range(10)]
    return simplified_db;

def create_db_from_db_with_same_act_code(complete_db,db_to_copy):
    act_codes=[act['code'] for act in db_to_copy]
    new_db=[act for act in complete_db if True in [act['code']==act_code for act_code in act_codes]]
    return new_db;

# %%
complete_db=ei33_db_no_uncert
number_of_act=10

ei33_db_LCI0_simplified_UP10=create_simplified_random_db(complete_db,number_of_act)

db_to_copy=ei33_db_LCI0_simplified_UP10
complete_db=ei33_db
ei33_db_LCI1_simplified_UP10=create_db_from_db_with_same_act_code(complete_db,db_to_copy)

ei33_db_LCI1_simplified_UP10
# Out:
# ['planing, beam, softwood, u=20%' (cubic meter, RoW, None),
#  'packaging glass production, brown' (kilogram, CH, None),
#  'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-GS, None),
#  'market for methanol factory' (unit, GLO, None),
#  'leaching of spodumene with sulfuric acid' (kilogram, GLO, None),
#  'market for p-chlorophenol' (kilogram, GLO, None),
#  'linseed production' (kilogram, RU, None),
#  'tomato seedling production, in unheated greenhouse, for planting' (unit, ES, None),
#  'infrastructure construction, for regional distribution of oil product' (unit, RoW, None),
#  'electricity, high voltage, import from SK' (kilowatt hour, HU, None)]

# %%
db_LCI0=ei33_db_LCI0_simplified_UP10
db_LCI1=ei33_db_LCI1_simplified_UP10
list_methods_name_LCIA0=IW_no_uncert
list_methods_name_LCIA1=IW_with_uncert_beta_wo
endpoint_name_1='Human Health'
endpoint_name_2='Ecosystem Quality'
iterations=1000

file_path_root=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Pickle Python object saved'

# %%
def mc_calculation_and_stats(db,list_methods_name,endpoint_name_1,endpoint_name_2,iterations):
    
    MC_results_dict=MC_multi_impact_entire_DB(db,list_methods_name,iterations)
    
    MC_results_dict=calculating_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2)
    MC_results_stats=calculating_stats_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2)
    
    return {'MC results':MC_results_dict,'stats':MC_results_stats}

# %%
results_ei33_db_simplified_UP10_LCI0_LCIA1=mc_calculation_and_stats(db_LCI0,list_methods_name_LCIA1,endpoint_name_1,endpoint_name_2,iterations)
object_name_to_save=results_ei33_db_simplified_UP10_LCI0_LCIA1
file_name='results_ei33_db_simplified_UP10_LCI0_LCIA1'
pickle_save(file_path_root,object_name_to_save,file_name)
# Out:
# 1 - 'infrastructure construction, for regional distribution of oil product' (unit, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 2 - 'market for p-chlorophenol' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 3 - 'tomato seedling production, in unheated greenhouse, for planting' (unit, ES, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 4 - 'electricity, high voltage, import from SK' (kilowatt hour, HU, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 5 - 'electricity production, wind, <1MW turbine, onshore' (kilowatt hour, CN-GS, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 6 - 'leaching of spodumene with sulfuric acid' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 7 - 'linseed production' (kilogram, RU, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 8 - 'market for methanol factory' (unit, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 9 - 'packaging glass production, brown' (kilogram, CH, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 10 - 'planing, beam, softwood, u=20%' (cubic meter, RoW, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')

# %% [markdown]
# Need to code a MC calculation with multi impact categories where the same LCI values are used for all IC during the same iteration --> do not run cell below, ot does not make sense as it is!

# %%
results_ei33_db_simplified_UP10_LCI1_LCIA0=mc_calculation_and_stats(db_LCI1,list_methods_name_LCIA0,endpoint_name_1,endpoint_name_2,iterations)
object_name_to_save=results_ei33_db_simplified_UP10_LCI1_LCIA0
file_name='results_ei33_db_simplified_UP10_LCI1_LCIA0'
pickle_save(file_path_root,object_name_to_save,file_name)

results_ei33_db_simplified_UP10_LCI1_LCIA1=mc_calculation_and_stats(db_LCI1,list_methods_name_LCIA1,endpoint_name_1,endpoint_name_2,iterations)
object_name_to_save=results_ei33_db_simplified_UP10_LCI1_LCIA1
file_name='results_ei33_db_simplified_UP10_LCI1_LCIA1'
pickle_save(file_path_root,object_name_to_save,file_name)
# Out:
# 1 - 'uranium fuel element production, enriched 3.8%, for light water reactor' (kilogram, CN, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Terrestrial acidification, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Human Health', 'Water availability, human health, GLO, with uncert')
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Marine eutrophication, GLO, with uncert')
# 2 - 'market for natural gas, from low pressure network (<0.1 bar), at service station' (kilogram, GLO, None)
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater acidification, GLO, with uncert')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-b0b644ad95f0> in <module>()
# ----> 1 results_ei33_db_simplified_UP10_LCI0_LCIA1=mc_calculation_and_stats(db_LCI0,list_methods_name_LCIA1,endpoint_name_1,endpoint_name_2,iterations)
#       2 object_name_to_save=results_ei33_db_simplified_UP10_LCI0_LCIA1
#       3 file_name='results_ei33_db_simplified_UP10_LCI0_LCIA1'
#       4 pickle_save(file_path_root,object_name_to_save,file_name)
#       5
#
# <ipython-input-178-248e3794f4bb> in mc_calculation_and_stats(db, list_methods_name, endpoint_name_1, endpoint_name_2, iterations)
#       1 def mc_calculation_and_stats(db,list_methods_name,endpoint_name_1,endpoint_name_2,iterations):
#       2
# ----> 3     MC_results_dict=MC_multi_impact_entire_DB(DB,list_methods_name,iterations)
#       4
#       5     MC_results_dict=calculating_endpoint(MC_results_dict,endpoint_name_1,endpoint_name_2)
#
# <ipython-input-104-8cd7ee56fed7> in MC_multi_impact_entire_DB(DB, list_methods_name, iterations)
#      11
#      12         fu_tuple = (act,1)
# ---> 13         scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
#      14         MC_results[act.key]=scores
#      15
#
# <ipython-input-102-eeb51539d7b1> in MC_multi_impact(fu_tuple, list_methods_name, iterations)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# <ipython-input-102-eeb51539d7b1> in <listcomp>(.0)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\monte_carlo.py in __next__(self)
#      92         if not hasattr(self, "tech_rng"):
#      93             self.load_data()
# ---> 94         self.rebuild_technosphere_matrix(self.tech_rng.next())
#      95         self.rebuild_biosphere_matrix(self.bio_rng.next())
#      96         if self.lcia:
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\lca.py in rebuild_technosphere_matrix(self, vector)
#     384             self.tech_params, self._activity_dict, self._product_dict,
#     385             "row", "col",
# --> 386             new_data=TBMBuilder.fix_supply_use(self.tech_params, vector.copy())
#     387         )
#     388
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\matrices.py in build_matrix(cls, array, row_dict, col_dict, row_index_label, col_index_label, data_label, new_data)
#     126             vector.astype(np.float64),
#     127             (array[row_index_label], array[col_index_label])),
# --> 128             (len(row_dict), len(col_dict))).tocsr()
#     129
#     130     @classmethod
#
# C:\bw2-python\envs\bw2\lib\site-packages\scipy\sparse\coo.py in tocsr(self)
#     360                       indptr,
#     361                       indices,
# --> 362                       data)
#     363
#     364             A = csr_matrix((data, indices, indptr), shape=self.shape)
#
# KeyboardInterrupt:
