# %%
import brightway2 as bw
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python
import csv
import stats_arrays

# %%
bw.projects.set_current('iw_integration')

# %% [markdown]
# First you have to add the generalized beta distribution in stats_array, following the corresponding notebook.

# %% [markdown]
# Loading CFs with uncertainty information for csv file. All ef_UUIDs correspond to elementary flows as defined in OpenLCA and classified for IMPACT World+. UUID in OpenLCA and BW2 are the same, nevertheless it exists additionnal elementary flows in OpenLCA. Therefore there are several elementary flows in the list that will not be relevant for the integration in BW2.

# %%
path_to_input_csv=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Files\All IC regionalized_with uncertainty.csv'
iw_olca_uncert = csv.DictReader(open(path_to_input_csv, "r"), delimiter=";")
iw_olca_uncert_list=[cf for cf in iw_olca_uncert]
iw_olca_uncert_dict={(cf['impact_cat_name'],cf['ef_UUID']):cf for cf in iw_olca_uncert_list}
iw_olca_uncert_dict
# Out:
# {('Freshwater acidification, GLO, with uncert',
#   '003697f1-54e9-409e-8179-23a95e99e4d7'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '003697f1-54e9-409e-8179-23a95e99e4d7',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Nitrogen dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '006aa3f7-59ba-450f-aa45-a2b2d1752647'): {'CF_formula': '1.591727031',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '146.2778145',
#   'IW_Sample_CF_Mean': '1.591727031',
#   'IW_Sample_CF_Min': '0.001710379',
#   'IW_Sample_CF_Std dev': '6.0942748',
#   'IW_Sample_CF_Variance': '37.14018533',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.665271967',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '146.2778145',
#   'beta_param_min': '0.001710379',
#   'ef_UUID': '006aa3f7-59ba-450f-aa45-a2b2d1752647',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Sulfate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.591727031',
#   'uncert_param3': '146.2778145',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '08a91e70-3ddc-11dd-954d-0050c2490048'): {'CF_formula': '1.746893022',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1556.719119',
#   'IW_Sample_CF_Mean': '1.746893022',
#   'IW_Sample_CF_Min': '0.000401678',
#   'IW_Sample_CF_Std dev': '6.357623159',
#   'IW_Sample_CF_Variance': '40.41937223',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.945945946',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1556.719119',
#   'beta_param_min': '0.000401678',
#   'ef_UUID': '08a91e70-3ddc-11dd-954d-0050c2490048',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Ammonium, ion',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000401678',
#   'uncert_param2': '1.746893022',
#   'uncert_param3': '1556.719119',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '08a91e70-3ddc-11dd-96ee-0050c2490048'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '08a91e70-3ddc-11dd-96ee-0050c2490048',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Nitrogen monoxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '0b7e10a8-6ca0-4a50-a39b-f2a019cb3610'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '0b7e10a8-6ca0-4a50-a39b-f2a019cb3610',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Nitrogen dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'): {'CF_formula': '0.584142094',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '68.58725307',
#   'IW_Sample_CF_Mean': '0.584181134',
#   'IW_Sample_CF_Min': '0.001758711',
#   'IW_Sample_CF_Std dev': '0.987867517',
#   'IW_Sample_CF_Variance': '0.975882232',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.730913642',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '68.58725307',
#   'beta_param_min': '0.001758711',
#   'ef_UUID': '0d1d9119-44bf-4c8e-a878-cdc78fd888ae',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Nitric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.584142094',
#   'uncert_param3': '68.58725307',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '0e0f75b3-2de4-4fbd-aee5-e0406b593ea8'): {'CF_formula': '2.246005314',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '2001.49601',
#   'IW_Sample_CF_Mean': '2.246005314',
#   'IW_Sample_CF_Min': '0.000516443',
#   'IW_Sample_CF_Std dev': '8.174086918',
#   'IW_Sample_CF_Variance': '66.81569695',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1.216216216',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '2001.49601',
#   'beta_param_min': '0.000516443',
#   'ef_UUID': '0e0f75b3-2de4-4fbd-aee5-e0406b593ea8',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Ammonia, as N',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000516443',
#   'uncert_param2': '2.246005314',
#   'uncert_param3': '2001.49601',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '0e9e6b81-0a68-4350-8368-566c083bd3e0'): {'CF_formula': '0.592144041',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '69.52680448',
#   'IW_Sample_CF_Mean': '0.592183615',
#   'IW_Sample_CF_Min': '0.001782803',
#   'IW_Sample_CF_Std dev': '1.001399949',
#   'IW_Sample_CF_Variance': '1.002801858',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.740926158',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '69.52680448',
#   'beta_param_min': '0.001782803',
#   'ef_UUID': '0e9e6b81-0a68-4350-8368-566c083bd3e0',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Nitrate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.592144041',
#   'uncert_param3': '69.52680448',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '0f440cc0-0f74-446d-99d6-8ff0e97a2444'): {'CF_formula': '1.846715481',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1645.674497',
#   'IW_Sample_CF_Mean': '1.846715481',
#   'IW_Sample_CF_Min': '0.000424631',
#   'IW_Sample_CF_Std dev': '6.72091591',
#   'IW_Sample_CF_Variance': '45.17071068',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1645.674497',
#   'beta_param_min': '0.000424631',
#   'ef_UUID': '0f440cc0-0f74-446d-99d6-8ff0e97a2444',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Ammonia',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000424631',
#   'uncert_param2': '1.846715481',
#   'uncert_param3': '1645.674497',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '11f41c41-7733-49bc-b1b1-1f00fbade521'): {'CF_formula': '0.652838878',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '581.7681736',
#   'IW_Sample_CF_Mean': '0.652838878',
#   'IW_Sample_CF_Min': '0.000150113',
#   'IW_Sample_CF_Std dev': '2.375934598',
#   'IW_Sample_CF_Variance': '5.645065212',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.353513514',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '581.7681736',
#   'beta_param_min': '0.000150113',
#   'ef_UUID': '11f41c41-7733-49bc-b1b1-1f00fbade521',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Ammonium carbonate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000150113',
#   'uncert_param2': '0.652838878',
#   'uncert_param3': '581.7681736',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '13825fb9-6e24-409a-bfcd-5dc4fd61ef98'): {'CF_formula': '1.912074609',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '175.7173746',
#   'IW_Sample_CF_Mean': '1.91207461',
#   'IW_Sample_CF_Min': '0.002054606',
#   'IW_Sample_CF_Std dev': '7.320795514',
#   'IW_Sample_CF_Variance': '53.59404696',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.79916318',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '175.7173746',
#   'beta_param_min': '0.002054606',
#   'ef_UUID': '13825fb9-6e24-409a-bfcd-5dc4fd61ef98',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Sulphur trioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.912074609',
#   'uncert_param3': '175.7173746',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc'): {'CF_formula': '0.652838878',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '581.7681736',
#   'IW_Sample_CF_Mean': '0.652838878',
#   'IW_Sample_CF_Min': '0.000150113',
#   'IW_Sample_CF_Std dev': '2.375934598',
#   'IW_Sample_CF_Variance': '5.645065212',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.353513514',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '581.7681736',
#   'beta_param_min': '0.000150113',
#   'ef_UUID': '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Ammonium carbonate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000150113',
#   'uncert_param2': '0.652838878',
#   'uncert_param3': '581.7681736',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '15ca802b-f541-44aa-bd33-35560a053193'): {'CF_formula': '0.592144041',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '69.52680448',
#   'IW_Sample_CF_Mean': '0.592183615',
#   'IW_Sample_CF_Min': '0.001782803',
#   'IW_Sample_CF_Std dev': '1.001399949',
#   'IW_Sample_CF_Variance': '1.002801858',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.740926158',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '69.52680448',
#   'beta_param_min': '0.001782803',
#   'ef_UUID': '15ca802b-f541-44aa-bd33-35560a053193',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Nitrate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.592144041',
#   'uncert_param3': '69.52680448',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '16521d00-4b6f-464f-b5dd-8da4a27b15ca'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '16521d00-4b6f-464f-b5dd-8da4a27b15ca',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Sulfur dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '1aa538b9-51eb-49fe-8904-de34e58945c7'): {'CF_formula': '0.584142094',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '68.58725307',
#   'IW_Sample_CF_Mean': '0.584181134',
#   'IW_Sample_CF_Min': '0.001758711',
#   'IW_Sample_CF_Std dev': '0.987867517',
#   'IW_Sample_CF_Variance': '0.975882232',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.730913642',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '68.58725307',
#   'beta_param_min': '0.001758711',
#   'ef_UUID': '1aa538b9-51eb-49fe-8904-de34e58945c7',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Nitric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.584142094',
#   'uncert_param3': '68.58725307',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '205617ae-ebc5-4245-8df6-8710d5d40615'): {'CF_formula': '0.592144041',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '69.52680448',
#   'IW_Sample_CF_Mean': '0.592183615',
#   'IW_Sample_CF_Min': '0.001782803',
#   'IW_Sample_CF_Std dev': '1.001399949',
#   'IW_Sample_CF_Variance': '1.002801858',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.740926158',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '69.52680448',
#   'beta_param_min': '0.001782803',
#   'ef_UUID': '205617ae-ebc5-4245-8df6-8710d5d40615',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Nitrate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.592144041',
#   'uncert_param3': '69.52680448',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '2b50f643-216a-412b-a0e5-5946867aa2ed'): {'CF_formula': '1.846715481',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1645.674497',
#   'IW_Sample_CF_Mean': '1.846715481',
#   'IW_Sample_CF_Min': '0.000424631',
#   'IW_Sample_CF_Std dev': '6.72091591',
#   'IW_Sample_CF_Variance': '45.17071068',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1645.674497',
#   'beta_param_min': '0.000424631',
#   'ef_UUID': '2b50f643-216a-412b-a0e5-5946867aa2ed',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Ammonia',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000424631',
#   'uncert_param2': '1.846715481',
#   'uncert_param3': '1645.674497',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '2e493ad7-ff7f-47b8-9966-1d67e0323386'): {'CF_formula': '0.584142094',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '68.58725307',
#   'IW_Sample_CF_Mean': '0.584181134',
#   'IW_Sample_CF_Min': '0.001758711',
#   'IW_Sample_CF_Std dev': '0.987867517',
#   'IW_Sample_CF_Variance': '0.975882232',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.730913642',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '68.58725307',
#   'beta_param_min': '0.001758711',
#   'ef_UUID': '2e493ad7-ff7f-47b8-9966-1d67e0323386',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Nitric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.584142094',
#   'uncert_param3': '68.58725307',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '3268d8df-59cc-4740-a89f-dee8355ad7c3'): {'CF_formula': '1.912074609',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '175.7173746',
#   'IW_Sample_CF_Mean': '1.91207461',
#   'IW_Sample_CF_Min': '0.002054606',
#   'IW_Sample_CF_Std dev': '7.320795514',
#   'IW_Sample_CF_Variance': '53.59404696',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.79916318',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '175.7173746',
#   'beta_param_min': '0.002054606',
#   'ef_UUID': '3268d8df-59cc-4740-a89f-dee8355ad7c3',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Sulphur trioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.912074609',
#   'uncert_param3': '175.7173746',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'): {'CF_formula': '0.584142094',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '68.58725307',
#   'IW_Sample_CF_Mean': '0.584181134',
#   'IW_Sample_CF_Min': '0.001758711',
#   'IW_Sample_CF_Std dev': '0.987867517',
#   'IW_Sample_CF_Variance': '0.975882232',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.730913642',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '68.58725307',
#   'beta_param_min': '0.001758711',
#   'ef_UUID': '37d014cb-8c2d-4c98-ab5c-2d4550822c2f',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Nitric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.584142094',
#   'uncert_param3': '68.58725307',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '3caec0e2-2d07-4463-abae-bef6a0d4bbdb'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '3caec0e2-2d07-4463-abae-bef6a0d4bbdb',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Sulfuric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '4490af97-53d7-4849-aa85-34b5a50e516b'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '4490af97-53d7-4849-aa85-34b5a50e516b',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Nitrogen dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '4841a0fe-c250-4a39-94a1-1bc31426c0f1'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '4841a0fe-c250-4a39-94a1-1bc31426c0f1',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Nitrogen oxides',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '48430c70-95e0-4036-9854-72cc772ac8b2'): {'CF_formula': '1.912074609',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '175.7173746',
#   'IW_Sample_CF_Mean': '1.91207461',
#   'IW_Sample_CF_Min': '0.002054606',
#   'IW_Sample_CF_Std dev': '7.320795514',
#   'IW_Sample_CF_Variance': '53.59404696',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.79916318',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '175.7173746',
#   'beta_param_min': '0.002054606',
#   'ef_UUID': '48430c70-95e0-4036-9854-72cc772ac8b2',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Sulphur trioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.912074609',
#   'uncert_param3': '175.7173746',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '51f0e6bf-5824-4247-a0f0-7766035da159'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '51f0e6bf-5824-4247-a0f0-7766035da159',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Sulfuric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '5c9d8310-f7e1-4e98-8e73-7eece0435676'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '5c9d8310-f7e1-4e98-8e73-7eece0435676',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Sulfuric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '5e7cf95c-9cc3-4479-89af-55377b3db99c'): {'CF_formula': '0.592144041',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '69.52680448',
#   'IW_Sample_CF_Mean': '0.592183615',
#   'IW_Sample_CF_Min': '0.001782803',
#   'IW_Sample_CF_Std dev': '1.001399949',
#   'IW_Sample_CF_Variance': '1.002801858',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.740926158',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '69.52680448',
#   'beta_param_min': '0.001782803',
#   'ef_UUID': '5e7cf95c-9cc3-4479-89af-55377b3db99c',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Nitrate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.592144041',
#   'uncert_param3': '69.52680448',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '615c56b4-3328-43b3-b1cd-feb6b6a5d99c'): {'CF_formula': '1.746893022',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1556.719119',
#   'IW_Sample_CF_Mean': '1.746893022',
#   'IW_Sample_CF_Min': '0.000401678',
#   'IW_Sample_CF_Std dev': '6.357623159',
#   'IW_Sample_CF_Variance': '40.41937223',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.945945946',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1556.719119',
#   'beta_param_min': '0.000401678',
#   'ef_UUID': '615c56b4-3328-43b3-b1cd-feb6b6a5d99c',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Ammonium, ion',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000401678',
#   'uncert_param2': '1.746893022',
#   'uncert_param3': '1556.719119',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '65bff69f-3b58-457c-bb21-45ad200b04e2'): {'CF_formula': '0.592144041',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '69.52680448',
#   'IW_Sample_CF_Mean': '0.592183615',
#   'IW_Sample_CF_Min': '0.001782803',
#   'IW_Sample_CF_Std dev': '1.001399949',
#   'IW_Sample_CF_Variance': '1.002801858',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '0.740926158',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '69.52680448',
#   'beta_param_min': '0.001782803',
#   'ef_UUID': '65bff69f-3b58-457c-bb21-45ad200b04e2',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Nitrate compounds',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.592144041',
#   'uncert_param3': '69.52680448',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '6ce44f77-d181-4396-8fa2-2276eeeb4c08'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '6ce44f77-d181-4396-8fa2-2276eeeb4c08',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Sulfur dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '73ec59d7-a227-407f-963a-fd9c61b4d172'): {'CF_formula': '0.652838878',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '581.7681736',
#   'IW_Sample_CF_Mean': '0.652838878',
#   'IW_Sample_CF_Min': '0.000150113',
#   'IW_Sample_CF_Std dev': '2.375934598',
#   'IW_Sample_CF_Variance': '5.645065212',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.353513514',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '581.7681736',
#   'beta_param_min': '0.000150113',
#   'ef_UUID': '73ec59d7-a227-407f-963a-fd9c61b4d172',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Ammonium carbonate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000150113',
#   'uncert_param2': '0.652838878',
#   'uncert_param3': '581.7681736',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '77357947-ccc5-438e-9996-95e65e1e1bce'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '77357947-ccc5-438e-9996-95e65e1e1bce',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Nitrogen oxides',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '78c3efe4-421c-4d30-82e4-b97ac5124993'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '78c3efe4-421c-4d30-82e4-b97ac5124993',
#   'flow_category_subcompart': 'low population density',
#   'flow_name': 'Sulfur dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '7ecc2b66-8dde-4266-8832-f492f564377b'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '7ecc2b66-8dde-4266-8832-f492f564377b',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Sulfuric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '826677aa-8347-4494-85da-a26fe3e1e824'): {'CF_formula': '1.591727031',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '146.2778145',
#   'IW_Sample_CF_Mean': '1.591727031',
#   'IW_Sample_CF_Min': '0.001710379',
#   'IW_Sample_CF_Std dev': '6.0942748',
#   'IW_Sample_CF_Variance': '37.14018533',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.665271967',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '146.2778145',
#   'beta_param_min': '0.001710379',
#   'ef_UUID': '826677aa-8347-4494-85da-a26fe3e1e824',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Sulfate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.591727031',
#   'uncert_param3': '146.2778145',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'): {'CF_formula': '1.846715481',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1645.674497',
#   'IW_Sample_CF_Mean': '1.846715481',
#   'IW_Sample_CF_Min': '0.000424631',
#   'IW_Sample_CF_Std dev': '6.72091591',
#   'IW_Sample_CF_Variance': '45.17071068',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1645.674497',
#   'beta_param_min': '0.000424631',
#   'ef_UUID': '8494ed3c-0416-4aa5-b100-51a2b2bcadbd',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Ammonia',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000424631',
#   'uncert_param2': '1.846715481',
#   'uncert_param3': '1645.674497',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'): {'CF_formula': '1.846715481',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1645.674497',
#   'IW_Sample_CF_Mean': '1.846715481',
#   'IW_Sample_CF_Min': '0.000424631',
#   'IW_Sample_CF_Std dev': '6.72091591',
#   'IW_Sample_CF_Variance': '45.17071068',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1645.674497',
#   'beta_param_min': '0.000424631',
#   'ef_UUID': '87883a4e-1e3e-4c9d-90c0-f1bea36f8014',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Ammonia',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000424631',
#   'uncert_param2': '1.846715481',
#   'uncert_param3': '1645.674497',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '887bfb8e-44de-4de0-b47d-bc49db8adec1'): {'CF_formula': '1.746893022',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1556.719119',
#   'IW_Sample_CF_Mean': '1.746893022',
#   'IW_Sample_CF_Min': '0.000401678',
#   'IW_Sample_CF_Std dev': '6.357623159',
#   'IW_Sample_CF_Variance': '40.41937223',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '0.945945946',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1556.719119',
#   'beta_param_min': '0.000401678',
#   'ef_UUID': '887bfb8e-44de-4de0-b47d-bc49db8adec1',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Ammonium, ion',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000401678',
#   'uncert_param2': '1.746893022',
#   'uncert_param3': '1556.719119',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '8c52f40c-69b7-4538-8923-b371523c71f5'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '8c52f40c-69b7-4538-8923-b371523c71f5',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Sulfur dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9115356e-a534-4329-9ec6-d9208720241b'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '9115356e-a534-4329-9ec6-d9208720241b',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Nitrogen oxides',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9990b51b-7023-4700-bca0-1a32ef921f74'): {'CF_formula': '1.846715481',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '1645.674497',
#   'IW_Sample_CF_Mean': '1.846715481',
#   'IW_Sample_CF_Min': '0.000424631',
#   'IW_Sample_CF_Std dev': '6.72091591',
#   'IW_Sample_CF_Variance': '45.17071068',
#   'IW_ef': 'NH3',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.074258037',
#   'beta_param_beta': '66.11494813',
#   'beta_param_max': '1645.674497',
#   'beta_param_min': '0.000424631',
#   'ef_UUID': '9990b51b-7023-4700-bca0-1a32ef921f74',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Ammonia',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0.000424631',
#   'uncert_param2': '1.846715481',
#   'uncert_param3': '1645.674497',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '99c65c6a-6871-40ba-af79-5bd6851688e4'): {'CF_formula': '2.392595977',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '219.8767148',
#   'IW_Sample_CF_Mean': '2.392595978',
#   'IW_Sample_CF_Min': '0.002570947',
#   'IW_Sample_CF_Std dev': '9.160576586',
#   'IW_Sample_CF_Variance': '83.91616338',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '219.8767148',
#   'beta_param_min': '0.002570947',
#   'ef_UUID': '99c65c6a-6871-40ba-af79-5bd6851688e4',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Sulfuric acid',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '2.392595977',
#   'uncert_param3': '219.8767148',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9af58019-22ff-4278-8f48-8e94b49aae5c'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '9af58019-22ff-4278-8f48-8e94b49aae5c',
#   'flow_category_subcompart': 'high population density',
#   'flow_name': 'Nitrite',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9b00c244-fcce-4d38-922b-601a81f2ba34'): {'CF_formula': '1.591727031',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '146.2778145',
#   'IW_Sample_CF_Mean': '1.591727031',
#   'IW_Sample_CF_Min': '0.001710379',
#   'IW_Sample_CF_Std dev': '6.0942748',
#   'IW_Sample_CF_Variance': '37.14018533',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.665271967',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '146.2778145',
#   'beta_param_min': '0.001710379',
#   'ef_UUID': '9b00c244-fcce-4d38-922b-601a81f2ba34',
#   'flow_category_subcompart': 'unspecified air',
#   'flow_name': 'Sulfate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.591727031',
#   'uncert_param3': '146.2778145',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9d0b18e8-484d-4d28-bca4-2db8023def45'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '9d0b18e8-484d-4d28-bca4-2db8023def45',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Nitrogen monoxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   '9fb048e8-b1c4-4b1a-b536-5467d511f75a'): {'CF_formula': '0.799194406',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '93.83769727',
#   'IW_Sample_CF_Mean': '0.799247818',
#   'IW_Sample_CF_Min': '0.002406182',
#   'IW_Sample_CF_Std dev': '1.35155162',
#   'IW_Sample_CF_Variance': '1.826691782',
#   'IW_ef': 'NOx',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.336155493',
#   'beta_param_beta': '39.24918627',
#   'beta_param_max': '93.83769727',
#   'beta_param_min': '0.002406182',
#   'ef_UUID': '9fb048e8-b1c4-4b1a-b536-5467d511f75a',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Nitrogen dioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.799194406',
#   'uncert_param3': '93.83769727',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   'a259eb99-e741-49e6-8b3f-8985c018be28'): {'CF_formula': '1.591727031',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '146.2778145',
#   'IW_Sample_CF_Mean': '1.591727031',
#   'IW_Sample_CF_Min': '0.001710379',
#   'IW_Sample_CF_Std dev': '6.0942748',
#   'IW_Sample_CF_Variance': '37.14018533',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.665271967',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '146.2778145',
#   'beta_param_min': '0.001710379',
#   'ef_UUID': 'a259eb99-e741-49e6-8b3f-8985c018be28',
#   'flow_category_subcompart': 'low population density, long-term',
#   'flow_name': 'Sulfate',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.591727031',
#   'uncert_param3': '146.2778145',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   'aeb3e625-906a-4993-9f02-785f8cfd1ea5'): {'CF_formula': '1.912074609',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '175.7173746',
#   'IW_Sample_CF_Mean': '1.91207461',
#   'IW_Sample_CF_Min': '0.002054606',
#   'IW_Sample_CF_Std dev': '7.320795514',
#   'IW_Sample_CF_Variance': '53.59404696',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.79916318',
#   'beta_param_alpha': '0.05646066',
#   'beta_param_beta': '5.137727289',
#   'beta_param_max': '175.7173746',
#   'beta_param_min': '0.002054606',
#   'ef_UUID': 'aeb3e625-906a-4993-9f02-785f8cfd1ea5',
#   'flow_category_subcompart': 'lower stratosphere + upper troposphere',
#   'flow_name': 'Sulphur trioxide',
#   'impact_cat_name': 'Freshwater acidification, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.912074609',
#   'uncert_param3': '175.7173746',
#   'uncert_type_name': 'triangle'},
#  ('Freshwater acidification, GLO, with uncert',
#   'b00950bc-99cb-4ee2-bbc0-5f878ea170c3'): {'CF_formula': '1.912074609',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'PDF.m2.yr',
#   'IW_Sample_CF_Max': '175.7173746',
#   'IW_Sample_CF_Mean': '1.91207461',
#   'IW_Sample_CF_Min': '0.002054606',
#   'IW_Sample_CF_Std dev': '7.320795514',
#   'IW_Sample_CF_Variance': '53.59404696',
#   'IW_ef': 'SO2',
#   'Stoechiometric_ratio': '0.79916318',
# ...
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'eba958f5-ffe1-3f4b-8f2c-8bc7b5a9b275',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, cooling, unspecified natural origin, MK',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'eba9b309-7926-37da-a4c5-0d4c2ef894f9'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'eba9b309-7926-37da-a4c5-0d4c2ef894f9',
#   'flow_category_subcompart': 'unspecified resource',
#   'flow_name': 'Water, unspecified natural origin, PK',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'ed3fdab8-6123-4c08-a25b-0a74a7fa779a'): {'CF_formula': '0',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0',
#   'IW_Sample_CF_Mean': '0',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '0',
#   'IW_Sample_CF_Variance': '0',
#   'IW_ef': 'Ocean',
#   'Stoechiometric_ratio': '-1',
#   'beta_param_alpha': '0',
#   'beta_param_beta': '0',
#   'beta_param_max': '0',
#   'beta_param_min': '0',
#   'ef_UUID': 'ed3fdab8-6123-4c08-a25b-0a74a7fa779a',
#   'flow_category_subcompart': 'ocean',
#   'flow_name': 'Water',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0',
#   'uncert_param3': '0',
#   'uncert_type_name': 'none'},
#  ('Water availability, human health, GLO, with uncert',
#   'f16adc98-f687-31b6-a538-af2914eacd2a'): {'CF_formula': '0',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0',
#   'IW_Sample_CF_Mean': '0',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '0',
#   'IW_Sample_CF_Variance': '0',
#   'IW_ef': 'Ocean',
#   'Stoechiometric_ratio': '-1',
#   'beta_param_alpha': '0',
#   'beta_param_beta': '0',
#   'beta_param_max': '0',
#   'beta_param_min': '0',
#   'ef_UUID': 'f16adc98-f687-31b6-a538-af2914eacd2a',
#   'flow_category_subcompart': 'ocean',
#   'flow_name': 'Water, IAI Area 8',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0',
#   'uncert_param3': '0',
#   'uncert_type_name': 'none'},
#  ('Water availability, human health, GLO, with uncert',
#   'f1a90356-cac4-3eb4-8619-eabe3d45c696'): {'CF_formula': '0.000128392',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001376656',
#   'IW_Sample_CF_Mean': '0.000128392',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '0.000108853',
#   'IW_Sample_CF_Variance': '1.18E-08',
#   'IW_ef': 'Surface',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.16820009',
#   'beta_param_beta': '11.35759719',
#   'beta_param_max': '0.001376656',
#   'beta_param_min': '0',
#   'ef_UUID': 'f1a90356-cac4-3eb4-8619-eabe3d45c696',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, turbine use, unspecified natural origin, IT',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000128392',
#   'uncert_param3': '0.001376656',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f1bc0318-5825-3ea8-b36a-53c0b602c412'): {'CF_formula': '0.000128392',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001376656',
#   'IW_Sample_CF_Mean': '0.000128392',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '0.000108853',
#   'IW_Sample_CF_Variance': '1.18E-08',
#   'IW_ef': 'Surface',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.16820009',
#   'beta_param_beta': '11.35759719',
#   'beta_param_max': '0.001376656',
#   'beta_param_min': '0',
#   'ef_UUID': 'f1bc0318-5825-3ea8-b36a-53c0b602c412',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, turbine use, unspecified natural origin, MY',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000128392',
#   'uncert_param3': '0.001376656',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f1bdb3e1-1235-4939-a4a0-6383caa42c63'): {'CF_formula': '-1.28E-07',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0',
#   'IW_Sample_CF_Mean': '-0.000128392',
#   'IW_Sample_CF_Min': '-0.001376656',
#   'IW_Sample_CF_Std dev': '0.000108853',
#   'IW_Sample_CF_Variance': '1.18E-08',
#   'IW_ef': 'Surface',
#   'Stoechiometric_ratio': '-1',
#   'beta_param_alpha': '11.35759719',
#   'beta_param_beta': '1.16820009',
#   'beta_param_max': '0',
#   'beta_param_min': '-0.001376656',
#   'ef_UUID': 'f1bdb3e1-1235-4939-a4a0-6383caa42c63',
#   'flow_category_subcompart': 'fresh water',
#   'flow_name': 'Water (river water from technosphere, waste water)',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '-1.38E-06',
#   'uncert_param2': '-1.28E-07',
#   'uncert_param3': '0',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, cooling, unspecified natural origin, CH',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f31750b0-268a-4d18-b694-8e79e91aff86'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'f31750b0-268a-4d18-b694-8e79e91aff86',
#   'flow_category_subcompart': 'unspecified resource',
#   'flow_name': 'Water, cooling, unspecified natural origin',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f4ed16d1-aacb-344f-ab16-aeb44de80128'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'f4ed16d1-aacb-344f-ab16-aeb44de80128',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, cooling, unspecified natural origin, PH',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f7baa589-bb9c-36c2-8ac2-4e23874315b5'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'f7baa589-bb9c-36c2-8ac2-4e23874315b5',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, cooling, unspecified natural origin, JP',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f835e4b9-3073-4547-ab20-ba20886fd6a3'): {'CF_formula': '6.35E-08',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.003107878',
#   'IW_Sample_CF_Mean': '6.35E-05',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '8.37E-05',
#   'IW_Sample_CF_Variance': '7.00E-09',
#   'IW_ef': 'Ground',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.544415251',
#   'beta_param_beta': '26.09022203',
#   'beta_param_max': '0.003107878',
#   'beta_param_min': '0',
#   'ef_UUID': 'f835e4b9-3073-4547-ab20-ba20886fd6a3',
#   'flow_category_subcompart': 'unspecified resource',
#   'flow_name': 'Water, groundwater consumption',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '6.35E-08',
#   'uncert_param3': '3.11E-06',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f838aec9-cb26-4597-bb6f-478cdf32e32a'): {'CF_formula': '1.14E-07',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'f838aec9-cb26-4597-bb6f-478cdf32e32a',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water Cooling fresh',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '1.14E-07',
#   'uncert_param3': '1.13E-06',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'f87edd21-d830-3d32-aeee-e69320033ccd'): {'CF_formula': '0.000128392',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001376656',
#   'IW_Sample_CF_Mean': '0.000128392',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '0.000108853',
#   'IW_Sample_CF_Variance': '1.18E-08',
#   'IW_ef': 'Surface',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.16820009',
#   'beta_param_beta': '11.35759719',
#   'beta_param_max': '0.001376656',
#   'beta_param_min': '0',
#   'ef_UUID': 'f87edd21-d830-3d32-aeee-e69320033ccd',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, turbine use, unspecified natural origin, AU',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000128392',
#   'uncert_param3': '0.001376656',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'fc1c42ce-a759-49fa-b987-f1ec5e503db1'): {'CF_formula': '0.000114438',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.001132988',
#   'IW_Sample_CF_Mean': '0.000114438',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '9.45E-05',
#   'IW_Sample_CF_Variance': '8.93E-09',
#   'IW_ef': 'Unknown',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '1.217045247',
#   'beta_param_beta': '10.83226341',
#   'beta_param_max': '0.001132988',
#   'beta_param_min': '0',
#   'ef_UUID': 'fc1c42ce-a759-49fa-b987-f1ec5e503db1',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, cooling, unspecified natural origin',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '0.000114438',
#   'uncert_param3': '0.001132988',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'fe0acd60-3ddc-11dd-ae59-0050c2490048'): {'CF_formula': '6.35E-08',
#   'CF_per_unit_name': 'kg',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0.003107878',
#   'IW_Sample_CF_Mean': '6.35E-05',
#   'IW_Sample_CF_Min': '0',
#   'IW_Sample_CF_Std dev': '8.37E-05',
#   'IW_Sample_CF_Variance': '7.00E-09',
#   'IW_ef': 'Ground',
#   'Stoechiometric_ratio': '1',
#   'beta_param_alpha': '0.544415251',
#   'beta_param_beta': '26.09022203',
#   'beta_param_max': '0.003107878',
#   'beta_param_min': '0',
#   'ef_UUID': 'fe0acd60-3ddc-11dd-ae59-0050c2490048',
#   'flow_category_subcompart': 'in water',
#   'flow_name': 'Water, ground',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '0',
#   'uncert_param2': '6.35E-08',
#   'uncert_param3': '3.11E-06',
#   'uncert_type_name': 'triangle'},
#  ('Water availability, human health, GLO, with uncert',
#   'feae94ff-e17a-3b3a-af20-6a50b822c273'): {'CF_formula': '-0.000128392',
#   'CF_per_unit_name': 'm3',
#   'CF_unit': 'DALY',
#   'IW_Sample_CF_Max': '0',
#   'IW_Sample_CF_Mean': '-0.000128392',
#   'IW_Sample_CF_Min': '-0.001376656',
#   'IW_Sample_CF_Std dev': '0.000108853',
#   'IW_Sample_CF_Variance': '1.18E-08',
#   'IW_ef': 'Surface',
#   'Stoechiometric_ratio': '-1',
#   'beta_param_alpha': '11.35759719',
#   'beta_param_beta': '1.16820009',
#   'beta_param_max': '0',
#   'beta_param_min': '-0.001376656',
#   'ef_UUID': 'feae94ff-e17a-3b3a-af20-6a50b822c273',
#   'flow_category_subcompart': 'river',
#   'flow_name': 'Water, PT',
#   'impact_cat_name': 'Water availability, human health, GLO, with uncert',
#   'impact_method_name': 'IMPACTWorld+ - Endpoint - only with spatial variability',
#   'uncert_param1': '-0.001376656',
#   'uncert_param2': '-0.000128392',
#   'uncert_param3': '0',
#   'uncert_type_name': 'triangle'}}

# %% [markdown]
# Here is the error found when performing Monte Carlo analysis

# %% [markdown]
# ---------------------------------------------------------------------------
# MaximumIterationsError                    Traceback (most recent call last)
# <ipython-input-35-90425dfde9bb> in <module>()
#       6 iterations = 10
#       7
# ----> 8 scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
#       9 scores
#
# <ipython-input-11-eeb51539d7b1> in MC_multi_impact(fu_tuple, list_methods_name, iterations)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# <ipython-input-11-eeb51539d7b1> in <listcomp>(.0)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\monte_carlo.py in __next__(self)
#      95         self.rebuild_biosphere_matrix(self.bio_rng.next())
#      96         if self.lcia:
# ---> 97             self.rebuild_characterization_matrix(self.cf_rng.next())
#      98         if self.weighting:
#      99             self.weighting_value = self.weighting_rng.next()
#
# C:\bw2-python\envs\bw2\lib\site-packages\stats_arrays\random.py in next(self)
#     181                 1,
#     182                 self.random,
# --> 183                 self.maximum_iterations
#     184             )
#     185             if len(random_data.shape) == 2:
#
# C:\bw2-python\envs\bw2\lib\site-packages\stats_arrays\distributions\base.py in bounded_random_variables(cls, params, size, seeded_random, maximum_iterations)
#     210             counter += 1
#     211             if counter >= maximum_iterations:
# --> 212                 print(str(maximum_iterations))
#     213                 raise MaximumIterationsError
#     214         return data
#
# MaximumIterationsError:

# %% [markdown]
# ## Creating uncertainty dictionaries for each CFs

# %% [markdown]
# The priority order for the choice of distribution is : 1- Generalized Beta distribution if alpha and beta positive or No distribution if specified 2- if alpha and beta negative, Triangular distribution with moment method 3- if mode_triangular<minimum, Bounded Normal with moment method (no problem with negative CFs)

# %%
def uncert_dict_triang_moment_method(sample_min,sample_mean,sample_max):
    
    mode = 3 * sample_mean - sample_min - sample_max
    
    if mode < sample_min:
        uncert_dict={'amount': sample_mean,
                'uncertainty type': stats_arrays.NoUncertainty.id};
    else:
        uncert_dict={'amount': sample_mean,
                'loc': mode,
                'maximum': sample_max,
                'minimum': sample_min,
                'uncertainty type': stats_arrays.TriangularUncertainty.id};
        
    return uncert_dict;

# %%
from stats_arrays import MCRandomNumberGenerator, UncertaintyBase


def test_distrib(ID,uncert_dict):
    params_distrib = UncertaintyBase.from_dicts(uncert_dict)
    mcrng_distrib = MCRandomNumberGenerator(params_distrib)
    try:
        mcrng_distrib.next()
        return;
    except:
        tuple_error=(ID,uncert_dict)
        return tuple_error;

# %%
iw_uncert_dict_beta={}
iw_uncert_beta_distrib={}
iw_uncert_none_distrib={}
iw_uncert_triang_distrib={}
iw_uncert_normal_distrib={}

list_error_generalized_beta=[]
list_error_triang=[]
list_error_normal=[]

i=0

for cf in iw_olca_uncert_dict:
    
    i=i+1
    
    amount=float(iw_olca_uncert_dict[cf]['CF_formula'])
    uncert_type=iw_olca_uncert_dict[cf]['uncert_type_name']
    
    if uncert_type.lower()=="none":
        uncert_dict=amount
        iw_uncert_dict_beta[cf]=uncert_dict
        iw_uncert_none_distrib[cf]=uncert_dict
        continue
    else:        
        alpha=float(iw_olca_uncert_dict[cf]['beta_param_alpha'])
        beta=float(iw_olca_uncert_dict[cf]['beta_param_beta'])
        minimum=float(iw_olca_uncert_dict[cf]['beta_param_min'])
        maximum=float(iw_olca_uncert_dict[cf]['beta_param_max'])
        mean=float(iw_olca_uncert_dict[cf]['IW_Sample_CF_Mean'])
        variance=float(iw_olca_uncert_dict[cf]['IW_Sample_CF_Variance'])
        mode_triang = 3 * mean - minimum - maximum
    
    if alpha>0 and beta>0:
        uncert_dict={'amount': amount,
                          'loc': alpha, 
                          'shape': beta, 
                          'maximum': maximum,
                          'minimum': minimum,
                          'uncertainty type': stats_arrays.GeneralizedBetaUncertainty.id}
        iw_uncert_dict_beta[cf]=uncert_dict
        iw_uncert_beta_distrib[cf]=uncert_dict
        if test_distrib(cf,uncert_dict)!= None:
            list_error_generalized_beta.append(test_distrib(cf,uncert_dict))
        continue
     
    elif mode_triang >= minimum:
        uncert_dict=uncert_dict_triang_moment_method(minimum,mean,maximum)
        iw_uncert_dict_beta[cf]=uncert_dict
        iw_uncert_triang_distrib[cf]=uncert_dict
        if test_distrib(cf,uncert_dict)!= None:
            list_error_triang.append(test_distrib(cf,uncert_dict))
        continue
    
    else:
        uncert_dict={'amount': amount,
                          'loc': mean, 
                          'scale': np.sqrt(np.abs(variance)), 
                          'maximum': maximum,
                          'minimum': minimum,
                          'uncertainty type': stats_arrays.NormalUncertainty.id}
        iw_uncert_dict_beta[cf]=uncert_dict
        iw_uncert_normal_distrib[cf]=uncert_dict
        if test_distrib(cf,uncert_dict)!= None:
            list_error_normal.append(test_distrib(cf,uncert_dict))

iw_uncert_dict_beta
# Out:
# {('Freshwater acidification, GLO, with uncert',
#   '003697f1-54e9-409e-8179-23a95e99e4d7'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '006aa3f7-59ba-450f-aa45-a2b2d1752647'): {'amount': 1.591727031,
#   'loc': 0.05646066,
#   'maximum': 146.2778145,
#   'minimum': 0.001710379,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '08a91e70-3ddc-11dd-954d-0050c2490048'): {'amount': 1.746893022,
#   'loc': 0.074258037,
#   'maximum': 1556.719119,
#   'minimum': 0.000401678,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '08a91e70-3ddc-11dd-96ee-0050c2490048'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '0b7e10a8-6ca0-4a50-a39b-f2a019cb3610'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'): {'amount': 0.584142094,
#   'loc': 0.336155493,
#   'maximum': 68.58725307,
#   'minimum': 0.001758711,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '0e0f75b3-2de4-4fbd-aee5-e0406b593ea8'): {'amount': 2.246005314,
#   'loc': 0.074258037,
#   'maximum': 2001.49601,
#   'minimum': 0.000516443,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '0e9e6b81-0a68-4350-8368-566c083bd3e0'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '0f440cc0-0f74-446d-99d6-8ff0e97a2444'): {'amount': 1.846715481,
#   'loc': 0.074258037,
#   'maximum': 1645.674497,
#   'minimum': 0.000424631,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '11f41c41-7733-49bc-b1b1-1f00fbade521'): {'amount': 0.652838878,
#   'loc': 0.074258037,
#   'maximum': 581.7681736,
#   'minimum': 0.000150113,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '13825fb9-6e24-409a-bfcd-5dc4fd61ef98'): {'amount': 1.912074609,
#   'loc': 0.05646066,
#   'maximum': 175.7173746,
#   'minimum': 0.002054606,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc'): {'amount': 0.652838878,
#   'loc': 0.074258037,
#   'maximum': 581.7681736,
#   'minimum': 0.000150113,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '15ca802b-f541-44aa-bd33-35560a053193'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '16521d00-4b6f-464f-b5dd-8da4a27b15ca'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '1aa538b9-51eb-49fe-8904-de34e58945c7'): {'amount': 0.584142094,
#   'loc': 0.336155493,
#   'maximum': 68.58725307,
#   'minimum': 0.001758711,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '205617ae-ebc5-4245-8df6-8710d5d40615'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '2b50f643-216a-412b-a0e5-5946867aa2ed'): {'amount': 1.846715481,
#   'loc': 0.074258037,
#   'maximum': 1645.674497,
#   'minimum': 0.000424631,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '2e493ad7-ff7f-47b8-9966-1d67e0323386'): {'amount': 0.584142094,
#   'loc': 0.336155493,
#   'maximum': 68.58725307,
#   'minimum': 0.001758711,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '3268d8df-59cc-4740-a89f-dee8355ad7c3'): {'amount': 1.912074609,
#   'loc': 0.05646066,
#   'maximum': 175.7173746,
#   'minimum': 0.002054606,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'): {'amount': 0.584142094,
#   'loc': 0.336155493,
#   'maximum': 68.58725307,
#   'minimum': 0.001758711,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '3caec0e2-2d07-4463-abae-bef6a0d4bbdb'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '4490af97-53d7-4849-aa85-34b5a50e516b'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '4841a0fe-c250-4a39-94a1-1bc31426c0f1'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '48430c70-95e0-4036-9854-72cc772ac8b2'): {'amount': 1.912074609,
#   'loc': 0.05646066,
#   'maximum': 175.7173746,
#   'minimum': 0.002054606,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '51f0e6bf-5824-4247-a0f0-7766035da159'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '5c9d8310-f7e1-4e98-8e73-7eece0435676'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '5e7cf95c-9cc3-4479-89af-55377b3db99c'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '615c56b4-3328-43b3-b1cd-feb6b6a5d99c'): {'amount': 1.746893022,
#   'loc': 0.074258037,
#   'maximum': 1556.719119,
#   'minimum': 0.000401678,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '65bff69f-3b58-457c-bb21-45ad200b04e2'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '6ce44f77-d181-4396-8fa2-2276eeeb4c08'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '73ec59d7-a227-407f-963a-fd9c61b4d172'): {'amount': 0.652838878,
#   'loc': 0.074258037,
#   'maximum': 581.7681736,
#   'minimum': 0.000150113,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '77357947-ccc5-438e-9996-95e65e1e1bce'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '78c3efe4-421c-4d30-82e4-b97ac5124993'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '7ecc2b66-8dde-4266-8832-f492f564377b'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '826677aa-8347-4494-85da-a26fe3e1e824'): {'amount': 1.591727031,
#   'loc': 0.05646066,
#   'maximum': 146.2778145,
#   'minimum': 0.001710379,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'): {'amount': 1.846715481,
#   'loc': 0.074258037,
#   'maximum': 1645.674497,
#   'minimum': 0.000424631,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'): {'amount': 1.846715481,
#   'loc': 0.074258037,
#   'maximum': 1645.674497,
#   'minimum': 0.000424631,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '887bfb8e-44de-4de0-b47d-bc49db8adec1'): {'amount': 1.746893022,
#   'loc': 0.074258037,
#   'maximum': 1556.719119,
#   'minimum': 0.000401678,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '8c52f40c-69b7-4538-8923-b371523c71f5'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9115356e-a534-4329-9ec6-d9208720241b'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9990b51b-7023-4700-bca0-1a32ef921f74'): {'amount': 1.846715481,
#   'loc': 0.074258037,
#   'maximum': 1645.674497,
#   'minimum': 0.000424631,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '99c65c6a-6871-40ba-af79-5bd6851688e4'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9af58019-22ff-4278-8f48-8e94b49aae5c'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9b00c244-fcce-4d38-922b-601a81f2ba34'): {'amount': 1.591727031,
#   'loc': 0.05646066,
#   'maximum': 146.2778145,
#   'minimum': 0.001710379,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9d0b18e8-484d-4d28-bca4-2db8023def45'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   '9fb048e8-b1c4-4b1a-b536-5467d511f75a'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'a259eb99-e741-49e6-8b3f-8985c018be28'): {'amount': 1.591727031,
#   'loc': 0.05646066,
#   'maximum': 146.2778145,
#   'minimum': 0.001710379,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'aeb3e625-906a-4993-9f02-785f8cfd1ea5'): {'amount': 1.912074609,
#   'loc': 0.05646066,
#   'maximum': 175.7173746,
#   'minimum': 0.002054606,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'b00950bc-99cb-4ee2-bbc0-5f878ea170c3'): {'amount': 1.912074609,
#   'loc': 0.05646066,
#   'maximum': 175.7173746,
#   'minimum': 0.002054606,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'b7ba3697-434d-4f47-91a1-f5b924871d92'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'b7e78e2a-dff8-49e8-b72c-c9157183860d'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'c1b91234-6f24-417b-8309-46111d09c457'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'c36f35d1-e815-4c85-8686-1a2d21264a2c'): {'amount': 0.652838878,
#   'loc': 0.074258037,
#   'maximum': 581.7681736,
#   'minimum': 0.000150113,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'ca31b010-acd3-4736-a76c-e4a900ae4809'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'cbd70647-6237-462a-9d01-d197a8b08506'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'ce53f0ea-aab2-423b-9bb5-8d7f2cada413'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'd068f3e2-b033-417b-a359-ca4f25da9731'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'd40b90a8-c469-41ec-b5ea-f80386859a82'): {'amount': 0.652838878,
#   'loc': 0.074258037,
#   'maximum': 581.7681736,
#   'minimum': 0.000150113,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'd64c693d-aa5a-40de-a250-ed9d24b90542'): {'amount': 1.591727031,
#   'loc': 0.05646066,
#   'maximum': 146.2778145,
#   'minimum': 0.001710379,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'd9945575-a965-4bf3-9cd7-584263172abd'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'dc084330-5108-4d9c-a7ed-eb3345507f13'): {'amount': 0.584142094,
#   'loc': 0.336155493,
#   'maximum': 68.58725307,
#   'minimum': 0.001758711,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'e1d913d8-214c-4957-b3e5-36ccc50f3724'): {'amount': 1.746893022,
#   'loc': 0.074258037,
#   'maximum': 1556.719119,
#   'minimum': 0.000401678,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'e1f2ab0a-6d4e-4705-9e8c-db67155d14f6'): {'amount': 1.746893022,
#   'loc': 0.074258037,
#   'maximum': 1556.719119,
#   'minimum': 0.000401678,
#   'shape': 66.11494813,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'e3edc996-b5bb-4465-b9e4-29eb368ab0e0'): {'amount': 0.392095378,
#   'loc': 0.336155493,
#   'maximum': 46.03801918,
#   'minimum': 0.001180505,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'e8c30bb3-92cc-41c8-acf3-281095e570cc'): {'amount': 0.592144041,
#   'loc': 0.336155493,
#   'maximum': 69.52680448,
#   'minimum': 0.001782803,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'f37a3611-f6a5-4141-8d16-6eac6a1e9a52'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'fd7aa71c-508c-480d-81a6-8052aad92646'): {'amount': 2.392595977,
#   'loc': 0.05646066,
#   'maximum': 219.8767148,
#   'minimum': 0.002570947,
#   'shape': 5.137727289,
#   'uncertainty type': 13},
#  ('Freshwater acidification, GLO, with uncert',
#   'fe02b51d-7a59-4015-ba12-d32da63ac7d9'): {'amount': 0.799194406,
#   'loc': 0.336155493,
#   'maximum': 93.83769727,
#   'minimum': 0.002406182,
#   'shape': 39.24918627,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '0857999c-aaf4-41f9-b3cc-5cc56909ecaa'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '1727b41d-377e-43cd-bc01-9eaba946eccb'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '18e1aef2-00e7-410d-9613-fdfb305a689e'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '226fb7e6-0ee2-4e8a-9fac-67d83b77aa75'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '2a89246a-8408-4775-a6db-7c33656f1469'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '2d4b8ec1-8d53-4e62-8a11-ebc45909b02e'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '329fc7d8-4011-4327-84e4-34ff76f0e42d'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '362acbd4-9fee-4943-9b92-4e73ef4b3387'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '3e129646-13b3-45a9-840a-c6b499f654b9'): {'amount': 4.855038443,
#   'loc': 0.000441333,
#   'maximum': 64790.34433,
#   'minimum': 7.49e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '3f512502-5e18-45f1-90a4-e22c93229ea2'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '43156184-3040-4095-9085-38d8895406cc'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '448934cb-8be4-4ae2-acdb-de9dec10459b'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '4574cd53-77cc-4540-827b-5736dda9c4d7'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '490b267b-f429-4d9a-ac79-224e37fb4d58'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '4a5a08f6-51ab-41e7-809a-13d70b509740'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '4ab486b5-7102-4a88-a7fd-3e7b42e0e2e2'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '4ba931a8-50e1-4b94-abe2-f645e93bb574'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '4d11b9d2-f8b4-413f-822f-141d7ae493d8'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '503ccbc4-8697-46e7-9a9b-beee17d4cdec'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '557da7c3-69dd-4122-a8c7-fe78f8f907a5'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '5687da3e-fa56-4ad0-81bc-a5f6d175433e'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '57c27ba7-a61a-4932-8cd5-095c88ff0245'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '6054fc06-c63a-48f2-bb80-3733834167bc'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '6a7e5863-714c-4dd4-9fbc-0d92b8f67e93'): {'amount': 4.855038443,
#   'loc': 0.000441333,
#   'maximum': 64790.34433,
#   'minimum': 7.49e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '70d467b6-115e-43c5-add2-441de9411348'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '75a4db8c-cc6c-4da5-a511-cf68acdad348'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '76b09afe-52b9-4ecc-b97a-00b49ad8ed1a'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   '7ae398c8-8532-11e0-9d78-0800200c9a66'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '7ea403ad-aba6-4f89-843f-41266477064f'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '89b48ac9-f3ea-3c38-b776-aac911237361'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '8d33cd5f-c365-44b8-bb70-a211d5bb15dd'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '91955aba-6ebc-4413-9342-f0298860b4aa'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '961ccd56-2eee-4f57-bb18-fc4362b49000'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   '9caf6b8a-03ae-478b-a6a0-d8423b0cd16a'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'a87680bc-ecde-471a-88bb-6bc7482a62cf'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'a8fea8cf-9b09-49fc-aa58-5a732494a2a0'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'ad62c648-1af8-4805-bbfb-64c6361eb9f6'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'aedea697-930a-4a0e-9e4f-b9c369aa9a33'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'b101cae3-a323-4b8a-8cc8-43d305b6e2ff'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'b1fca66f-8e83-469a-a7b5-018e14d5d545'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'b2631209-8374-431e-b7d5-56c96c6b6d79'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'b2c8d9ab-da12-445f-bf52-eeca64a96fd6'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'b3cfad3f-b7da-490b-a491-8507a1bb7c4b'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'be10dd54-eb4d-48ae-9e14-7d79ce8b170d'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'be437c78-bc3a-4ccc-bdf3-9129d143a891'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'c8791f3c-3c4a-4278-91c0-483797d14da2'): {'amount': 3.623163017,
#   'loc': 0.000441333,
#   'maximum': 48351.00323,
#   'minimum': 5.59e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'c8a80a68-83a7-4453-97f4-082ee1b60c71'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'd07a6bba-3816-4ac1-bb17-f0b99e5ee17a'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'd76b8325-e4de-4d1c-b2b8-cf0128dc941c'): {'amount': 11.08687883,
#   'loc': 0.000441333,
#   'maximum': 147954.0699,
#   'minimum': 1.71e-05,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'dc2458f6-30fc-4c71-97f6-ff4c5470bd3a'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'dcd473f2-93b3-416b-8b97-d157b6ce1fe8'): {'amount': 3.514468127,
#   'loc': 0.000441333,
#   'maximum': 46900.47314,
#   'minimum': 5.42e-06,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Freshwater eutrophication, GLO, with uncert',
#   'ec76fb5c-b402-416b-825c-53e074fe7525'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'f012d2d5-ebb4-4531-8285-0b98af3dcbd4'): 0.0,
#  ('Freshwater eutrophication, GLO, with uncert',
#   'fc0b5c85-3b49-42c2-a3fd-db7e57b696e3'): {'amount': 0.079709586,
#   'loc': 0.000441333,
#   'maximum': 1063.722071,
#   'minimum': 1.23e-07,
#   'shape': 5.889147648,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '012ee35c-c4e1-4759-9f62-e1a7a8504f8c'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '062a6faf-b1a5-4a6a-aa02-47ae3ec566a8'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '080bf4c6-fab3-4e21-88c7-20b435aa42e8'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '0a03fe20-343b-42d4-87b5-1300cfd47a7a'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '0d6e367d-0c4c-4f6d-9bff-9b370a182ff1'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '12501edd-e004-40be-bf07-01d7f4c32ea8'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '135816ab-f119-4a64-b608-a61cb788af7d'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14811cde-0ef0-4327-ad94-4ee232f7a462'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14b92328-e08d-4fac-b16a-da5dcd0e5627'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '16835899-c22f-4e78-8076-0d4d340c6f60'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '16df4fdf-06a1-4c84-bd49-b933d5bd2714'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '18636f13-f552-4136-a353-3b5a8e5f87d1'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1896b498-8d13-4f58-8c17-21fe57740158'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '19f84b2e-e6ff-4351-ba3a-8b650fc20d14'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1a01977a-d170-4ac1-86df-aae792cbeb8f'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1ae03e9f-9f0b-4f9e-8440-9c3d4f1b1868'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1b0a8570-eab4-46c2-9b67-c9b918e75676'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1c359785-3e70-4e0b-be1c-6258f9f20708'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1eaa9ea4-40b8-414a-b198-5626400372e1'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1f99f0be-f142-4a18-a7cd-209bf22218c8'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '21baa1af-e8af-425b-a127-91629f718508'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '23bce6d9-34d7-4be0-ba7d-4fd4e896e6d0'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '250de680-25a7-4a3b-93c9-a9ed44bb4e0c'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26586deb-0d0d-42b7-ae01-e6e517a743cb'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26efe47c-92a5-4dea-b4d0-eac13e418a58'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2843362e-6942-48fb-acdc-cea07d6e08cc'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2925111b-3464-4e34-9d02-b73c1c033e91'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2997b0b4-f6ec-4df0-9481-4bdab4e86507'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2aa913a6-41a4-47cd-83bd-58cc5e1b11a5'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2ffde7a9-81d0-4113-a519-3196e5886679'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3259f9e3-8108-444b-9521-de12e53f6e35'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3295a31d-855c-4ed1-ace4-e81d0a7f04c6'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '33817d31-6212-44bb-99b0-df1426ae92e5'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '35f58560-2ce4-4213-9984-616a292e63ea'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '395c7600-604a-4e1f-85df-b5f94edeb659'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3afbc2d8-1b51-4d43-87a7-e68291c1e999'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3b4db191-9634-4a01-a873-f3cb234785e4'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3cc6b9e3-fda3-4712-b5b2-df07b0b996f3'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e2da818-59cb-491a-8e4c-fa62e2a9d944'): {'amount': 0.124836367,
#   'loc': 0.30207999,
#   'maximum': 0.22,
#   'minimum': 0.0,
#   'shape': 0.230277684,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e7f1605-9451-4e53-9690-ab5318033227'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3fa694bc-8c9e-406d-b7aa-f2e50d8511b8'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '42c0b068-ba0d-42e3-9549-c35b455ab873'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4497ab6d-6666-43d1-abfd-563b45cb8cda'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4498615d-0ed6-4ca4-8a87-267f31f624b0'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '44ea6f89-8780-45b4-a80a-cfc3abcfef5f'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '45091000-d7e1-459f-bac5-38b51efb4d63'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a49c025-f03c-4eab-a0eb-b06d1a4442db'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a69ed71-6cc0-46f6-a4ab-1b9675f8315b'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b3f09d7-7681-4f2d-b967-d630dfb29068'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b6b9b76-3199-4bd0-b11d-f8f2efbeac4e'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4ce71e21-8f14-48da-b9e5-4743e5f3c0ab'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4f0baf82-3128-4d23-a722-7a75f10dc987'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4f243941-fdd0-42e9-90d4-3a5b0a352c5b'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '50b14562-ddeb-49d7-899c-dcbf9dfed004'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '56ec994a-eb96-42e8-93eb-4970e30e6362'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '59ded913-17fe-4b3e-80cb-79b97cdbef9a'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c26adb8-cd01-4177-b77c-d17dfca4d16c'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c44eadf-8f68-496b-b9ef-f94be1372c58'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5ce41517-25bb-4da6-b839-5fd0f00baff1'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5d615a38-6d0a-4f3a-8973-69b333b6e814'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5db2250f-278c-4b47-8c45-561ae9ff448d'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5dbd8205-fa09-3895-90d3-5e1d7406c179'): {'amount': 0.224587886,
#   'loc': 5.66e-16,
#   'maximum': 0.39,
#   'minimum': 0.18,
#   'shape': 2.1e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '61461094-ed15-4201-a57e-b888b508dcdd'): {'amount': 0.124836367,
#   'loc': 0.30207999,
#   'maximum': 0.22,
#   'minimum': 0.0,
#   'shape': 0.230277684,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '64f2cbe7-791b-4d4b-bd13-f0c142922738'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '67884dbf-8895-42ca-9a2a-37aef1189d3b'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69c7d771-04fc-499e-84f8-6c7b923b8ced'): {'amount': 0.224587886,
#   'loc': 5.66e-16,
#   'maximum': 0.39,
#   'minimum': 0.18,
#   'shape': 2.1e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69cdd9a1-25d8-4185-8d86-17dc1878ede1'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69dfa439-8e4e-4cae-bb0c-85a8aa8b9a73'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '6cd33048-b06a-4b9b-bf8d-b4b6b47754f9'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '6de7ded7-4f84-4652-bc6b-1207f1af012c'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '70c4c6d8-ed81-4763-ae6d-39e54ef0b1fa'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7100fd9e-c7da-43b3-877e-bce9390dc1fc'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '72745257-3534-4ca3-adfa-a2eb63f1e7d9'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '74212326-ca29-46f8-a600-4e45b0ad688e'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '77c14227-fb17-46a2-843c-130d92d28a28'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '785d44a4-2979-4ea3-8121-aa82a65ba2e5'): {'amount': 0.224587886,
#   'loc': 5.66e-16,
#   'maximum': 0.39,
#   'minimum': 0.18,
#   'shape': 2.1e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7ae398bc-8532-11e0-9d78-0800200c9a66'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7ae398bd-8532-11e0-9d78-0800200c9a66'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7ae398be-8532-11e0-9d78-0800200c9a66'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d143ee5-e848-47d0-91e8-f10f7c86963d'): {'amount': 0.224587886,
#   'loc': 5.66e-16,
#   'maximum': 0.39,
#   'minimum': 0.18,
#   'shape': 2.1e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d6baa46-6ac9-4f04-9bcb-abc382574260'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7e7d6ebb-8c9c-4ecb-b64b-23a8c2c908c4'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7ea7c8d2-d20a-4c68-ab8c-b435447833eb'): {'amount': 0.632603085,
#   'loc': 0.5978092549999998,
#   'maximum': 0.76,
#   'minimum': 0.54,
#   'uncertainty type': 5},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '83d26cf2-b841-4bad-82b8-2add507aca12'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '84f3ca3a-5ecb-49f2-883c-1897bab3b7f7'): {'amount': 0.074625861,
#   'loc': 0.074625861,
#   'maximum': 0.42,
#   'minimum': 0.02,
#   'scale': 0.13735486886164611,
#   'uncertainty type': 3},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '86d3fdb1-3b9b-4b01-a6eb-6bdab06676d7'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '871a58d9-bbbb-4cdf-bf84-dd4a90fa7c8e'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '90d8275b-9542-463f-8b33-0173708543ad'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '92f8f25e-135a-48df-b90c-c6c4547fe94d'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
#   'minimum': 0.01,
#   'shape': 1.639456974,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '956c5f83-65c8-4607-9749-147cfb9c8f70'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '97c598f0-4d1d-4f9f-906e-097347168153'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '98b723d4-3362-4b38-8b1e-1bedacfd5e27'): {'amount': 0.200590982,
#   'loc': 0.867347639,
#   'maximum': 0.52,
#   'minimum': -0.08,
#   'shape': 0.987339847,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '9a290e90-6d97-46af-8387-589f197aa868'): 0.0,
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '9db06277-b6d9-4c48-8cfb-de342e928a50'): {'amount': 0.41535659,
#   'loc': 5.8e-16,
#   'maximum': 0.5,
#   'minimum': 0.4,
#   'shape': 3.2e-15,
#   'uncertainty type': 13},
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a029c026-6970-40a0-b597-5ebd8dfbaa97'): {'amount': 0.159934864,
#   'loc': 0.585175339,
#   'maximum': 0.58,
# ...
#   'b28303de-9da9-3c1b-bf30-49b5fad9e452'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b297cf0c-23c3-34a8-9cdf-586650be58fd'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b5e65e84-a1e1-3a02-a74f-8e6a9c0b2ad6'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b77bffdd-d035-368c-a735-a37ca4640331'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b84a7e1e-2ed1-3f04-80d0-d7f5ed16245b'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b8d4fe11-af72-3603-adae-44d0524e0857'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b8e26d9b-b07b-45b7-a2dc-5320a8934416'): {'amount': 6.35e-08,
#   'loc': 0.544415251,
#   'maximum': 0.003107878,
#   'minimum': 0.0,
#   'shape': 26.09022203,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b94df422-b76f-3d10-91ef-83dc99967b51'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'b9f02930-d0e3-3144-92bf-1babde3b17d8'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'bb15f4ab-42e1-4f4a-8e48-3a3fb9d90155'): {'amount': -6.35e-05,
#   'loc': 26.09022203,
#   'maximum': 0.0,
#   'minimum': -0.003107878,
#   'shape': 0.544415251,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'bea8ee06-61e8-4770-abce-6ed950985dfe'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'beb8d1f8-7819-321d-a32d-ab3884121e7b'): {'amount': -6.35e-05,
#   'loc': 26.09022203,
#   'maximum': 0.0,
#   'minimum': -0.003107878,
#   'shape': 0.544415251,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c0f39d6f-dd5a-4465-9dee-b0c5f897d175'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c17215a3-b80a-3372-810c-ccc92b97d3ef'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c266520e-f671-3990-99dd-057fa51ebfe6'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c32bea0d-1d42-36dd-aeac-9a7b16696eba'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c39ddc68-60d8-32e9-a0ce-05125d213c0d'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c5294e60-47a2-3ba3-bd8d-12cec538bb7a'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c56bfea1-912d-468f-ba43-bef7c14c8c1e'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c6424dad-5233-328c-9752-b5a2378726be'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c7024325-1fdf-3d70-b078-a34cc49c6db6'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c76abb6e-4dff-3c0f-b3d9-80be0f80ec3e'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'c9eaca71-6924-483f-9e86-51265bc0e9ef'): {'amount': -1.14e-07,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'ca0d7b64-6044-3a7c-af04-ae23b94edb7b'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'ce9fd979-2f96-3b4f-b09a-94df06fb3feb'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd022cb79-66cc-3668-bfd6-dc2549d6179b'): {'amount': -0.000128392,
#   'loc': 11.35759719,
#   'maximum': 0.0,
#   'minimum': -0.001376656,
#   'shape': 1.16820009,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd340bcfb-77bb-34f2-8052-b598a2cdf17e'): {'amount': 1.28e-07,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd40062f6-9cad-3324-84dd-d8f194a5005d'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd4e91995-843c-380f-9b1d-e73eb87989d3'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd512585c-a3ff-3bd4-8854-3d23c14926c0'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd73cbb05-f4f8-3e7c-be7b-1226f429335b'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd78b41a7-b3f3-328f-9e55-0a9836c86c6e'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd84c58f8-bc2a-3fed-badd-2a35ec5e4c6a'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'd9c3f006-e25d-3beb-98c1-ed5cc01ce96c'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'de7f555b-1fed-4087-b06e-5fb145ca33eb'): {'amount': -1.28e-07,
#   'loc': 11.35759719,
#   'maximum': 0.0,
#   'minimum': -0.001376656,
#   'shape': 1.16820009,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'debe7510-db87-4df7-bf4c-cfb3a622edb1'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'df74eba0-aca1-3b76-982f-16bebb424870'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'df77647b-d3ea-3476-a665-4d435343ff5d'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e0065ac9-4578-3e8d-9338-fd99a299ae46'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e0241436-ad0b-40ab-90f8-db4fd79f4e8c'): {'amount': 2.53e-08,
#   'loc': 0.369189553,
#   'maximum': 0.001554149,
#   'minimum': 0.0,
#   'shape': 22.3452813,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e07f3eae-2be2-4768-bb89-11e5bf4c743e'): {'amount': 1.28e-07,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e0e6bb44-1b7b-4d85-a3f8-1ee6a1e983d4'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e273a57d-19bd-3a0e-abc7-d6e32bc320dd'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e30bc01a-26c4-33dc-90b1-2976a9dd2785'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e329aa39-56b8-3015-abd0-efba8fae94cb'): {'amount': -0.000114438,
#   'loc': 10.83226341,
#   'maximum': 0.0,
#   'minimum': -0.001132988,
#   'shape': 1.217045247,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e51e9393-0c77-3bd0-897c-1e3a4729196a'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e6bf7393-ca27-36b6-89d0-0c155afe959a'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e86c6358-1283-31b1-af5d-6bf05fc58ff8'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e8e6e8f7-373e-3381-b6cf-bb6d4ddb2d76'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'e9649289-4111-3ec4-80fd-770952c30c49'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'ea46e7e8-e9b6-31ac-be23-52f09bf73782'): {'amount': 6.35e-05,
#   'loc': 0.544415251,
#   'maximum': 0.003107878,
#   'minimum': 0.0,
#   'shape': 26.09022203,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'eba958f5-ffe1-3f4b-8f2c-8bc7b5a9b275'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'eba9b309-7926-37da-a4c5-0d4c2ef894f9'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'ed3fdab8-6123-4c08-a25b-0a74a7fa779a'): 0.0,
#  ('Water availability, human health, GLO, with uncert',
#   'f16adc98-f687-31b6-a538-af2914eacd2a'): 0.0,
#  ('Water availability, human health, GLO, with uncert',
#   'f1a90356-cac4-3eb4-8619-eabe3d45c696'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f1bc0318-5825-3ea8-b36a-53c0b602c412'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f1bdb3e1-1235-4939-a4a0-6383caa42c63'): {'amount': -1.28e-07,
#   'loc': 11.35759719,
#   'maximum': 0.0,
#   'minimum': -0.001376656,
#   'shape': 1.16820009,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f31750b0-268a-4d18-b694-8e79e91aff86'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f4ed16d1-aacb-344f-ab16-aeb44de80128'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f7baa589-bb9c-36c2-8ac2-4e23874315b5'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f835e4b9-3073-4547-ab20-ba20886fd6a3'): {'amount': 6.35e-08,
#   'loc': 0.544415251,
#   'maximum': 0.003107878,
#   'minimum': 0.0,
#   'shape': 26.09022203,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f838aec9-cb26-4597-bb6f-478cdf32e32a'): {'amount': 1.14e-07,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'f87edd21-d830-3d32-aeee-e69320033ccd'): {'amount': 0.000128392,
#   'loc': 1.16820009,
#   'maximum': 0.001376656,
#   'minimum': 0.0,
#   'shape': 11.35759719,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'fc1c42ce-a759-49fa-b987-f1ec5e503db1'): {'amount': 0.000114438,
#   'loc': 1.217045247,
#   'maximum': 0.001132988,
#   'minimum': 0.0,
#   'shape': 10.83226341,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'fe0acd60-3ddc-11dd-ae59-0050c2490048'): {'amount': 6.35e-08,
#   'loc': 0.544415251,
#   'maximum': 0.003107878,
#   'minimum': 0.0,
#   'shape': 26.09022203,
#   'uncertainty type': 13},
#  ('Water availability, human health, GLO, with uncert',
#   'feae94ff-e17a-3b3a-af20-6a50b822c273'): {'amount': -0.000128392,
#   'loc': 11.35759719,
#   'maximum': 0.0,
#   'minimum': -0.001376656,
#   'shape': 1.16820009,
#   'uncertainty type': 13}}

# %%
(len(list_error_generalized_beta),len(iw_uncert_beta_distrib)),(len(list_error_triang),len(iw_uncert_triang_distrib)),(len(list_error_normal),len(iw_uncert_normal_distrib))
# Out:
# ((550, 767), (0, 31), (0, 20))

# %% [markdown]
# Only some generalized beta distributions are errors.

# %%
list_error_generalized_beta
# Out:
# [(('Land transformation, biodiversity, GLO, with uncert',
#    '94e30f54-58ad-4496-b043-637c688e44e0'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'b28303de-9da9-3c1b-bf30-49b5fad9e452'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '92138f4d-5e83-41fb-a202-6d59c36d5231'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5be81c7a-31d9-4b79-b9e4-50e92d78a014'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '6f1e33ee-7fc0-3c9c-a9f9-408ad4a7b072'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '9348a45e-047c-4f05-9794-648e9b9dae33'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'c8c9bc86-8649-4637-a435-c2b52d5e1ddf'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '2b04a22c-28fd-309d-acf9-d349d537efbe'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'ad1dac87-cd0a-350c-8848-4f1fc289cb3a'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '71cb08fe-d3f7-3d38-8073-d94815935029'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '2aa913a6-41a4-47cd-83bd-58cc5e1b11a5'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '341e910f-3799-3a3c-82e9-0ef26c78fd07'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8c1494a5-4987-4715-aa2d-1908c495f4eb'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '29a9157e-42d5-3e71-ab26-dd76fec002d8'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '474772b5-d4f6-3da7-a081-14c84cddf81d'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '6e7c3e56-841c-5199-ddfe-000053de1cfc'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '871a58d9-bbbb-4cdf-bf84-dd4a90fa7c8e'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '4deca3ec-ae40-460b-b063-35934d4fc936'),
#   {'amount': 6.35e-05,
#    'loc': 0.544415251,
#    'maximum': 0.003107878,
#    'minimum': 0.0,
#    'shape': 26.09022203,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '26d923eb-b44e-3615-b6e0-d72e8c7639f0'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '5ce41517-25bb-4da6-b839-5fd0f00baff1'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'faa01bcb-884e-4c79-9ea2-16da6596c6a6'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '55893abb-69ff-4a33-9349-a8d37a172537'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'a19c6dec-d1ef-3dfa-8e97-6871a9a5e669'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '062a6faf-b1a5-4a6a-aa02-47ae3ec566a8'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '66f25f1d-1898-4827-bcbb-ca82f15c4d02'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c7024325-1fdf-3d70-b078-a34cc49c6db6'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '2cb441cd-8d2e-4e5c-a208-48c4fa005c41'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '220b9a7a-1ced-462b-b645-e80253e189ee'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'b84a7e1e-2ed1-3f04-80d0-d7f5ed16245b'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '34f9fc3a-0406-4a90-b85f-7df531350944'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '12b740b7-b774-336e-817f-d26ade9fff26'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'eba9b309-7926-37da-a4c5-0d4c2ef894f9'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '5cf68994-cf11-4e37-9834-1f0e1c382fa5'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '822b9d39-087b-44c5-aff9-602b748294d8'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '93c1f160-9027-469e-bbb3-32f2ca951759'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '92f8f25e-135a-48df-b90c-c6c4547fe94d'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'bd6d11e8-eb49-4664-b065-7bcf9c888053'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '9db06277-b6d9-4c48-8cfb-de342e928a50'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '585ef0b1-6194-3653-8208-2ef96fb9ef69'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '831f249e-53f2-49cf-a93c-7cee105f048e'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'e97b784a-ec09-4b1b-9f14-cc0ce9799c9e'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8c75e7ab-8ab8-41e4-b394-c166ff5b050d'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5d8950af-bf5f-3373-b75e-441c1b5d3743'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '24422b32-3046-322c-b53b-ccad50a2f4f9'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'df72bd78-cbf0-4bc8-91c3-710ea579b1d1'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'a42347d2-09f1-405e-95dd-bf6ac03765d8'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'b1720e30-2692-4a1f-8ced-b58574d2e7c6'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '2d88cf1e-7aa4-3409-bd12-5da97c133385'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'a029c026-6970-40a0-b597-5ebd8dfbaa97'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '67c40aae-d403-464d-9649-c12695e43ad8'),
#   {'amount': 6.35e-05,
#    'loc': 0.544415251,
#    'maximum': 0.003107878,
#    'minimum': 0.0,
#    'shape': 26.09022203,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '72745257-3534-4ca3-adfa-a2eb63f1e7d9'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e30bc01a-26c4-33dc-90b1-2976a9dd2785'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e07f3eae-2be2-4768-bb89-11e5bf4c743e'),
#   {'amount': 1.28e-07,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '178463a8-4cb3-4a8b-90d6-e360c6a68f38'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '4fe8d4ab-fdd1-4316-8065-deb1edb04e39'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '60e8cda5-9b44-367b-a106-b9380025d82a'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'c14ea750-4a9f-41fa-bcc1-4a1d84466f43'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'd10b390c-9d0c-4f59-b31d-3d0d70e77a35'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '91a067cc-543a-4d73-a0c0-feb1f8935756'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '61756661-69cf-31bf-ab1d-18f785e5e36b'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '2e5924bd-a303-3800-9293-e3c3f08f4daf'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '07d4460c-ae27-4717-9db9-9e0b1ea12dd5'),
#   {'amount': -27.43061409,
#    'loc': 8.74e-16,
#    'maximum': -17.86073994,
#    'minimum': -62.9329279,
#    'shape': 2.36e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'd512585c-a3ff-3bd4-8854-3d23c14926c0'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'f31750b0-268a-4d18-b694-8e79e91aff86'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'd4e91995-843c-380f-9b1d-e73eb87989d3'),
#   {'amount': -0.000114438,
#    'loc': 10.83226341,
#    'maximum': 0.0,
#    'minimum': -0.001132988,
#    'shape': 1.217045247,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '1a568858-efa8-4c2a-b46e-82b6e66b6072'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '47f98e48-4fc8-3d7d-9eec-3920e811b100'),
#   {'amount': -0.000114438,
#    'loc': 10.83226341,
#    'maximum': 0.0,
#    'minimum': -0.001132988,
#    'shape': 1.217045247,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '8d9f20e9-38f2-4a25-bb19-9da1e323fda4'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '0775d4c9-2c91-4a0d-a4a7-1c6b96e47ea4'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '12be05aa-48ad-49a8-a864-7a51ba56075b'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'ef12e210-aafe-4308-a70a-0baa89a48040'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '9df90c6b-2bac-35c1-b7fc-943f3ca23c7f'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'fa815715-eeb2-4cfc-b006-0e5877bd5932'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '77c1d221-d35c-4753-911b-0ac3dc331794'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'b1989cfb-9f7e-32fd-b93d-679cf5940c48'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '45fa090d-ec34-3e43-b374-bf56e72ad973'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '0d7c280e-9f07-48b7-bf01-5cfd0d475e1c'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '7f952328-9a9b-3e3f-9412-2fbfc9bfb8d7'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '88e8456c-dc23-4bb4-aed5-a4186a2fbf77'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '04eb0695-e67b-46e5-9516-da6bde119822'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'abc1487f-7ac2-3aed-b04d-105a47d73e16'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'c1513682-45ad-444e-afb5-27c660714e88'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'ee2631d0-c8ee-4ee9-a4a0-c1c0ff6373bd'),
#   {'amount': 0.200590982,
#    'loc': 0.867347639,
#    'maximum': 0.52,
#    'minimum': -0.08,
#    'shape': 0.987339847,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '19f7928a-99ea-4206-b957-f06834edeb1b'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'fe91efc5-25ce-4316-b0d1-43173a755777'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '4dbbc4de-4e1b-4b19-b6e4-d89f39a4dd80'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '0cab58d3-f449-48d4-94bd-ec09d19736d6'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '1494ba3b-1cbb-366d-b4af-a6038e6dd592'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '1a95203d-8fe0-44ed-9203-22d40c1bc617'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '2dace710-44ce-4074-9617-65a5f2c1a3ee'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '25beccea-63c7-3d2b-b7de-287eb4c140f2'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '3259f9e3-8108-444b-9521-de12e53f6e35'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '41f2491f-5305-3954-91b4-73397dcc1ea4'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '2e785337-a069-3d02-4c59-000033481da0'),
#   {'amount': 27.43061409,
#    'loc': 2.36e-16,
#    'maximum': 62.9329279,
#    'minimum': 17.86073994,
#    'shape': 8.74e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'feae94ff-e17a-3b3a-af20-6a50b822c273'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '4ce71e21-8f14-48da-b9e5-4743e5f3c0ab'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'de7f555b-1fed-4087-b06e-5fb145ca33eb'),
#   {'amount': -1.28e-07,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'a2a9cda7-9dd0-4a39-b422-f45298906dd8'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '6a9cb1f7-2d28-4fa5-acd0-456cc1cfd72f'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'fc1c42ce-a759-49fa-b987-f1ec5e503db1'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '37fc5b02-751d-3353-b4d4-6fac8ee07b69'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'd022cb79-66cc-3668-bfd6-dc2549d6179b'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'dae78878-37f4-4012-a9ea-62a0e9bb6720'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5e73790c-b694-35c4-a642-71bb74188377'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'b77bffdd-d035-368c-a735-a37ca4640331'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'a16ffdac-79e9-3a72-9cc2-26b926ff349f'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '200b628c-ac2c-3864-bb86-3ac8c5e442d4'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'dde38771-435a-4f90-ad87-fd944f90b437'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'cffc8ff1-63bd-40d8-8b91-13cbee6457b3'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'a487b7db-318a-46ff-8e52-2837fab777ad'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '56ec994a-eb96-42e8-93eb-4970e30e6362'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '43c326df-fae0-4e31-a1f2-5a9dcf3f2244'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'b6dcefd8-3848-4338-9c3e-fe6e91f20937'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '54b82481-32a3-4e82-bac7-1df475dbc80c'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'd73cbb05-f4f8-3e7c-be7b-1226f429335b'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '76292ccb-383a-44d2-9460-3559057aef47'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '17c78134-7968-3a3b-8bcd-2a363909e6e3'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8ca8ac08-340a-3d73-9cda-d685c4987950'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'fe0acd60-3ddc-11dd-ae59-0050c2490048'),
#   {'amount': 6.35e-08,
#    'loc': 0.544415251,
#    'maximum': 0.003107878,
#    'minimum': 0.0,
#    'shape': 26.09022203,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '8f5c8cb3-dccd-45da-9f1f-d1c61cd789c3'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '080bf4c6-fab3-4e21-88c7-20b435aa42e8'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '9ff8ff07-805b-3902-a5d3-a7373eb706e8'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '94506e78-584b-3ad0-bd8a-8f7b2a2508e6'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '94ff3932-5a6d-389c-bb65-c3a348f9f1b2'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '1eaa9ea4-40b8-414a-b198-5626400372e1'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'df74eba0-aca1-3b76-982f-16bebb424870'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'ccc8855c-0628-4741-afe7-1c79d463fadf'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '31e4e26b-a997-4969-963d-243699aca3a8'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '8c81249c-0541-4b04-812e-d1578a35c7f1'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '90a5a447-af6f-421a-8201-011f07ad1150'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '67b7362f-588a-492d-a060-fa0a50856668'),
#   {'amount': 1.14e-07,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '9f10b83a-5b75-48dd-a103-2d27a2c8a6cb'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '8519773f-80c3-4982-b871-170dad258d69'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '59357070-8888-3f64-b9a7-1ea875b33e42'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '14811cde-0ef0-4327-ad94-4ee232f7a462'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '4b6b9b76-3199-4bd0-b11d-f8f2efbeac4e'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'b8e26d9b-b07b-45b7-a2dc-5320a8934416'),
#   {'amount': 6.35e-08,
#    'loc': 0.544415251,
#    'maximum': 0.003107878,
#    'minimum': 0.0,
#    'shape': 26.09022203,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '19f84b2e-e6ff-4351-ba3a-8b650fc20d14'),
#   {'amount': 0.200590982,
#    'loc': 0.867347639,
#    'maximum': 0.52,
#    'minimum': -0.08,
#    'shape': 0.987339847,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'e717f3cc-ac70-4c9b-be56-1614239b917e'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'aca1714f-0040-4a65-a73a-0e38aa9f50f4'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '4ee18a71-8635-4a40-af0d-79c01d58077d'),
#   {'amount': -1.28e-07,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '96775c4c-b80d-3cae-8b4e-0eb508071b37'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '2843362e-6942-48fb-acdc-cea07d6e08cc'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '96ad8bf8-e303-4034-a27c-631b5115fa4c'),
#   {'amount': 6.35e-08,
#    'loc': 0.544415251,
#    'maximum': 0.003107878,
#    'minimum': 0.0,
#    'shape': 26.09022203,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '48f50b54-6156-418c-b4be-d14558be12c8'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '0817641a-ddba-3916-9f67-85ac42fc9529'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8715a2b5-92a4-3377-8293-7b03c4094cc7'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8f6a3319-0f5c-3c12-9b29-b7b1ae510368'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c6424dad-5233-328c-9752-b5a2378726be'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '2f0c7a7b-a356-32e7-a4bc-8b7659cd280e'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '0a03fe20-343b-42d4-87b5-1300cfd47a7a'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '4858a358-5a21-3a3c-a0bb-8db58c91f6d1'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '14ce1e7c-c545-3acc-aedb-3c75484dc03f'),
#   {'amount': -0.000114438,
#    'loc': 10.83226341,
#    'maximum': 0.0,
#    'minimum': -0.001132988,
#    'shape': 1.217045247,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '86d3fdb1-3b9b-4b01-a6eb-6bdab06676d7'),
#   {'amount': 0.200590982,
#    'loc': 0.867347639,
#    'maximum': 0.52,
#    'minimum': -0.08,
#    'shape': 0.987339847,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'd1707523-ac5e-4145-9676-386da2a30a7c'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'ba94eeb5-4b68-4848-a86e-71a9f3b70a4c'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'a99a8eaf-2f2c-42c6-b6ce-d5686a9ca249'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '60202f55-1d85-4fda-81d7-e6376a74f500'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '3e4d9e9e-6556-11dd-ad8b-0800200c9a66'),
#   {'amount': 1.14e-07,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '577f7291-6e3b-4050-9239-f34e2aca0cf1'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '67055318-bad9-420f-ae31-9ba54456518d'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Marine eutrophication, GLO, with uncert',
#    '2e493ad7-ff7f-47b8-9966-1d67e0323386'),
#   {'amount': 0.192220644,
#    'loc': 0.952527552,
#    'maximum': 0.931170987,
#    'minimum': 0.00507465,
#    'shape': 3.761077367,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '53d423d2-6313-3983-bd74-6dbf0efa793d'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'aa784c1b-0d0b-4c69-b631-b045d6ee61af'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e86c6358-1283-31b1-af5d-6bf05fc58ff8'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'f84b2b33-df49-45d4-8949-d5ab8b800656'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '75178d65-a01b-4108-8871-6b8c78a3ffe2'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '6298894f-6ebb-3b82-aa4c-e5fa3c332a09'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '31e3aeb5-dae5-4a33-8038-a616442906c3'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '66e3f915-d5e1-3df9-8e35-3c2cbb83d132'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '26586deb-0d0d-42b7-ae01-e6e517a743cb'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'e6dd1a4b-0a12-4b46-9245-6ec9b63c8255'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '2141caeb-e469-376b-8f78-deb8dded9c7e'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '3b3a4648-20e6-3efb-adae-ddc7cfaf3c8b'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'bb15f4ab-42e1-4f4a-8e48-3a3fb9d90155'),
#   {'amount': -6.35e-05,
#    'loc': 26.09022203,
#    'maximum': 0.0,
#    'minimum': -0.003107878,
#    'shape': 0.544415251,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '99955f8f-0222-3094-af2c-47eeec843957'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '5c26adb8-cd01-4177-b77c-d17dfca4d16c'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '3b4db191-9634-4a01-a873-f3cb234785e4'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '525b8812-77d3-4248-aa8e-805910443a23'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '64f910df-cc09-359b-aff3-e90a04c55cc4'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '4e48b83e-af69-429f-8941-2332e7ddc62a'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'a65f41ac-79d1-373e-8212-e030d7a2290e'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '631d9552-1190-4edf-abc9-319139c90bd4'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '59df4945-6ee2-4ea6-9ef7-36c4f4b478f6'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '8db6a887-3429-371c-8b04-a0f39b44ca7c'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e6bf7393-ca27-36b6-89d0-0c155afe959a'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e0e6bb44-1b7b-4d85-a3f8-1ee6a1e983d4'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '57196c65-5805-32ae-888e-bde1d00dd671'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'f501d85b-c98a-4319-b687-8a1b4c3ec32b'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '322b3ced-400e-431f-94cf-d72afb030907'),
# ...
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '73cba245-5969-4076-8490-75a236073196'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '10e7a3bc-9edc-322b-b3eb-0ca651428c2c'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'a6888cde-b33b-4bec-9e07-c6f3e6932f24'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'b79e26a0-88db-441f-b79b-508506e81b93'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '121b0f77-c14f-393e-8b68-30b46e1a426c'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '975543fa-3eed-4b0c-b87b-50f26630fe89'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'd585d599-05f1-47ff-8c41-790f51830b9b'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '99801a43-d476-4055-8d97-fb7c4ae173d4'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '4a1ae352-5361-380b-9bad-a1680e9658fe'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '8f516f52-4ecc-46c6-9029-65de3f05eea4'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'a4c4b2e8-7611-4690-b00f-80789d4eb9fe'),
#   {'amount': 0.159934864,
#    'loc': 0.585175339,
#    'maximum': 0.58,
#    'minimum': 0.01,
#    'shape': 1.639456974,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c76abb6e-4dff-3c0f-b3d9-80be0f80ec3e'),
#   {'amount': -0.000114438,
#    'loc': 10.83226341,
#    'maximum': 0.0,
#    'minimum': -0.001132988,
#    'shape': 1.217045247,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '7a4ce745-2cc7-3746-a9c9-fa54e4b5818c'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '55beee8d-d04e-4307-bb0e-4e113dc07ee7'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '6e9312ec-1e02-4232-9589-0746bc67d4e6'),
#   {'amount': -6.35e-08,
#    'loc': 26.09022203,
#    'maximum': 0.0,
#    'minimum': -0.003107878,
#    'shape': 0.544415251,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c32bea0d-1d42-36dd-aeac-9a7b16696eba'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    'b0828a29-0261-4a12-a5d3-9e72c7e89619'),
#   {'amount': 0.41535659,
#    'loc': 5.8e-16,
#    'maximum': 0.5,
#    'minimum': 0.4,
#    'shape': 3.2e-15,
#    'uncertainty type': 13}),
#  (('Land occupation, biodiversity, GLO, with uncert',
#    '785d44a4-2979-4ea3-8121-aa82a65ba2e5'),
#   {'amount': 0.224587886,
#    'loc': 5.66e-16,
#    'maximum': 0.39,
#    'minimum': 0.18,
#    'shape': 2.1e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'c3eff967-20d8-4bcd-bd26-2dc2592a37b9'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '3abea18f-cd91-4106-b23d-093c49427525'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '09a69d95-307e-4332-a566-1ce37f032853'),
#   {'amount': 1.14e-07,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '22c11859-a872-43da-84ee-bd7423a50f5e'),
#   {'amount': 2.53e-05,
#    'loc': 0.369189553,
#    'maximum': 0.001554149,
#    'minimum': 0.0,
#    'shape': 22.3452813,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'fcb77a5a-6882-4aeb-82a9-ba57688d2224'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'e8e6e8f7-373e-3381-b6cf-bb6d4ddb2d76'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'f1bc0318-5825-3ea8-b36a-53c0b602c412'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '1ba56136-54c1-3840-ab0c-34f1e333412c'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '9af35f20-e8f1-4e39-8241-f3e76741dc78'),
#   {'amount': -12.86664312,
#    'loc': 1.73e-15,
#    'maximum': -8.310179922,
#    'minimum': -41.67505986,
#    'shape': 2.73e-16,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5e37f4c5-3ad2-377e-87b7-46e80144b3c2'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5f6ecee0-a80d-3172-8c35-d3258079891b'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '65e587ee-924c-351b-a6ea-f46547c660ca'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'ae1e393b-8ec0-3060-b98c-945b00f012c1'),
#   {'amount': -0.000114438,
#    'loc': 10.83226341,
#    'maximum': 0.0,
#    'minimum': -0.001132988,
#    'shape': 1.217045247,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '6e694082-a3be-3aa5-a2ce-0ff3f1d6b869'),
#   {'amount': -0.000128392,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '1ba33265-7100-47b7-b9ed-1f1a74fbb141'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c0f39d6f-dd5a-4465-9dee-b0c5f897d175'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '6e02ccfc-9eb5-4a51-be9a-870c1087c833'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '295e6c24-7c10-4118-a330-0672382000d7'),
#   {'amount': -1.28e-07,
#    'loc': 11.35759719,
#    'maximum': 0.0,
#    'minimum': -0.001376656,
#    'shape': 1.16820009,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '433b7ce7-5c2d-41c3-80ef-ead7f45c8699'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '9c369e6e-909b-3828-80eb-97cb53c9fb13'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'fbe76292-b1ff-4efe-8ac6-3a36c4f3c900'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'b5d37ef1-0d36-4c00-8a38-54bbdc5e1eda'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    'c5294e60-47a2-3ba3-bd8d-12cec538bb7a'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5261c4f4-4abf-3ac2-873a-183e9956e671'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '5ef54da5-e7c2-3ac7-a01c-45725d131111'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'c0143eba-3daf-44ad-8d34-6e1d34128ace'),
#   {'amount': -27.43061409,
#    'loc': 8.74e-16,
#    'maximum': -17.86073994,
#    'minimum': -62.9329279,
#    'shape': 2.36e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'fdda4f8e-b620-4df6-92a9-101a251d2f42'),
#   {'amount': 27.43061409,
#    'loc': 2.36e-16,
#    'maximum': 62.9329279,
#    'minimum': 17.86073994,
#    'shape': 8.74e-16,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '17a5a406-333f-4b9e-8852-c2de50bc9585'),
#   {'amount': -23.08479162,
#    'loc': 1.28164767,
#    'maximum': 0.0,
#    'minimum': -62.46007511,
#    'shape': 0.751399527,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '1acb026e-9de6-48fe-9e0d-be4d24125bbc'),
#   {'amount': 0.000128392,
#    'loc': 1.16820009,
#    'maximum': 0.001376656,
#    'minimum': 0.0,
#    'shape': 11.35759719,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'de94ed71-1e83-40ad-9916-6b7c16d55a6d'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '37683746-5ef6-352c-bb22-7d6bacc6766f'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '3aa37a9b-98ad-42b0-b7c9-bf472c9a2aa3'),
#   {'amount': -168.8913863,
#    'loc': 1.03e-14,
#    'maximum': -166.2035984,
#    'minimum': -183.7061033,
#    'shape': 1.88e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '786699f7-8069-49e4-a6e6-dffed3c32314'),
#   {'amount': 37.34469997,
#    'loc': 0.188369003,
#    'maximum': 91.41197914,
#    'minimum': 0.493290004,
#    'shape': 0.27636933,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '565414ae-fff7-4f41-9668-a5a7d12874a9'),
#   {'amount': 168.8913863,
#    'loc': 1.88e-15,
#    'maximum': 183.7061033,
#    'minimum': 166.2035984,
#    'shape': 1.03e-14,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '7381c88b-dc3f-4aff-9ae7-261b8216fac2'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '12604ba6-b7a1-4036-885c-72704b029906'),
#   {'amount': 1.14e-07,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '3f8e24d7-3d44-4a47-870f-9e3e74decca4'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '3f9dea81-3fba-46b9-83d5-23ffd5bae744'),
#   {'amount': -37.34469997,
#    'loc': 0.27636933,
#    'maximum': -0.493290004,
#    'minimum': -91.41197914,
#    'shape': 0.188369003,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '891b2f36-c1cb-495a-9f27-be7b583eaf1b'),
#   {'amount': 253.2820882,
#    'loc': 0.224561911,
#    'maximum': 315.786837,
#    'minimum': 32.06385025,
#    'shape': 0.063449497,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'ea3bc981-8a35-40e1-82bd-33a12820f98c'),
#   {'amount': 12.86664312,
#    'loc': 2.73e-16,
#    'maximum': 41.67505986,
#    'minimum': 8.310179922,
#    'shape': 1.73e-15,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    'e4d65952-4845-473f-bdc8-fb40c20ac3a4'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '0a89160c-168b-3315-a7f7-5543bc60cedf'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13}),
#  (('Land transformation, biodiversity, GLO, with uncert',
#    '4b420f19-0421-461e-a0b6-7efbf580089b'),
#   {'amount': -253.2820882,
#    'loc': 0.063449497,
#    'maximum': -32.06385025,
#    'minimum': -315.786837,
#    'shape': 0.224561911,
#    'uncertainty type': 13}),
#  (('Water availability, human health, GLO, with uncert',
#    '882c52b9-814b-3acf-9940-c3c39cc271b7'),
#   {'amount': 0.000114438,
#    'loc': 1.217045247,
#    'maximum': 0.001132988,
#    'minimum': 0.0,
#    'shape': 10.83226341,
#    'uncertainty type': 13})]

# %%
ic_errors_all=[error[0][0] for error in list_error_generalized_beta]
ic_errors=set(ic_errors_all)
ic_errors
# Out:
# {'Land occupation, biodiversity, GLO, with uncert',
#  'Land transformation, biodiversity, GLO, with uncert',
#  'Marine eutrophication, GLO, with uncert',
#  'Water availability, human health, GLO, with uncert'}

# %%
cf_errors_all=[error[0] for error in list_error_generalized_beta]
cf_errors_all
# Out:
# [('Land transformation, biodiversity, GLO, with uncert',
#   '94e30f54-58ad-4496-b043-637c688e44e0'),
#  ('Water availability, human health, GLO, with uncert',
#   'b28303de-9da9-3c1b-bf30-49b5fad9e452'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '92138f4d-5e83-41fb-a202-6d59c36d5231'),
#  ('Water availability, human health, GLO, with uncert',
#   '5be81c7a-31d9-4b79-b9e4-50e92d78a014'),
#  ('Water availability, human health, GLO, with uncert',
#   '6f1e33ee-7fc0-3c9c-a9f9-408ad4a7b072'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9348a45e-047c-4f05-9794-648e9b9dae33'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c8c9bc86-8649-4637-a435-c2b52d5e1ddf'),
#  ('Water availability, human health, GLO, with uncert',
#   '2b04a22c-28fd-309d-acf9-d349d537efbe'),
#  ('Water availability, human health, GLO, with uncert',
#   'ad1dac87-cd0a-350c-8848-4f1fc289cb3a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'),
#  ('Water availability, human health, GLO, with uncert',
#   '71cb08fe-d3f7-3d38-8073-d94815935029'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2aa913a6-41a4-47cd-83bd-58cc5e1b11a5'),
#  ('Water availability, human health, GLO, with uncert',
#   '341e910f-3799-3a3c-82e9-0ef26c78fd07'),
#  ('Water availability, human health, GLO, with uncert',
#   '8c1494a5-4987-4715-aa2d-1908c495f4eb'),
#  ('Water availability, human health, GLO, with uncert',
#   '29a9157e-42d5-3e71-ab26-dd76fec002d8'),
#  ('Water availability, human health, GLO, with uncert',
#   '474772b5-d4f6-3da7-a081-14c84cddf81d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6e7c3e56-841c-5199-ddfe-000053de1cfc'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '871a58d9-bbbb-4cdf-bf84-dd4a90fa7c8e'),
#  ('Water availability, human health, GLO, with uncert',
#   '4deca3ec-ae40-460b-b063-35934d4fc936'),
#  ('Water availability, human health, GLO, with uncert',
#   '26d923eb-b44e-3615-b6e0-d72e8c7639f0'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5ce41517-25bb-4da6-b839-5fd0f00baff1'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'faa01bcb-884e-4c79-9ea2-16da6596c6a6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55893abb-69ff-4a33-9349-a8d37a172537'),
#  ('Water availability, human health, GLO, with uncert',
#   'a19c6dec-d1ef-3dfa-8e97-6871a9a5e669'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '062a6faf-b1a5-4a6a-aa02-47ae3ec566a8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '66f25f1d-1898-4827-bcbb-ca82f15c4d02'),
#  ('Water availability, human health, GLO, with uncert',
#   'c7024325-1fdf-3d70-b078-a34cc49c6db6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2cb441cd-8d2e-4e5c-a208-48c4fa005c41'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '220b9a7a-1ced-462b-b645-e80253e189ee'),
#  ('Water availability, human health, GLO, with uncert',
#   'b84a7e1e-2ed1-3f04-80d0-d7f5ed16245b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '34f9fc3a-0406-4a90-b85f-7df531350944'),
#  ('Water availability, human health, GLO, with uncert',
#   '12b740b7-b774-336e-817f-d26ade9fff26'),
#  ('Water availability, human health, GLO, with uncert',
#   'eba9b309-7926-37da-a4c5-0d4c2ef894f9'),
#  ('Water availability, human health, GLO, with uncert',
#   'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5cf68994-cf11-4e37-9834-1f0e1c382fa5'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '822b9d39-087b-44c5-aff9-602b748294d8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '93c1f160-9027-469e-bbb3-32f2ca951759'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '92f8f25e-135a-48df-b90c-c6c4547fe94d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bd6d11e8-eb49-4664-b065-7bcf9c888053'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '9db06277-b6d9-4c48-8cfb-de342e928a50'),
#  ('Water availability, human health, GLO, with uncert',
#   '585ef0b1-6194-3653-8208-2ef96fb9ef69'),
#  ('Water availability, human health, GLO, with uncert',
#   '831f249e-53f2-49cf-a93c-7cee105f048e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e97b784a-ec09-4b1b-9f14-cc0ce9799c9e'),
#  ('Water availability, human health, GLO, with uncert',
#   '8c75e7ab-8ab8-41e4-b394-c166ff5b050d'),
#  ('Water availability, human health, GLO, with uncert',
#   '5d8950af-bf5f-3373-b75e-441c1b5d3743'),
#  ('Water availability, human health, GLO, with uncert',
#   '24422b32-3046-322c-b53b-ccad50a2f4f9'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'df72bd78-cbf0-4bc8-91c3-710ea579b1d1'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a42347d2-09f1-405e-95dd-bf6ac03765d8'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b1720e30-2692-4a1f-8ced-b58574d2e7c6'),
#  ('Water availability, human health, GLO, with uncert',
#   '2d88cf1e-7aa4-3409-bd12-5da97c133385'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a029c026-6970-40a0-b597-5ebd8dfbaa97'),
#  ('Water availability, human health, GLO, with uncert',
#   '67c40aae-d403-464d-9649-c12695e43ad8'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '72745257-3534-4ca3-adfa-a2eb63f1e7d9'),
#  ('Water availability, human health, GLO, with uncert',
#   'e30bc01a-26c4-33dc-90b1-2976a9dd2785'),
#  ('Water availability, human health, GLO, with uncert',
#   'e07f3eae-2be2-4768-bb89-11e5bf4c743e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '178463a8-4cb3-4a8b-90d6-e360c6a68f38'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4fe8d4ab-fdd1-4316-8065-deb1edb04e39'),
#  ('Water availability, human health, GLO, with uncert',
#   '60e8cda5-9b44-367b-a106-b9380025d82a'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c14ea750-4a9f-41fa-bcc1-4a1d84466f43'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd10b390c-9d0c-4f59-b31d-3d0d70e77a35'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '91a067cc-543a-4d73-a0c0-feb1f8935756'),
#  ('Water availability, human health, GLO, with uncert',
#   '61756661-69cf-31bf-ab1d-18f785e5e36b'),
#  ('Water availability, human health, GLO, with uncert',
#   '2e5924bd-a303-3800-9293-e3c3f08f4daf'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '07d4460c-ae27-4717-9db9-9e0b1ea12dd5'),
#  ('Water availability, human health, GLO, with uncert',
#   'd512585c-a3ff-3bd4-8854-3d23c14926c0'),
#  ('Water availability, human health, GLO, with uncert',
#   'f31750b0-268a-4d18-b694-8e79e91aff86'),
#  ('Water availability, human health, GLO, with uncert',
#   'd4e91995-843c-380f-9b1d-e73eb87989d3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1a568858-efa8-4c2a-b46e-82b6e66b6072'),
#  ('Water availability, human health, GLO, with uncert',
#   '47f98e48-4fc8-3d7d-9eec-3920e811b100'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8d9f20e9-38f2-4a25-bb19-9da1e323fda4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0775d4c9-2c91-4a0d-a4a7-1c6b96e47ea4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '12be05aa-48ad-49a8-a864-7a51ba56075b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ef12e210-aafe-4308-a70a-0baa89a48040'),
#  ('Water availability, human health, GLO, with uncert',
#   '9df90c6b-2bac-35c1-b7fc-943f3ca23c7f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa815715-eeb2-4cfc-b006-0e5877bd5932'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '77c1d221-d35c-4753-911b-0ac3dc331794'),
#  ('Water availability, human health, GLO, with uncert',
#   'b1989cfb-9f7e-32fd-b93d-679cf5940c48'),
#  ('Water availability, human health, GLO, with uncert',
#   '45fa090d-ec34-3e43-b374-bf56e72ad973'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0d7c280e-9f07-48b7-bf01-5cfd0d475e1c'),
#  ('Water availability, human health, GLO, with uncert',
#   '7f952328-9a9b-3e3f-9412-2fbfc9bfb8d7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '88e8456c-dc23-4bb4-aed5-a4186a2fbf77'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '04eb0695-e67b-46e5-9516-da6bde119822'),
#  ('Water availability, human health, GLO, with uncert',
#   'abc1487f-7ac2-3aed-b04d-105a47d73e16'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c1513682-45ad-444e-afb5-27c660714e88'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ee2631d0-c8ee-4ee9-a4a0-c1c0ff6373bd'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '19f7928a-99ea-4206-b957-f06834edeb1b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fe91efc5-25ce-4316-b0d1-43173a755777'),
#  ('Water availability, human health, GLO, with uncert',
#   '4dbbc4de-4e1b-4b19-b6e4-d89f39a4dd80'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0cab58d3-f449-48d4-94bd-ec09d19736d6'),
#  ('Water availability, human health, GLO, with uncert',
#   '1494ba3b-1cbb-366d-b4af-a6038e6dd592'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1a95203d-8fe0-44ed-9203-22d40c1bc617'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2dace710-44ce-4074-9617-65a5f2c1a3ee'),
#  ('Water availability, human health, GLO, with uncert',
#   '25beccea-63c7-3d2b-b7de-287eb4c140f2'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3259f9e3-8108-444b-9521-de12e53f6e35'),
#  ('Water availability, human health, GLO, with uncert',
#   '41f2491f-5305-3954-91b4-73397dcc1ea4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e785337-a069-3d02-4c59-000033481da0'),
#  ('Water availability, human health, GLO, with uncert',
#   'feae94ff-e17a-3b3a-af20-6a50b822c273'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4ce71e21-8f14-48da-b9e5-4743e5f3c0ab'),
#  ('Water availability, human health, GLO, with uncert',
#   'de7f555b-1fed-4087-b06e-5fb145ca33eb'),
#  ('Water availability, human health, GLO, with uncert',
#   'a2a9cda7-9dd0-4a39-b422-f45298906dd8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6a9cb1f7-2d28-4fa5-acd0-456cc1cfd72f'),
#  ('Water availability, human health, GLO, with uncert',
#   'fc1c42ce-a759-49fa-b987-f1ec5e503db1'),
#  ('Water availability, human health, GLO, with uncert',
#   '37fc5b02-751d-3353-b4d4-6fac8ee07b69'),
#  ('Water availability, human health, GLO, with uncert',
#   'd022cb79-66cc-3668-bfd6-dc2549d6179b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'dae78878-37f4-4012-a9ea-62a0e9bb6720'),
#  ('Water availability, human health, GLO, with uncert',
#   '5e73790c-b694-35c4-a642-71bb74188377'),
#  ('Water availability, human health, GLO, with uncert',
#   'b77bffdd-d035-368c-a735-a37ca4640331'),
#  ('Water availability, human health, GLO, with uncert',
#   'a16ffdac-79e9-3a72-9cc2-26b926ff349f'),
#  ('Water availability, human health, GLO, with uncert',
#   '200b628c-ac2c-3864-bb86-3ac8c5e442d4'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'dde38771-435a-4f90-ad87-fd944f90b437'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cffc8ff1-63bd-40d8-8b91-13cbee6457b3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a487b7db-318a-46ff-8e52-2837fab777ad'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '56ec994a-eb96-42e8-93eb-4970e30e6362'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43c326df-fae0-4e31-a1f2-5a9dcf3f2244'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b6dcefd8-3848-4338-9c3e-fe6e91f20937'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '54b82481-32a3-4e82-bac7-1df475dbc80c'),
#  ('Water availability, human health, GLO, with uncert',
#   'd73cbb05-f4f8-3e7c-be7b-1226f429335b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '76292ccb-383a-44d2-9460-3559057aef47'),
#  ('Water availability, human health, GLO, with uncert',
#   '17c78134-7968-3a3b-8bcd-2a363909e6e3'),
#  ('Water availability, human health, GLO, with uncert',
#   '8ca8ac08-340a-3d73-9cda-d685c4987950'),
#  ('Water availability, human health, GLO, with uncert',
#   'fe0acd60-3ddc-11dd-ae59-0050c2490048'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8f5c8cb3-dccd-45da-9f1f-d1c61cd789c3'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '080bf4c6-fab3-4e21-88c7-20b435aa42e8'),
#  ('Water availability, human health, GLO, with uncert',
#   '9ff8ff07-805b-3902-a5d3-a7373eb706e8'),
#  ('Water availability, human health, GLO, with uncert',
#   '94506e78-584b-3ad0-bd8a-8f7b2a2508e6'),
#  ('Water availability, human health, GLO, with uncert',
#   '94ff3932-5a6d-389c-bb65-c3a348f9f1b2'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1eaa9ea4-40b8-414a-b198-5626400372e1'),
#  ('Water availability, human health, GLO, with uncert',
#   'df74eba0-aca1-3b76-982f-16bebb424870'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ccc8855c-0628-4741-afe7-1c79d463fadf'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '31e4e26b-a997-4969-963d-243699aca3a8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8c81249c-0541-4b04-812e-d1578a35c7f1'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '90a5a447-af6f-421a-8201-011f07ad1150'),
#  ('Water availability, human health, GLO, with uncert',
#   '67b7362f-588a-492d-a060-fa0a50856668'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9f10b83a-5b75-48dd-a103-2d27a2c8a6cb'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8519773f-80c3-4982-b871-170dad258d69'),
#  ('Water availability, human health, GLO, with uncert',
#   '59357070-8888-3f64-b9a7-1ea875b33e42'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14811cde-0ef0-4327-ad94-4ee232f7a462'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b6b9b76-3199-4bd0-b11d-f8f2efbeac4e'),
#  ('Water availability, human health, GLO, with uncert',
#   'b8e26d9b-b07b-45b7-a2dc-5320a8934416'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '19f84b2e-e6ff-4351-ba3a-8b650fc20d14'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e717f3cc-ac70-4c9b-be56-1614239b917e'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'aca1714f-0040-4a65-a73a-0e38aa9f50f4'),
#  ('Water availability, human health, GLO, with uncert',
#   '4ee18a71-8635-4a40-af0d-79c01d58077d'),
#  ('Water availability, human health, GLO, with uncert',
#   '96775c4c-b80d-3cae-8b4e-0eb508071b37'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2843362e-6942-48fb-acdc-cea07d6e08cc'),
#  ('Water availability, human health, GLO, with uncert',
#   '96ad8bf8-e303-4034-a27c-631b5115fa4c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '48f50b54-6156-418c-b4be-d14558be12c8'),
#  ('Water availability, human health, GLO, with uncert',
#   '0817641a-ddba-3916-9f67-85ac42fc9529'),
#  ('Water availability, human health, GLO, with uncert',
#   '8715a2b5-92a4-3377-8293-7b03c4094cc7'),
#  ('Water availability, human health, GLO, with uncert',
#   '8f6a3319-0f5c-3c12-9b29-b7b1ae510368'),
#  ('Water availability, human health, GLO, with uncert',
#   'c6424dad-5233-328c-9752-b5a2378726be'),
#  ('Water availability, human health, GLO, with uncert',
#   '2f0c7a7b-a356-32e7-a4bc-8b7659cd280e'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '0a03fe20-343b-42d4-87b5-1300cfd47a7a'),
#  ('Water availability, human health, GLO, with uncert',
#   '4858a358-5a21-3a3c-a0bb-8db58c91f6d1'),
#  ('Water availability, human health, GLO, with uncert',
#   '14ce1e7c-c545-3acc-aedb-3c75484dc03f'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '86d3fdb1-3b9b-4b01-a6eb-6bdab06676d7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd1707523-ac5e-4145-9676-386da2a30a7c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ba94eeb5-4b68-4848-a86e-71a9f3b70a4c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a99a8eaf-2f2c-42c6-b6ce-d5686a9ca249'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '60202f55-1d85-4fda-81d7-e6376a74f500'),
#  ('Water availability, human health, GLO, with uncert',
#   '3e4d9e9e-6556-11dd-ad8b-0800200c9a66'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '577f7291-6e3b-4050-9239-f34e2aca0cf1'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '67055318-bad9-420f-ae31-9ba54456518d'),
#  ('Marine eutrophication, GLO, with uncert',
#   '2e493ad7-ff7f-47b8-9966-1d67e0323386'),
#  ('Water availability, human health, GLO, with uncert',
#   '53d423d2-6313-3983-bd74-6dbf0efa793d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'aa784c1b-0d0b-4c69-b631-b045d6ee61af'),
#  ('Water availability, human health, GLO, with uncert',
#   'e86c6358-1283-31b1-af5d-6bf05fc58ff8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f84b2b33-df49-45d4-8949-d5ab8b800656'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '75178d65-a01b-4108-8871-6b8c78a3ffe2'),
#  ('Water availability, human health, GLO, with uncert',
#   '6298894f-6ebb-3b82-aa4c-e5fa3c332a09'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '31e3aeb5-dae5-4a33-8038-a616442906c3'),
#  ('Water availability, human health, GLO, with uncert',
#   '66e3f915-d5e1-3df9-8e35-3c2cbb83d132'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26586deb-0d0d-42b7-ae01-e6e517a743cb'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e6dd1a4b-0a12-4b46-9245-6ec9b63c8255'),
#  ('Water availability, human health, GLO, with uncert',
#   '2141caeb-e469-376b-8f78-deb8dded9c7e'),
#  ('Water availability, human health, GLO, with uncert',
#   '3b3a4648-20e6-3efb-adae-ddc7cfaf3c8b'),
#  ('Water availability, human health, GLO, with uncert',
#   'bb15f4ab-42e1-4f4a-8e48-3a3fb9d90155'),
#  ('Water availability, human health, GLO, with uncert',
#   '99955f8f-0222-3094-af2c-47eeec843957'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c26adb8-cd01-4177-b77c-d17dfca4d16c'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3b4db191-9634-4a01-a873-f3cb234785e4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '525b8812-77d3-4248-aa8e-805910443a23'),
#  ('Water availability, human health, GLO, with uncert',
#   '64f910df-cc09-359b-aff3-e90a04c55cc4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4e48b83e-af69-429f-8941-2332e7ddc62a'),
#  ('Water availability, human health, GLO, with uncert',
#   'a65f41ac-79d1-373e-8212-e030d7a2290e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '631d9552-1190-4edf-abc9-319139c90bd4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '59df4945-6ee2-4ea6-9ef7-36c4f4b478f6'),
#  ('Water availability, human health, GLO, with uncert',
#   '8db6a887-3429-371c-8b04-a0f39b44ca7c'),
#  ('Water availability, human health, GLO, with uncert',
#   'e6bf7393-ca27-36b6-89d0-0c155afe959a'),
#  ('Water availability, human health, GLO, with uncert',
#   'e0e6bb44-1b7b-4d85-a3f8-1ee6a1e983d4'),
#  ('Water availability, human health, GLO, with uncert',
#   '57196c65-5805-32ae-888e-bde1d00dd671'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f501d85b-c98a-4319-b687-8a1b4c3ec32b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '322b3ced-400e-431f-94cf-d72afb030907'),
#  ('Marine eutrophication, GLO, with uncert',
#   '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '20bfd418-5b2e-4c9c-ae57-cf7ebd573c2a'),
#  ('Water availability, human health, GLO, with uncert',
#   '41d2ebdf-efb6-372f-97bb-76f0ccf21e92'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd73b27a2-81bd-4264-baa5-ce4aca3545be'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa288b80-6ef1-4e80-b534-5c2e5c492fd8'),
#  ('Water availability, human health, GLO, with uncert',
#   '191319b7-f72f-3f3a-b2cd-56ea835f9c35'),
#  ('Water availability, human health, GLO, with uncert',
#   '5a19056b-6d15-3a0c-bd00-d184e991d3ab'),
#  ('Water availability, human health, GLO, with uncert',
#   '3c27fe4e-eec8-4bea-91cd-afc0b0ab138f'),
#  ('Water availability, human health, GLO, with uncert',
#   '6bb96a1a-3f9a-32e5-b61d-171bd4d6cc95'),
#  ('Water availability, human health, GLO, with uncert',
#   'c266520e-f671-3990-99dd-057fa51ebfe6'),
#  ('Water availability, human health, GLO, with uncert',
#   'f87edd21-d830-3d32-aeee-e69320033ccd'),
#  ('Water availability, human health, GLO, with uncert',
#   'e9649289-4111-3ec4-80fd-770952c30c49'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'fe24f9d9-3dde-4dec-9f4a-1c00b94f353e'),
#  ('Water availability, human health, GLO, with uncert',
#   'b94df422-b76f-3d10-91ef-83dc99967b51'),
#  ('Water availability, human health, GLO, with uncert',
#   'ce9fd979-2f96-3b4f-b09a-94df06fb3feb'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ed4b8d66-7643-47f0-9912-ef646db1e5ea'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '64f2cbe7-791b-4d4b-bd13-f0c142922738'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ab3e851e-21c9-47cf-8e7d-5f96dfae3ba5'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9278dfef-7744-438f-865a-8c264c9de8cb'),
#  ('Water availability, human health, GLO, with uncert',
#   '1702cfd9-5643-3a73-8a00-09755abe9fac'),
#  ('Water availability, human health, GLO, with uncert',
#   '5d8406dc-0091-38c0-b3ab-3a50bfd7e399'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '72705cd3-348c-49a5-877a-1c947882d1b7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7e2b64d5-3c75-4adf-88a6-d54b4bb46d3c'),
#  ('Water availability, human health, GLO, with uncert',
#   '48ae8335-d233-311c-b5ee-fc554c018671'),
#  ('Water availability, human health, GLO, with uncert',
#   'e273a57d-19bd-3a0e-abc7-d6e32bc320dd'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b9a35003-86ed-45d8-b616-ef6859087b40'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cbdd7871-f1a9-46ca-bd95-5863d459d34a'),
#  ('Water availability, human health, GLO, with uncert',
#   '76dc4c91-6ffe-43bf-b7d4-ba8c71def0c8'),
#  ('Water availability, human health, GLO, with uncert',
#   '07ca6082-954c-3128-9b62-6fc5852b5e5a'),
#  ('Water availability, human health, GLO, with uncert',
#   'df77647b-d3ea-3476-a665-4d435343ff5d'),
#  ('Water availability, human health, GLO, with uncert',
#   'aec504f6-5f16-3830-ab89-122a01e43efb'),
#  ('Water availability, human health, GLO, with uncert',
#   '4944a588-e3a9-3182-9231-ee8c975f617f'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3cc6b9e3-fda3-4712-b5b2-df07b0b996f3'),
#  ('Water availability, human health, GLO, with uncert',
#   'f838aec9-cb26-4597-bb6f-478cdf32e32a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'df1c10b2-021a-4db8-af05-267ceee43385'),
#  ('Water availability, human health, GLO, with uncert',
#   '64b8db56-7e67-32da-9f5f-7fbd2a66c03a'),
#  ('Water availability, human health, GLO, with uncert',
#   '84f07f02-ead8-37c6-a8f2-f96cc0ebb067'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c44eadf-8f68-496b-b9ef-f94be1372c58'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0e1c3d27-fb97-457a-a5d0-a324e7043402'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ecdb040b-aae3-495b-804c-e6b3d6f687ff'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '426e316e-db90-40ec-9f45-fa08e6db160c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cdbfd224-21fe-457e-a47d-26a525965051'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'cf39ec61-e779-4614-97b7-ec622556040d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ab1be93d-4439-4a05-8588-d4fe2e177871'),
#  ('Water availability, human health, GLO, with uncert',
#   '154568ac-8185-38bc-9de3-1aab78e98a8c'),
#  ('Water availability, human health, GLO, with uncert',
#   '7b492692-f5e0-393c-9e58-0374b38ae9c5'),
#  ('Water availability, human health, GLO, with uncert',
#   'acb7676c-2874-3e55-b74a-0aa3144f9362'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f988c6c1-830d-4f77-a7e2-0c943c606d94'),
#  ('Water availability, human health, GLO, with uncert',
#   '936081af-f5b2-3dcc-99b7-bf9570452566'),
#  ('Water availability, human health, GLO, with uncert',
#   '7a9d85b4-c90c-3c20-bf15-7d1e6ef20c3a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ef4e5109-025b-4786-860e-9dcc2db701a0'),
#  ('Water availability, human health, GLO, with uncert',
#   '2a8a1088-2664-3b27-8865-b484ecb6d999'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2925111b-3464-4e34-9d02-b73c1c033e91'),
#  ('Water availability, human health, GLO, with uncert',
#   'd78b41a7-b3f3-328f-9e55-0a9836c86c6e'),
#  ('Water availability, human health, GLO, with uncert',
#   '4b724d3a-2a1f-3176-a05b-b06c12d0c7e4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd998622b-6ec3-4082-80b9-22205251fb03'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1ae03e9f-9f0b-4f9e-8440-9c3d4f1b1868'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '07a366fe-1c9e-4651-ad1a-1da666316417'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43758b25-3b21-4f3b-ae0e-bf126f0105ff'),
#  ('Water availability, human health, GLO, with uncert',
#   '3ac1aaff-7bd1-375e-bcd8-ec7625823843'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '250de680-25a7-4a3b-93c9-a9ed44bb4e0c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '994d61de-fbb0-4187-a4d4-b11c3c2b9102'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd50fbe3f-b265-4fde-bf05-4156fe27b0a3'),
#  ('Water availability, human health, GLO, with uncert',
#   'b5e65e84-a1e1-3a02-a74f-8e6a9c0b2ad6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '902b828c-5b1f-4a1b-ad0f-d795eaaf067c'),
#  ('Water availability, human health, GLO, with uncert',
#   'e51e9393-0c77-3bd0-897c-1e3a4729196a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5aa2c010-fe60-4176-9731-1df76e317f75'),
#  ('Water availability, human health, GLO, with uncert',
#   '471f0cd8-bd7b-3cea-ade9-8a3293cb7641'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0ee752cd-5b6b-458d-b660-3e45a6798413'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'dbcfb8d9-9146-4c0d-8f89-cfd5a3951959'),
#  ('Water availability, human health, GLO, with uncert',
#   'd9c3f006-e25d-3beb-98c1-ed5cc01ce96c'),
#  ('Water availability, human health, GLO, with uncert',
#   'b2473da9-b49b-38b8-996d-a682ae82cae2'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8c920eda-3eee-4782-ace6-c706fb363b88'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '60fbcca2-15a2-4791-ab89-09921211487f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '512a5356-8059-4772-a43f-42e3c4f3d299'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '61461094-ed15-4201-a57e-b888b508dcdd'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2299398e-0846-4290-bcab-09bda2e61ee3'),
#  ('Water availability, human health, GLO, with uncert',
#   '7e1170d4-99d0-3812-8b94-0c6cd519b58b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd0394db1-a1cd-4026-bf50-dd5e47331572'),
#  ('Water availability, human health, GLO, with uncert',
#   '1e74759c-f865-3a12-bf79-6b1df1a9ebc3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '451e6159-6db9-430a-82c6-2452d120431a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a55659bb-d9f2-4904-a2ad-489cd484cf70'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c199261c-8234-43c5-b906-5b67707e4395'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7411975d-4167-467f-b36d-89eb1e83eeac'),
#  ('Water availability, human health, GLO, with uncert',
#   '7ed8789d-5282-4cb9-901a-cdf5433c2dec'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e2da818-59cb-491a-8e4c-fa62e2a9d944'),
#  ('Water availability, human health, GLO, with uncert',
#   '468ced72-ed96-3ffe-bd81-584d0605aa21'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '36995b1f-0e88-439a-9295-7029d9bfc9e7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e52cbfa-94d7-432b-892f-431daa71a6ef'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'd4e14d98-0abd-4e45-94a7-112fd5277c35'),
#  ('Water availability, human health, GLO, with uncert',
#   'f1bdb3e1-1235-4939-a4a0-6383caa42c63'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8d59bb59-b416-41c2-adab-bba044237346'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a47cd00c-476b-4f73-a0a0-46dc11638699'),
#  ('Water availability, human health, GLO, with uncert',
#   'beb8d1f8-7819-321d-a32d-ab3884121e7b'),
#  ('Water availability, human health, GLO, with uncert',
#   '172fec48-5592-3d59-80cc-a4d86eeb1db8'),
#  ('Water availability, human health, GLO, with uncert',
#   '47ede456-cb14-44fd-bc8e-01cb1bee4af1'),
#  ('Marine eutrophication, GLO, with uncert',
#   '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3ae54a86-f4ea-40dc-b2ad-840913d49ef3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8b03ce87-7aec-4106-8f9f-752c6174fda3'),
#  ('Water availability, human health, GLO, with uncert',
#   '4089d90f-81cf-37fa-a004-ebbad26d04b3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '922b6b30-8dc3-4c66-ba0a-be9738d67f98'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99f1deff-a149-49bf-b1fd-95f7ff7d1331'),
#  ('Water availability, human health, GLO, with uncert',
#   'b1f08696-54fa-458d-9a6b-af614db865e6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '63735d98-57b0-429c-8267-40a5f1da06b1'),
#  ('Water availability, human health, GLO, with uncert',
#   '0609bdf8-819f-4556-8686-94e3a2476f2e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4da2ea28-8273-4901-9931-264169ec7731'),
#  ('Water availability, human health, GLO, with uncert',
#   '9e0de545-41c5-4d35-897d-561df22e6272'),
#  ('Water availability, human health, GLO, with uncert',
#   '8e338a98-3038-3aef-973b-a3b0b86c0244'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bbcdd18c-4d16-4c28-b031-d988884030a7'),
#  ('Water availability, human health, GLO, with uncert',
#   'b8d4fe11-af72-3603-adae-44d0524e0857'),
#  ('Water availability, human health, GLO, with uncert',
#   'e0065ac9-4578-3e8d-9338-fd99a299ae46'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0abf9db7-b5a2-4c18-8ec6-aca3a7fb5579'),
#  ('Water availability, human health, GLO, with uncert',
#   '1fef4759-76ce-4443-9a0e-cfa38c4ce14a'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'bafff3e8-f51e-42d6-8924-dcab1098c8ef'),
#  ('Water availability, human health, GLO, with uncert',
#   '473aaa0c-5be9-3c1d-8bd9-41e6729abc99'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a69ed71-6cc0-46f6-a4ab-1b9675f8315b'),
#  ('Water availability, human health, GLO, with uncert',
#   '60a87dc7-eb4a-3212-942d-a46f8730798a'),
#  ('Water availability, human health, GLO, with uncert',
#   '75b5c052-b7fa-48f6-8ce8-cfefed1f6fd2'),
#  ('Water availability, human health, GLO, with uncert',
#   'a945fa6e-b056-4eec-b684-cf42e461d64c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5a022658-5189-4504-bb60-fc21e49c3004'),
#  ('Water availability, human health, GLO, with uncert',
#   'd40062f6-9cad-3324-84dd-d8f194a5005d'),
#  ('Water availability, human health, GLO, with uncert',
#   '1a88c7ff-be1f-4134-bf27-c09936d144a8'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '74212326-ca29-46f8-a600-4e45b0ad688e'),
#  ('Water availability, human health, GLO, with uncert',
#   'bea8ee06-61e8-4770-abce-6ed950985dfe'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'aa6a298f-893f-449d-8573-39f32fd43fe5'),
#  ('Water availability, human health, GLO, with uncert',
#   '09333058-7adb-4965-aa9f-7d7f7aa47de6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '97ad7d9b-eca1-4b54-8b31-9db2527f8518'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e1a4ab8-76e5-44cf-a726-ea75ac62efac'),
#  ('Water availability, human health, GLO, with uncert',
#   '3fc1d5e2-8e32-480a-be55-45b7f42dd0d6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7f401bdd-4116-48ad-b217-013fd904d323'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '11700b93-5c22-4714-a468-0859f6b46b17'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '46b8b2fd-eb2a-413d-bc39-e7dc18a420ef'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '012ee35c-c4e1-4759-9f62-e1a7a8504f8c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '00d15dd1-8517-49dd-933d-e7db77e9d342'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6f2f97dc-2aeb-482c-a20a-9747f0746898'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'fe9c3a98-a6d2-452d-a9a4-a13e64f1b95b'),
#  ('Water availability, human health, GLO, with uncert',
#   'c39ddc68-60d8-32e9-a0ce-05125d213c0d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '00907a61-b501-4f47-b688-1dc2b51d48c1'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'db6f90ef-27fc-41a8-a541-07efdce1fab5'),
#  ('Water availability, human health, GLO, with uncert',
#   'c17215a3-b80a-3372-810c-ccc92b97d3ef'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'de48749a-85cb-4307-8a2b-c9d5830d0bae'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '28e5f69f-7b2e-4e31-9725-d407b2964b3f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0331d547-57ea-4ec6-a746-3ab289c3626a'),
#  ('Water availability, human health, GLO, with uncert',
#   '31b9c5a7-2359-3349-be6f-086fe117cd37'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '395c7600-604a-4e1f-85df-b5f94edeb659'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a49c025-f03c-4eab-a0eb-b06d1a4442db'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f9795c43-391d-4e31-a4ce-bee8259adb03'),
#  ('Water availability, human health, GLO, with uncert',
#   'ca0d7b64-6044-3a7c-af04-ae23b94edb7b'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69c7d771-04fc-499e-84f8-6c7b923b8ced'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a97a1cec-673d-448a-b3ba-8ea16fe44973'),
#  ('Water availability, human health, GLO, with uncert',
#   'a7bbf899-f764-3025-91ee-43b59036b5d0'),
#  ('Water availability, human health, GLO, with uncert',
#   '6ddcf13b-64d6-33e3-97eb-a14040dddfca'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '345281db-4ed3-e458-5ead-00003fdd1e9a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '38921804-39ac-4a71-b675-2d092357fe0d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a8e39acd-6e7f-4d43-973b-37e6b7c00037'),
#  ('Water availability, human health, GLO, with uncert',
#   'b9f02930-d0e3-3144-92bf-1babde3b17d8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '975ae6bf-9a02-4d6f-af7e-8f1253842fed'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7b830424-436d-428c-b2ad-3e93f3115d7b'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '6cd33048-b06a-4b9b-bf8d-b4b6b47754f9'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '97c598f0-4d1d-4f9f-906e-097347168153'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4624deff-2016-41d4-b2bf-3db8dab88779'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1e033b47-5e2f-4fd4-acc3-df3e2e3e56a5'),
#  ('Water availability, human health, GLO, with uncert',
#   'a3f36ce8-73ad-38a8-9073-16558ed96158'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b3f09d7-7681-4f2d-b967-d630dfb29068'),
#  ('Water availability, human health, GLO, with uncert',
#   'd340bcfb-77bb-34f2-8052-b598a2cdf17e'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '135816ab-f119-4a64-b608-a61cb788af7d'),
#  ('Water availability, human health, GLO, with uncert',
#   '72721c4e-d589-4ad7-8c5e-4228b8690ddb'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '98b723d4-3362-4b38-8b1e-1bedacfd5e27'),
#  ('Water availability, human health, GLO, with uncert',
#   '31950f2d-17c2-469f-9066-0f6dbb76ce7a'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5dbd8205-fa09-3895-90d3-5e1d7406c179'),
#  ('Water availability, human health, GLO, with uncert',
#   '3f7e0b7e-aefd-4efd-a946-7bdad142fd50'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '276c95b8-3eb7-42e9-9bb7-f8125e33f486'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7d5b5802-3698-4be8-98f8-ab7c1a2e9328'),
#  ('Water availability, human health, GLO, with uncert',
#   '64efcbd6-4217-37a8-acb5-f78df61be29b'),
#  ('Water availability, human health, GLO, with uncert',
#   '6e323b42-84de-3746-bc4e-baea6f53e6ab'),
#  ('Water availability, human health, GLO, with uncert',
#   '8dee1571-3aa3-30b5-96bd-25bfb82df9f0'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c3f83a91-4888-41a4-add9-fd01678a1e5f'),
#  ('Water availability, human health, GLO, with uncert',
#   'c56bfea1-912d-468f-ba43-bef7c14c8c1e'),
#  ('Water availability, human health, GLO, with uncert',
#   '0e848871-d8b6-457a-a274-dd50fd437502'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1d678d0d-fe42-429b-9aa9-d30127b0ca9c'),
#  ('Water availability, human health, GLO, with uncert',
#   'eba958f5-ffe1-3f4b-8f2c-8bc7b5a9b275'),
#  ('Water availability, human health, GLO, with uncert',
#   'd84c58f8-bc2a-3fed-badd-2a35ec5e4c6a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'af41f691-3a3e-47a3-9e45-3b4d78469ae0'),
#  ('Water availability, human health, GLO, with uncert',
#   'a5a6f52b-e9e0-39b8-8cf6-9e5f4cb7e258'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '93ac2969-a4e9-49b5-8b97-5cbc6b9b2601'),
#  ('Water availability, human health, GLO, with uncert',
#   '572445fe-ff91-3f7e-8846-a3fddd87ea52'),
#  ('Water availability, human health, GLO, with uncert',
#   '5511e6ea-d68e-39ad-a83d-2f11e9348ea3'),
#  ('Water availability, human health, GLO, with uncert',
#   'e329aa39-56b8-3015-abd0-efba8fae94cb'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '29630a65-f38c-48a5-9744-c0121f586640'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa4d4851-3cab-48a0-a2e4-d3e047323eb6'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69dfa439-8e4e-4cae-bb0c-85a8aa8b9a73'),
#  ('Water availability, human health, GLO, with uncert',
#   'b297cf0c-23c3-34a8-9cdf-586650be58fd'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '267ca4fd-2526-451e-86e0-796318d509b6'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '032542d3-7078-4f85-bd95-75fdac9268d2'),
#  ('Water availability, human health, GLO, with uncert',
#   '86ea740c-2765-34b8-9af6-6e7c7bd1f0b0'),
#  ('Water availability, human health, GLO, with uncert',
#   '23f4e3e3-c30b-3d45-b888-5263a9484861'),
#  ('Water availability, human health, GLO, with uncert',
#   '5e45aecb-61b2-359e-9393-6f0bbbc4b1f7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ff6c4aa2-6baf-4ef2-82d4-14fadaf6b060'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5779b2aa-ed88-4f1f-89a4-95b4dfa5d61c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '399f4fd0-8fd8-4a22-82ee-c7f3b6a3d22a'),
#  ('Marine eutrophication, GLO, with uncert',
#   'dc084330-5108-4d9c-a7ed-eb3345507f13'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e71f95a5-fd82-4128-9fd1-be3f0e85d0fc'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c033dd2f-87a4-435d-a7cb-477b15310066'),
#  ('Marine eutrophication, GLO, with uncert',
#   '1aa538b9-51eb-49fe-8904-de34e58945c7'),
#  ('Water availability, human health, GLO, with uncert',
#   '6efff6a9-428a-4062-b415-3950e32c1dab'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b93fac73-b3b1-4825-b1db-c129d404d3f3'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '59ded913-17fe-4b3e-80cb-79b97cdbef9a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c7d2cf2d-0d21-45f7-9769-b07f3e53b76a'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6f0c79d3-c980-4cd5-ae0a-51f7d9a5f472'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0930b6b8-d9c6-4462-966f-ac7495b63bed'),
#  ('Water availability, human health, GLO, with uncert',
#   '229b3c06-8be1-3415-b776-6bfa63650993'),
#  ('Water availability, human health, GLO, with uncert',
#   'f1a90356-cac4-3eb4-8619-eabe3d45c696'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14b92328-e08d-4fac-b16a-da5dcd0e5627'),
#  ('Water availability, human health, GLO, with uncert',
#   'ab92ef07-03ba-3f2c-8568-0805e78fad4d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd264f35c-7f48-47d8-885b-057bdafa04a3'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26efe47c-92a5-4dea-b4d0-eac13e418a58'),
#  ('Water availability, human health, GLO, with uncert',
#   'c9eaca71-6924-483f-9e86-51265bc0e9ef'),
#  ('Water availability, human health, GLO, with uncert',
#   '55e63a8a-224b-36f7-a5c8-f0635363f0f1'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e7f1605-9451-4e53-9690-ab5318033227'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '75ee82c9-e3fe-4887-ae1d-050ff7a6a6be'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9c08496f-7895-44f9-8686-fe3154392da4'),
#  ('Water availability, human health, GLO, with uncert',
#   '19229850-3ddf-3c30-bfa5-b356b7be2fbd'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'f958c174-0a02-4bef-8290-efc2abcf3130'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '69d8569b-a90e-4bf5-8a5d-e8d0c59068cc'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f05cca02-ec18-4acc-9939-59658ff9a554'),
#  ('Water availability, human health, GLO, with uncert',
#   '13af5f43-9b78-382a-adc0-e632e0f2dc9f'),
#  ('Water availability, human health, GLO, with uncert',
#   'f835e4b9-3073-4547-ab20-ba20886fd6a3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c7869c43-266c-429d-bfd5-6b578ed32ce8'),
#  ('Water availability, human health, GLO, with uncert',
#   '30aa8b31-d824-4c3a-b6b3-d141f710b63f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8a00b5c3-2465-4520-9f43-22a64c846b6c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7fdc928c-f347-45e7-82d7-046acdf878ae'),
#  ('Water availability, human health, GLO, with uncert',
#   '4a57e617-eb1f-4c75-b6d9-61dea2d82295'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'edd772b0-62b3-4148-9391-2d381c7003fa'),
#  ('Water availability, human health, GLO, with uncert',
#   '9d966161-d561-33f5-9050-8233889024b0'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '44359d15-59d8-44be-a256-68e4aeabe192'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ab295ced-caf0-4281-96a2-7ebc2203c508'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c16d78c6-a944-4bfa-8e7a-b292b5b49d2e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9497544b-a783-486e-a029-1f042de08741'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43c8b65e-8551-37da-9f00-7fedc95fe17d'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ed6f73f6-6ea8-43d3-9212-b4551140484e'),
#  ('Water availability, human health, GLO, with uncert',
#   '2d2d23a0-4896-384b-896c-7852db85f132'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9607e93d-3572-461f-bb2c-8597cc23bab0'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '14a00c9f-9976-44fd-aa01-e8bba2835841'),
#  ('Water availability, human health, GLO, with uncert',
#   '1f31247d-6556-11dd-ad8b-0800200c9a66'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '44ea6f89-8780-45b4-a80a-cfc3abcfef5f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '61d316ad-7f5a-4bc1-915f-1336263035cf'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e3c1224d-1958-4fbb-b0e3-91943e5975c7'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9b5b8c40-38fe-42fb-8130-56c15e485fd0'),
#  ('Water availability, human health, GLO, with uncert',
#   '4f07dade-dcfe-384a-b666-513d575b8c9d'),
#  ('Water availability, human health, GLO, with uncert',
#   'f4ed16d1-aacb-344f-ab16-aeb44de80128'),
#  ('Water availability, human health, GLO, with uncert',
#   '875699e1-34cc-3d53-ab91-d88d0cb89c2a'),
#  ('Water availability, human health, GLO, with uncert',
#   'af44fff2-0c47-3785-b610-c950776f117a'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4498615d-0ed6-4ca4-8a87-267f31f624b0'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '64d99cb5-3b4f-4195-b86f-c5f45b4dcd19'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bc55a5b7-5a07-4ba7-87af-6f374d79ef06'),
#  ('Water availability, human health, GLO, with uncert',
#   '034f8a4d-d2c9-3242-bfc2-929e373b367c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5eb25424-acb6-4ffa-a96a-5fdef05f6515'),
#  ('Water availability, human health, GLO, with uncert',
#   'ea46e7e8-e9b6-31ac-be23-52f09bf73782'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69cdd9a1-25d8-4185-8d86-17dc1878ede1'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '826a2a83-e704-48f5-87c4-211cb869cc73'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99127c79-69f5-4046-a298-3f842c68d62b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '668553fa-6988-8473-87d8-000071c2a500'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55c8f839-9908-45c2-bc1b-df7a3f7b34f3'),
#  ('Water availability, human health, GLO, with uncert',
#   '5f9e8551-455c-393e-86c9-27683f6d9d5f'),
#  ('Water availability, human health, GLO, with uncert',
#   'a92767f6-04ba-3c3f-b7e8-3551f19346b6'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b91d0527-9a01-4a86-b420-c62b70629ba4'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d6baa46-6ac9-4f04-9bcb-abc382574260'),
#  ('Water availability, human health, GLO, with uncert',
#   '995f3484-64f1-4d38-bc97-5364463e02b0'),
#  ('Water availability, human health, GLO, with uncert',
#   '19975317-8737-420c-a405-e7148bdb8d9c'),
#  ('Water availability, human health, GLO, with uncert',
#   '2ba4d6f7-45c2-32af-b377-35ca261dca67'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '70c4c6d8-ed81-4763-ae6d-39e54ef0b1fa'),
#  ('Water availability, human health, GLO, with uncert',
#   'debe7510-db87-4df7-bf4c-cfb3a622edb1'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '45091000-d7e1-459f-bac5-38b51efb4d63'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9be62afc-89f5-4c81-86b0-e3fec4dbd311'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2f5a81ae-2a76-4807-8d8d-a4be0c11acfa'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c24fe83a-3170-49a3-ab67-279d34b8d920'),
#  ('Water availability, human health, GLO, with uncert',
#   '461b9748-ac92-46d2-96ad-fb63097c0376'),
#  ('Water availability, human health, GLO, with uncert',
#   '22f7036b-d608-4e79-844f-7ccf7ca409e8'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '366ece56-e09c-4acd-b615-aaedd9bbe777'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '956c5f83-65c8-4607-9749-147cfb9c8f70'),
#  ('Water availability, human health, GLO, with uncert',
#   '8c7323c6-2d9c-3874-91f3-69d87ed3754f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bba9f623-5919-4ef3-b98d-c94af1553179'),
#  ('Water availability, human health, GLO, with uncert',
#   'f7baa589-bb9c-36c2-8ac2-4e23874315b5'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f398a9bd-7a54-4cf3-847d-8a3805c45ee5'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d143ee5-e848-47d0-91e8-f10f7c86963d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e002771-9f22-43e3-9990-f06f8235700b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3abec56e-98ea-44d2-b91d-7ae9bcd2141d'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1b3f4af1-ca0a-4235-af27-56030df17933'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '626915e9-2424-4059-8b6a-fae47161acdf'),
#  ('Water availability, human health, GLO, with uncert',
#   'e0241436-ad0b-40ab-90f8-db4fd79f4e8c'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'e1e245de-5e76-4d8c-a083-95262b06dcf2'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3573b5ab-5158-4048-a364-aad9e706acb4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '73cba245-5969-4076-8490-75a236073196'),
#  ('Water availability, human health, GLO, with uncert',
#   '10e7a3bc-9edc-322b-b3eb-0ca651428c2c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a6888cde-b33b-4bec-9e07-c6f3e6932f24'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b79e26a0-88db-441f-b79b-508506e81b93'),
#  ('Water availability, human health, GLO, with uncert',
#   '121b0f77-c14f-393e-8b68-30b46e1a426c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '975543fa-3eed-4b0c-b87b-50f26630fe89'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd585d599-05f1-47ff-8c41-790f51830b9b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99801a43-d476-4055-8d97-fb7c4ae173d4'),
#  ('Water availability, human health, GLO, with uncert',
#   '4a1ae352-5361-380b-9bad-a1680e9658fe'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8f516f52-4ecc-46c6-9029-65de3f05eea4'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a4c4b2e8-7611-4690-b00f-80789d4eb9fe'),
#  ('Water availability, human health, GLO, with uncert',
#   'c76abb6e-4dff-3c0f-b3d9-80be0f80ec3e'),
#  ('Water availability, human health, GLO, with uncert',
#   '7a4ce745-2cc7-3746-a9c9-fa54e4b5818c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55beee8d-d04e-4307-bb0e-4e113dc07ee7'),
#  ('Water availability, human health, GLO, with uncert',
#   '6e9312ec-1e02-4232-9589-0746bc67d4e6'),
#  ('Water availability, human health, GLO, with uncert',
#   'c32bea0d-1d42-36dd-aeac-9a7b16696eba'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b0828a29-0261-4a12-a5d3-9e72c7e89619'),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '785d44a4-2979-4ea3-8121-aa82a65ba2e5'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c3eff967-20d8-4bcd-bd26-2dc2592a37b9'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3abea18f-cd91-4106-b23d-093c49427525'),
#  ('Water availability, human health, GLO, with uncert',
#   '09a69d95-307e-4332-a566-1ce37f032853'),
#  ('Water availability, human health, GLO, with uncert',
#   '22c11859-a872-43da-84ee-bd7423a50f5e'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fcb77a5a-6882-4aeb-82a9-ba57688d2224'),
#  ('Water availability, human health, GLO, with uncert',
#   'e8e6e8f7-373e-3381-b6cf-bb6d4ddb2d76'),
#  ('Water availability, human health, GLO, with uncert',
#   'f1bc0318-5825-3ea8-b36a-53c0b602c412'),
#  ('Water availability, human health, GLO, with uncert',
#   '1ba56136-54c1-3840-ab0c-34f1e333412c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9af35f20-e8f1-4e39-8241-f3e76741dc78'),
#  ('Water availability, human health, GLO, with uncert',
#   '5e37f4c5-3ad2-377e-87b7-46e80144b3c2'),
#  ('Water availability, human health, GLO, with uncert',
#   '5f6ecee0-a80d-3172-8c35-d3258079891b'),
#  ('Water availability, human health, GLO, with uncert',
#   '65e587ee-924c-351b-a6ea-f46547c660ca'),
#  ('Water availability, human health, GLO, with uncert',
#   'ae1e393b-8ec0-3060-b98c-945b00f012c1'),
#  ('Water availability, human health, GLO, with uncert',
#   '6e694082-a3be-3aa5-a2ce-0ff3f1d6b869'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1ba33265-7100-47b7-b9ed-1f1a74fbb141'),
#  ('Water availability, human health, GLO, with uncert',
#   'c0f39d6f-dd5a-4465-9dee-b0c5f897d175'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6e02ccfc-9eb5-4a51-be9a-870c1087c833'),
#  ('Water availability, human health, GLO, with uncert',
#   '295e6c24-7c10-4118-a330-0672382000d7'),
#  ('Water availability, human health, GLO, with uncert',
#   '433b7ce7-5c2d-41c3-80ef-ead7f45c8699'),
#  ('Water availability, human health, GLO, with uncert',
#   '9c369e6e-909b-3828-80eb-97cb53c9fb13'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fbe76292-b1ff-4efe-8ac6-3a36c4f3c900'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b5d37ef1-0d36-4c00-8a38-54bbdc5e1eda'),
#  ('Water availability, human health, GLO, with uncert',
#   'c5294e60-47a2-3ba3-bd8d-12cec538bb7a'),
#  ('Water availability, human health, GLO, with uncert',
#   '5261c4f4-4abf-3ac2-873a-183e9956e671'),
#  ('Water availability, human health, GLO, with uncert',
#   '5ef54da5-e7c2-3ac7-a01c-45725d131111'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c0143eba-3daf-44ad-8d34-6e1d34128ace'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fdda4f8e-b620-4df6-92a9-101a251d2f42'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '17a5a406-333f-4b9e-8852-c2de50bc9585'),
#  ('Water availability, human health, GLO, with uncert',
#   '1acb026e-9de6-48fe-9e0d-be4d24125bbc'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'de94ed71-1e83-40ad-9916-6b7c16d55a6d'),
#  ('Water availability, human health, GLO, with uncert',
#   '37683746-5ef6-352c-bb22-7d6bacc6766f'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3aa37a9b-98ad-42b0-b7c9-bf472c9a2aa3'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '786699f7-8069-49e4-a6e6-dffed3c32314'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '565414ae-fff7-4f41-9668-a5a7d12874a9'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7381c88b-dc3f-4aff-9ae7-261b8216fac2'),
#  ('Water availability, human health, GLO, with uncert',
#   '12604ba6-b7a1-4036-885c-72704b029906'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3f8e24d7-3d44-4a47-870f-9e3e74decca4'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3f9dea81-3fba-46b9-83d5-23ffd5bae744'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '891b2f36-c1cb-495a-9f27-be7b583eaf1b'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ea3bc981-8a35-40e1-82bd-33a12820f98c'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e4d65952-4845-473f-bdc8-fb40c20ac3a4'),
#  ('Water availability, human health, GLO, with uncert',
#   '0a89160c-168b-3315-a7f7-5543bc60cedf'),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4b420f19-0421-461e-a0b6-7efbf580089b'),
#  ('Water availability, human health, GLO, with uncert',
#   '882c52b9-814b-3acf-9940-c3c39cc271b7')]

# %%
valid_or_not={}

for cf in cf_errors_all:
    uncert_dict=iw_uncert_dict_beta[cf]
    uncert=stats_arrays.UncertaintyBase.from_dicts(uncert_dict)
    
    if stats_arrays.GeneralizedBetaUncertainty.check_bounds_reasonableness(uncert)!= None:
        valid_or_not[cf]=stats_arrays.GeneralizedBetaUncertainty.check_bounds_reasonableness(uncert)
    
valid_or_not
# Out:
# {}

# %%
cdf={}

for cf in cf_errors_all:
    uncert_dict=iw_uncert_dict_beta[cf]
    uncert=stats_arrays.UncertaintyBase.from_dicts(uncert_dict)
    cdf[cf]=stats_arrays.GeneralizedBetaUncertainty.cdf(uncert,(uncert['minimum']-uncert['maximum'])/2)
    
cdf
# Out:
# {('Land occupation, biodiversity, GLO, with uncert',
#   '012ee35c-c4e1-4759-9f62-e1a7a8504f8c'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '062a6faf-b1a5-4a6a-aa02-47ae3ec566a8'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '080bf4c6-fab3-4e21-88c7-20b435aa42e8'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '0a03fe20-343b-42d4-87b5-1300cfd47a7a'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '135816ab-f119-4a64-b608-a61cb788af7d'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14811cde-0ef0-4327-ad94-4ee232f7a462'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '14b92328-e08d-4fac-b16a-da5dcd0e5627'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '19f84b2e-e6ff-4351-ba3a-8b650fc20d14'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1ae03e9f-9f0b-4f9e-8440-9c3d4f1b1868'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '1eaa9ea4-40b8-414a-b198-5626400372e1'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '250de680-25a7-4a3b-93c9-a9ed44bb4e0c'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26586deb-0d0d-42b7-ae01-e6e517a743cb'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '26efe47c-92a5-4dea-b4d0-eac13e418a58'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2843362e-6942-48fb-acdc-cea07d6e08cc'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2925111b-3464-4e34-9d02-b73c1c033e91'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '2aa913a6-41a4-47cd-83bd-58cc5e1b11a5'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3259f9e3-8108-444b-9521-de12e53f6e35'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '395c7600-604a-4e1f-85df-b5f94edeb659'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3b4db191-9634-4a01-a873-f3cb234785e4'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3cc6b9e3-fda3-4712-b5b2-df07b0b996f3'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e2da818-59cb-491a-8e4c-fa62e2a9d944'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '3e7f1605-9451-4e53-9690-ab5318033227'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4498615d-0ed6-4ca4-8a87-267f31f624b0'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '44ea6f89-8780-45b4-a80a-cfc3abcfef5f'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '45091000-d7e1-459f-bac5-38b51efb4d63'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a49c025-f03c-4eab-a0eb-b06d1a4442db'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4a69ed71-6cc0-46f6-a4ab-1b9675f8315b'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b3f09d7-7681-4f2d-b967-d630dfb29068'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4b6b9b76-3199-4bd0-b11d-f8f2efbeac4e'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '4ce71e21-8f14-48da-b9e5-4743e5f3c0ab'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '56ec994a-eb96-42e8-93eb-4970e30e6362'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '59ded913-17fe-4b3e-80cb-79b97cdbef9a'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c26adb8-cd01-4177-b77c-d17dfca4d16c'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5c44eadf-8f68-496b-b9ef-f94be1372c58'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5ce41517-25bb-4da6-b839-5fd0f00baff1'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '5dbd8205-fa09-3895-90d3-5e1d7406c179'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '61461094-ed15-4201-a57e-b888b508dcdd'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '64f2cbe7-791b-4d4b-bd13-f0c142922738'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69c7d771-04fc-499e-84f8-6c7b923b8ced'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69cdd9a1-25d8-4185-8d86-17dc1878ede1'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '69dfa439-8e4e-4cae-bb0c-85a8aa8b9a73'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '6cd33048-b06a-4b9b-bf8d-b4b6b47754f9'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '70c4c6d8-ed81-4763-ae6d-39e54ef0b1fa'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '72745257-3534-4ca3-adfa-a2eb63f1e7d9'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '74212326-ca29-46f8-a600-4e45b0ad688e'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '785d44a4-2979-4ea3-8121-aa82a65ba2e5'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d143ee5-e848-47d0-91e8-f10f7c86963d'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '7d6baa46-6ac9-4f04-9bcb-abc382574260'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '86d3fdb1-3b9b-4b01-a6eb-6bdab06676d7'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '871a58d9-bbbb-4cdf-bf84-dd4a90fa7c8e'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '92f8f25e-135a-48df-b90c-c6c4547fe94d'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '956c5f83-65c8-4607-9749-147cfb9c8f70'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '97c598f0-4d1d-4f9f-906e-097347168153'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '98b723d4-3362-4b38-8b1e-1bedacfd5e27'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   '9db06277-b6d9-4c48-8cfb-de342e928a50'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a029c026-6970-40a0-b597-5ebd8dfbaa97'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a47cd00c-476b-4f73-a0a0-46dc11638699'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'a4c4b2e8-7611-4690-b00f-80789d4eb9fe'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ab295ced-caf0-4281-96a2-7ebc2203c508'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'aca1714f-0040-4a65-a73a-0e38aa9f50f4'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b0828a29-0261-4a12-a5d3-9e72c7e89619'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b1720e30-2692-4a1f-8ced-b58574d2e7c6'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b91d0527-9a01-4a86-b420-c62b70629ba4'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'b9a35003-86ed-45d8-b616-ef6859087b40'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'bafff3e8-f51e-42d6-8924-dcab1098c8ef'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c033dd2f-87a4-435d-a7cb-477b15310066'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c14ea750-4a9f-41fa-bcc1-4a1d84466f43'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'c199261c-8234-43c5-b906-5b67707e4395'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'cf39ec61-e779-4614-97b7-ec622556040d'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'd4e14d98-0abd-4e45-94a7-112fd5277c35'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'dde38771-435a-4f90-ad87-fd944f90b437'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'e1e245de-5e76-4d8c-a083-95262b06dcf2'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ed4b8d66-7643-47f0-9912-ef646db1e5ea'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ed6f73f6-6ea8-43d3-9212-b4551140484e'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'ee2631d0-c8ee-4ee9-a4a0-c1c0ff6373bd'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'f958c174-0a02-4bef-8290-efc2abcf3130'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'faa01bcb-884e-4c79-9ea2-16da6596c6a6'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'fe24f9d9-3dde-4dec-9f4a-1c00b94f353e'): array([[ 0.]]),
#  ('Land occupation, biodiversity, GLO, with uncert',
#   'fe9c3a98-a6d2-452d-a9a4-a13e64f1b95b'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '00907a61-b501-4f47-b688-1dc2b51d48c1'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '00d15dd1-8517-49dd-933d-e7db77e9d342'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '032542d3-7078-4f85-bd95-75fdac9268d2'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0331d547-57ea-4ec6-a746-3ab289c3626a'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '04eb0695-e67b-46e5-9516-da6bde119822'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0775d4c9-2c91-4a0d-a4a7-1c6b96e47ea4'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '07a366fe-1c9e-4651-ad1a-1da666316417'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '07d4460c-ae27-4717-9db9-9e0b1ea12dd5'): array([[ 0.21261261]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0930b6b8-d9c6-4462-966f-ac7495b63bed'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0abf9db7-b5a2-4c18-8ec6-aca3a7fb5579'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0cab58d3-f449-48d4-94bd-ec09d19736d6'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0d7c280e-9f07-48b7-bf01-5cfd0d475e1c'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0e1c3d27-fb97-457a-a5d0-a324e7043402'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '0ee752cd-5b6b-458d-b660-3e45a6798413'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '11700b93-5c22-4714-a468-0859f6b46b17'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '12be05aa-48ad-49a8-a864-7a51ba56075b'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '14a00c9f-9976-44fd-aa01-e8bba2835841'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '178463a8-4cb3-4a8b-90d6-e360c6a68f38'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '17a5a406-333f-4b9e-8852-c2de50bc9585'): array([[ 0.32256771]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '19f7928a-99ea-4206-b957-f06834edeb1b'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1a568858-efa8-4c2a-b46e-82b6e66b6072'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1a95203d-8fe0-44ed-9203-22d40c1bc617'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1b3f4af1-ca0a-4235-af27-56030df17933'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1ba33265-7100-47b7-b9ed-1f1a74fbb141'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1d678d0d-fe42-429b-9aa9-d30127b0ca9c'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '1e033b47-5e2f-4fd4-acc3-df3e2e3e56a5'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '20bfd418-5b2e-4c9c-ae57-cf7ebd573c2a'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '220b9a7a-1ced-462b-b645-e80253e189ee'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2299398e-0846-4290-bcab-09bda2e61ee3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '267ca4fd-2526-451e-86e0-796318d509b6'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '276c95b8-3eb7-42e9-9bb7-f8125e33f486'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '28e5f69f-7b2e-4e31-9725-d407b2964b3f'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '29630a65-f38c-48a5-9744-c0121f586640'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2cb441cd-8d2e-4e5c-a208-48c4fa005c41'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2dace710-44ce-4074-9617-65a5f2c1a3ee'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e002771-9f22-43e3-9990-f06f8235700b'): array([[ 0.21261261]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e1a4ab8-76e5-44cf-a726-ea75ac62efac'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e52cbfa-94d7-432b-892f-431daa71a6ef'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2e785337-a069-3d02-4c59-000033481da0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '2f5a81ae-2a76-4807-8d8d-a4be0c11acfa'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '31e3aeb5-dae5-4a33-8038-a616442906c3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '31e4e26b-a997-4969-963d-243699aca3a8'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '322b3ced-400e-431f-94cf-d72afb030907'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '345281db-4ed3-e458-5ead-00003fdd1e9a'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '34f9fc3a-0406-4a90-b85f-7df531350944'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3573b5ab-5158-4048-a364-aad9e706acb4'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '366ece56-e09c-4acd-b615-aaedd9bbe777'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '36995b1f-0e88-439a-9295-7029d9bfc9e7'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '38921804-39ac-4a71-b675-2d092357fe0d'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '399f4fd0-8fd8-4a22-82ee-c7f3b6a3d22a'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3aa37a9b-98ad-42b0-b7c9-bf472c9a2aa3'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3abea18f-cd91-4106-b23d-093c49427525'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3abec56e-98ea-44d2-b91d-7ae9bcd2141d'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3ae54a86-f4ea-40dc-b2ad-840913d49ef3'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3f8e24d7-3d44-4a47-870f-9e3e74decca4'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '3f9dea81-3fba-46b9-83d5-23ffd5bae744'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '426e316e-db90-40ec-9f45-fa08e6db160c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43758b25-3b21-4f3b-ae0e-bf126f0105ff'): array([[ 0.32256771]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43c326df-fae0-4e31-a1f2-5a9dcf3f2244'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '43c8b65e-8551-37da-9f00-7fedc95fe17d'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '44359d15-59d8-44be-a256-68e4aeabe192'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '451e6159-6db9-430a-82c6-2452d120431a'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4624deff-2016-41d4-b2bf-3db8dab88779'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '46b8b2fd-eb2a-413d-bc39-e7dc18a420ef'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '48f50b54-6156-418c-b4be-d14558be12c8'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4b420f19-0421-461e-a0b6-7efbf580089b'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4da2ea28-8273-4901-9931-264169ec7731'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4e48b83e-af69-429f-8941-2332e7ddc62a'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '4fe8d4ab-fdd1-4316-8065-deb1edb04e39'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '512a5356-8059-4772-a43f-42e3c4f3d299'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '525b8812-77d3-4248-aa8e-805910443a23'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '54b82481-32a3-4e82-bac7-1df475dbc80c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55893abb-69ff-4a33-9349-a8d37a172537'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55beee8d-d04e-4307-bb0e-4e113dc07ee7'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '55c8f839-9908-45c2-bc1b-df7a3f7b34f3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '565414ae-fff7-4f41-9668-a5a7d12874a9'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5779b2aa-ed88-4f1f-89a4-95b4dfa5d61c'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '577f7291-6e3b-4050-9239-f34e2aca0cf1'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '59df4945-6ee2-4ea6-9ef7-36c4f4b478f6'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5a022658-5189-4504-bb60-fc21e49c3004'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5aa2c010-fe60-4176-9731-1df76e317f75'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5cf68994-cf11-4e37-9834-1f0e1c382fa5'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '5eb25424-acb6-4ffa-a96a-5fdef05f6515'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '60202f55-1d85-4fda-81d7-e6376a74f500'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '60fbcca2-15a2-4791-ab89-09921211487f'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '61d316ad-7f5a-4bc1-915f-1336263035cf'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '626915e9-2424-4059-8b6a-fae47161acdf'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '631d9552-1190-4edf-abc9-319139c90bd4'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '63735d98-57b0-429c-8267-40a5f1da06b1'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '64d99cb5-3b4f-4195-b86f-c5f45b4dcd19'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '668553fa-6988-8473-87d8-000071c2a500'): array([[ 0.21261261]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '66f25f1d-1898-4827-bcbb-ca82f15c4d02'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '67055318-bad9-420f-ae31-9ba54456518d'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '69d8569b-a90e-4bf5-8a5d-e8d0c59068cc'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6a9cb1f7-2d28-4fa5-acd0-456cc1cfd72f'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6e02ccfc-9eb5-4a51-be9a-870c1087c833'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6e7c3e56-841c-5199-ddfe-000053de1cfc'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6f0c79d3-c980-4cd5-ae0a-51f7d9a5f472'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '6f2f97dc-2aeb-482c-a20a-9747f0746898'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '72705cd3-348c-49a5-877a-1c947882d1b7'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7381c88b-dc3f-4aff-9ae7-261b8216fac2'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '73cba245-5969-4076-8490-75a236073196'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7411975d-4167-467f-b36d-89eb1e83eeac'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '75178d65-a01b-4108-8871-6b8c78a3ffe2'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '75ee82c9-e3fe-4887-ae1d-050ff7a6a6be'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '76292ccb-383a-44d2-9460-3559057aef47'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '77c1d221-d35c-4753-911b-0ac3dc331794'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '786699f7-8069-49e4-a6e6-dffed3c32314'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7b830424-436d-428c-b2ad-3e93f3115d7b'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7d5b5802-3698-4be8-98f8-ab7c1a2e9328'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7e2b64d5-3c75-4adf-88a6-d54b4bb46d3c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7f401bdd-4116-48ad-b217-013fd904d323'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '7fdc928c-f347-45e7-82d7-046acdf878ae'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '822b9d39-087b-44c5-aff9-602b748294d8'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '826a2a83-e704-48f5-87c4-211cb869cc73'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8519773f-80c3-4982-b871-170dad258d69'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '88e8456c-dc23-4bb4-aed5-a4186a2fbf77'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '891b2f36-c1cb-495a-9f27-be7b583eaf1b'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8a00b5c3-2465-4520-9f43-22a64c846b6c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8b03ce87-7aec-4106-8f9f-752c6174fda3'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8c81249c-0541-4b04-812e-d1578a35c7f1'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8c920eda-3eee-4782-ace6-c706fb363b88'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8d59bb59-b416-41c2-adab-bba044237346'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8d9f20e9-38f2-4a25-bb19-9da1e323fda4'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8f516f52-4ecc-46c6-9029-65de3f05eea4'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '8f5c8cb3-dccd-45da-9f1f-d1c61cd789c3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '902b828c-5b1f-4a1b-ad0f-d795eaaf067c'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '90a5a447-af6f-421a-8201-011f07ad1150'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '91a067cc-543a-4d73-a0c0-feb1f8935756'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '92138f4d-5e83-41fb-a202-6d59c36d5231'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '922b6b30-8dc3-4c66-ba0a-be9738d67f98'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9278dfef-7744-438f-865a-8c264c9de8cb'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9348a45e-047c-4f05-9794-648e9b9dae33'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '93ac2969-a4e9-49b5-8b97-5cbc6b9b2601'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '93c1f160-9027-469e-bbb3-32f2ca951759'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9497544b-a783-486e-a029-1f042de08741'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '94e30f54-58ad-4496-b043-637c688e44e0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9607e93d-3572-461f-bb2c-8597cc23bab0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '975543fa-3eed-4b0c-b87b-50f26630fe89'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '975ae6bf-9a02-4d6f-af7e-8f1253842fed'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '97ad7d9b-eca1-4b54-8b31-9db2527f8518'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99127c79-69f5-4046-a298-3f842c68d62b'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '994d61de-fbb0-4187-a4d4-b11c3c2b9102'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99801a43-d476-4055-8d97-fb7c4ae173d4'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '99f1deff-a149-49bf-b1fd-95f7ff7d1331'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9af35f20-e8f1-4e39-8241-f3e76741dc78'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9b5b8c40-38fe-42fb-8130-56c15e485fd0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9be62afc-89f5-4c81-86b0-e3fec4dbd311'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9c08496f-7895-44f9-8686-fe3154392da4'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   '9f10b83a-5b75-48dd-a103-2d27a2c8a6cb'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a42347d2-09f1-405e-95dd-bf6ac03765d8'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a487b7db-318a-46ff-8e52-2837fab777ad'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a55659bb-d9f2-4904-a2ad-489cd484cf70'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a6888cde-b33b-4bec-9e07-c6f3e6932f24'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a8e39acd-6e7f-4d43-973b-37e6b7c00037'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a97a1cec-673d-448a-b3ba-8ea16fe44973'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'a99a8eaf-2f2c-42c6-b6ce-d5686a9ca249'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'aa6a298f-893f-449d-8573-39f32fd43fe5'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'aa784c1b-0d0b-4c69-b631-b045d6ee61af'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ab1be93d-4439-4a05-8588-d4fe2e177871'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ab3e851e-21c9-47cf-8e7d-5f96dfae3ba5'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'af41f691-3a3e-47a3-9e45-3b4d78469ae0'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b5d37ef1-0d36-4c00-8a38-54bbdc5e1eda'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b6dcefd8-3848-4338-9c3e-fe6e91f20937'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b79e26a0-88db-441f-b79b-508506e81b93'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'b93fac73-b3b1-4825-b1db-c129d404d3f3'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ba94eeb5-4b68-4848-a86e-71a9f3b70a4c'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bba9f623-5919-4ef3-b98d-c94af1553179'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bbcdd18c-4d16-4c28-b031-d988884030a7'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bc55a5b7-5a07-4ba7-87af-6f374d79ef06'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'bd6d11e8-eb49-4664-b065-7bcf9c888053'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c0143eba-3daf-44ad-8d34-6e1d34128ace'): array([[ 0.21261261]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c1513682-45ad-444e-afb5-27c660714e88'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c16d78c6-a944-4bfa-8e7a-b292b5b49d2e'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c24fe83a-3170-49a3-ab67-279d34b8d920'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c3eff967-20d8-4bcd-bd26-2dc2592a37b9'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c3f83a91-4888-41a4-add9-fd01678a1e5f'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c7869c43-266c-429d-bfd5-6b578ed32ce8'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c7d2cf2d-0d21-45f7-9769-b07f3e53b76a'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c8c9bc86-8649-4637-a435-c2b52d5e1ddf'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cbdd7871-f1a9-46ca-bd95-5863d459d34a'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ccc8855c-0628-4741-afe7-1c79d463fadf'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cdbfd224-21fe-457e-a47d-26a525965051'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'cffc8ff1-63bd-40d8-8b91-13cbee6457b3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd0394db1-a1cd-4026-bf50-dd5e47331572'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd10b390c-9d0c-4f59-b31d-3d0d70e77a35'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd1707523-ac5e-4145-9676-386da2a30a7c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd264f35c-7f48-47d8-885b-057bdafa04a3'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd50fbe3f-b265-4fde-bf05-4156fe27b0a3'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd585d599-05f1-47ff-8c41-790f51830b9b'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd73b27a2-81bd-4264-baa5-ce4aca3545be'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'd998622b-6ec3-4082-80b9-22205251fb03'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'dae78878-37f4-4012-a9ea-62a0e9bb6720'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'db6f90ef-27fc-41a8-a541-07efdce1fab5'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'dbcfb8d9-9146-4c0d-8f89-cfd5a3951959'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'de48749a-85cb-4307-8a2b-c9d5830d0bae'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'de94ed71-1e83-40ad-9916-6b7c16d55a6d'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'df1c10b2-021a-4db8-af05-267ceee43385'): array([[ 0.32256771]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'df72bd78-cbf0-4bc8-91c3-710ea579b1d1'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e3c1224d-1958-4fbb-b0e3-91943e5975c7'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e4d65952-4845-473f-bdc8-fb40c20ac3a4'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e6dd1a4b-0a12-4b46-9245-6ec9b63c8255'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e717f3cc-ac70-4c9b-be56-1614239b917e'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e71f95a5-fd82-4128-9fd1-be3f0e85d0fc'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'e97b784a-ec09-4b1b-9f14-cc0ce9799c9e'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ea3bc981-8a35-40e1-82bd-33a12820f98c'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ecdb040b-aae3-495b-804c-e6b3d6f687ff'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'edd772b0-62b3-4148-9391-2d381c7003fa'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ef12e210-aafe-4308-a70a-0baa89a48040'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ef4e5109-025b-4786-860e-9dcc2db701a0'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f05cca02-ec18-4acc-9939-59658ff9a554'): array([[ 0.80302368]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f398a9bd-7a54-4cf3-847d-8a3805c45ee5'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f501d85b-c98a-4319-b687-8a1b4c3ec32b'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f84b2b33-df49-45d4-8949-d5ab8b800656'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f9795c43-391d-4e31-a4ce-bee8259adb03'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'f988c6c1-830d-4f77-a7e2-0c943c606d94'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa288b80-6ef1-4e80-b534-5c2e5c492fd8'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa4d4851-3cab-48a0-a2e4-d3e047323eb6'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fa815715-eeb2-4cfc-b006-0e5877bd5932'): array([[ 1.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fbe76292-b1ff-4efe-8ac6-3a36c4f3c900'): array([[ 0.40226084]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fcb77a5a-6882-4aeb-82a9-ba57688d2224'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fdda4f8e-b620-4df6-92a9-101a251d2f42'): array([[ 0.]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'fe91efc5-25ce-4316-b0d1-43173a755777'): array([[ 0.13629556]]),
#  ('Land transformation, biodiversity, GLO, with uncert',
#   'ff6c4aa2-6baf-4ef2-82d4-14fadaf6b060'): array([[ 0.80302368]]),
#  ('Marine eutrophication, GLO, with uncert',
#   '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'): array([[ 0.]]),
#  ('Marine eutrophication, GLO, with uncert',
#   '1aa538b9-51eb-49fe-8904-de34e58945c7'): array([[ 0.]]),
#  ('Marine eutrophication, GLO, with uncert',
#   '2e493ad7-ff7f-47b8-9966-1d67e0323386'): array([[ 0.]]),
#  ('Marine eutrophication, GLO, with uncert',
#   '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'): array([[ 0.]]),
#  ('Marine eutrophication, GLO, with uncert',
#   'dc084330-5108-4d9c-a7ed-eb3345507f13'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '034f8a4d-d2c9-3242-bfc2-929e373b367c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '0609bdf8-819f-4556-8686-94e3a2476f2e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '07ca6082-954c-3128-9b62-6fc5852b5e5a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '0817641a-ddba-3916-9f67-85ac42fc9529'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '09333058-7adb-4965-aa9f-7d7f7aa47de6'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '09a69d95-307e-4332-a566-1ce37f032853'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '0a89160c-168b-3315-a7f7-5543bc60cedf'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '0e848871-d8b6-457a-a274-dd50fd437502'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   '10e7a3bc-9edc-322b-b3eb-0ca651428c2c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '121b0f77-c14f-393e-8b68-30b46e1a426c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '12604ba6-b7a1-4036-885c-72704b029906'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '12b740b7-b774-336e-817f-d26ade9fff26'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '13af5f43-9b78-382a-adc0-e632e0f2dc9f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1494ba3b-1cbb-366d-b4af-a6038e6dd592'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '14ce1e7c-c545-3acc-aedb-3c75484dc03f'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '154568ac-8185-38bc-9de3-1aab78e98a8c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1702cfd9-5643-3a73-8a00-09755abe9fac'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   '172fec48-5592-3d59-80cc-a4d86eeb1db8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '17c78134-7968-3a3b-8bcd-2a363909e6e3'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '191319b7-f72f-3f3a-b2cd-56ea835f9c35'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '19229850-3ddf-3c30-bfa5-b356b7be2fbd'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '19975317-8737-420c-a405-e7148bdb8d9c'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1a88c7ff-be1f-4134-bf27-c09936d144a8'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1acb026e-9de6-48fe-9e0d-be4d24125bbc'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1ba56136-54c1-3840-ab0c-34f1e333412c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1e74759c-f865-3a12-bf79-6b1df1a9ebc3'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1f31247d-6556-11dd-ad8b-0800200c9a66'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '1fef4759-76ce-4443-9a0e-cfa38c4ce14a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '200b628c-ac2c-3864-bb86-3ac8c5e442d4'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2141caeb-e469-376b-8f78-deb8dded9c7e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '229b3c06-8be1-3415-b776-6bfa63650993'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '22c11859-a872-43da-84ee-bd7423a50f5e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '22f7036b-d608-4e79-844f-7ccf7ca409e8'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '23f4e3e3-c30b-3d45-b888-5263a9484861'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '24422b32-3046-322c-b53b-ccad50a2f4f9'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '25beccea-63c7-3d2b-b7de-287eb4c140f2'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '26d923eb-b44e-3615-b6e0-d72e8c7639f0'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '295e6c24-7c10-4118-a330-0672382000d7'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '29a9157e-42d5-3e71-ab26-dd76fec002d8'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2a8a1088-2664-3b27-8865-b484ecb6d999'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2b04a22c-28fd-309d-acf9-d349d537efbe'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2ba4d6f7-45c2-32af-b377-35ca261dca67'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2d2d23a0-4896-384b-896c-7852db85f132'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2d88cf1e-7aa4-3409-bd12-5da97c133385'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2e5924bd-a303-3800-9293-e3c3f08f4daf'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '2f0c7a7b-a356-32e7-a4bc-8b7659cd280e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '30aa8b31-d824-4c3a-b6b3-d141f710b63f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '31950f2d-17c2-469f-9066-0f6dbb76ce7a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '31b9c5a7-2359-3349-be6f-086fe117cd37'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '341e910f-3799-3a3c-82e9-0ef26c78fd07'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '37683746-5ef6-352c-bb22-7d6bacc6766f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '37fc5b02-751d-3353-b4d4-6fac8ee07b69'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3ac1aaff-7bd1-375e-bcd8-ec7625823843'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3b3a4648-20e6-3efb-adae-ddc7cfaf3c8b'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3c27fe4e-eec8-4bea-91cd-afc0b0ab138f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3e4d9e9e-6556-11dd-ad8b-0800200c9a66'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3f7e0b7e-aefd-4efd-a946-7bdad142fd50'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   '3fc1d5e2-8e32-480a-be55-45b7f42dd0d6'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4089d90f-81cf-37fa-a004-ebbad26d04b3'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '41d2ebdf-efb6-372f-97bb-76f0ccf21e92'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '41f2491f-5305-3954-91b4-73397dcc1ea4'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '433b7ce7-5c2d-41c3-80ef-ead7f45c8699'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '45fa090d-ec34-3e43-b374-bf56e72ad973'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '461b9748-ac92-46d2-96ad-fb63097c0376'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   '468ced72-ed96-3ffe-bd81-584d0605aa21'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '471f0cd8-bd7b-3cea-ade9-8a3293cb7641'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '473aaa0c-5be9-3c1d-8bd9-41e6729abc99'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '474772b5-d4f6-3da7-a081-14c84cddf81d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '47ede456-cb14-44fd-bc8e-01cb1bee4af1'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '47f98e48-4fc8-3d7d-9eec-3920e811b100'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4858a358-5a21-3a3c-a0bb-8db58c91f6d1'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '48ae8335-d233-311c-b5ee-fc554c018671'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4944a588-e3a9-3182-9231-ee8c975f617f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4a1ae352-5361-380b-9bad-a1680e9658fe'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4a57e617-eb1f-4c75-b6d9-61dea2d82295'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4b724d3a-2a1f-3176-a05b-b06c12d0c7e4'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4dbbc4de-4e1b-4b19-b6e4-d89f39a4dd80'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4deca3ec-ae40-460b-b063-35934d4fc936'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4ee18a71-8635-4a40-af0d-79c01d58077d'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '4f07dade-dcfe-384a-b666-513d575b8c9d'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5261c4f4-4abf-3ac2-873a-183e9956e671'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '53d423d2-6313-3983-bd74-6dbf0efa793d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5511e6ea-d68e-39ad-a83d-2f11e9348ea3'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '55e63a8a-224b-36f7-a5c8-f0635363f0f1'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '57196c65-5805-32ae-888e-bde1d00dd671'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '572445fe-ff91-3f7e-8846-a3fddd87ea52'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '585ef0b1-6194-3653-8208-2ef96fb9ef69'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '59357070-8888-3f64-b9a7-1ea875b33e42'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5a19056b-6d15-3a0c-bd00-d184e991d3ab'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5be81c7a-31d9-4b79-b9e4-50e92d78a014'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5d8406dc-0091-38c0-b3ab-3a50bfd7e399'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5d8950af-bf5f-3373-b75e-441c1b5d3743'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5e37f4c5-3ad2-377e-87b7-46e80144b3c2'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5e45aecb-61b2-359e-9393-6f0bbbc4b1f7'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5e73790c-b694-35c4-a642-71bb74188377'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5ef54da5-e7c2-3ac7-a01c-45725d131111'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5f6ecee0-a80d-3172-8c35-d3258079891b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '5f9e8551-455c-393e-86c9-27683f6d9d5f'): array([[ 0.]]),
# ...
#  ('Water availability, human health, GLO, with uncert',
#   '61756661-69cf-31bf-ab1d-18f785e5e36b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6298894f-6ebb-3b82-aa4c-e5fa3c332a09'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '64b8db56-7e67-32da-9f5f-7fbd2a66c03a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '64efcbd6-4217-37a8-acb5-f78df61be29b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '64f910df-cc09-359b-aff3-e90a04c55cc4'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '65e587ee-924c-351b-a6ea-f46547c660ca'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '66e3f915-d5e1-3df9-8e35-3c2cbb83d132'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '67b7362f-588a-492d-a060-fa0a50856668'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '67c40aae-d403-464d-9649-c12695e43ad8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6bb96a1a-3f9a-32e5-b61d-171bd4d6cc95'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6ddcf13b-64d6-33e3-97eb-a14040dddfca'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6e323b42-84de-3746-bc4e-baea6f53e6ab'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6e694082-a3be-3aa5-a2ce-0ff3f1d6b869'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6e9312ec-1e02-4232-9589-0746bc67d4e6'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6efff6a9-428a-4062-b415-3950e32c1dab'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '6f1e33ee-7fc0-3c9c-a9f9-408ad4a7b072'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '71cb08fe-d3f7-3d38-8073-d94815935029'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '72721c4e-d589-4ad7-8c5e-4228b8690ddb'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '75b5c052-b7fa-48f6-8ce8-cfefed1f6fd2'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '76dc4c91-6ffe-43bf-b7d4-ba8c71def0c8'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7a4ce745-2cc7-3746-a9c9-fa54e4b5818c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7a9d85b4-c90c-3c20-bf15-7d1e6ef20c3a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7b492692-f5e0-393c-9e58-0374b38ae9c5'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7e1170d4-99d0-3812-8b94-0c6cd519b58b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7ed8789d-5282-4cb9-901a-cdf5433c2dec'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '7f952328-9a9b-3e3f-9412-2fbfc9bfb8d7'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '831f249e-53f2-49cf-a93c-7cee105f048e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '84f07f02-ead8-37c6-a8f2-f96cc0ebb067'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '86ea740c-2765-34b8-9af6-6e7c7bd1f0b0'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8715a2b5-92a4-3377-8293-7b03c4094cc7'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '875699e1-34cc-3d53-ab91-d88d0cb89c2a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '882c52b9-814b-3acf-9940-c3c39cc271b7'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8c1494a5-4987-4715-aa2d-1908c495f4eb'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8c7323c6-2d9c-3874-91f3-69d87ed3754f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8c75e7ab-8ab8-41e4-b394-c166ff5b050d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8ca8ac08-340a-3d73-9cda-d685c4987950'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8db6a887-3429-371c-8b04-a0f39b44ca7c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8dee1571-3aa3-30b5-96bd-25bfb82df9f0'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8e338a98-3038-3aef-973b-a3b0b86c0244'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '8f6a3319-0f5c-3c12-9b29-b7b1ae510368'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '936081af-f5b2-3dcc-99b7-bf9570452566'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '94506e78-584b-3ad0-bd8a-8f7b2a2508e6'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '94ff3932-5a6d-389c-bb65-c3a348f9f1b2'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '96775c4c-b80d-3cae-8b4e-0eb508071b37'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   '96ad8bf8-e303-4034-a27c-631b5115fa4c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '995f3484-64f1-4d38-bc97-5364463e02b0'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   '99955f8f-0222-3094-af2c-47eeec843957'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '9c369e6e-909b-3828-80eb-97cb53c9fb13'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '9d966161-d561-33f5-9050-8233889024b0'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '9df90c6b-2bac-35c1-b7fc-943f3ca23c7f'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '9e0de545-41c5-4d35-897d-561df22e6272'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   '9ff8ff07-805b-3902-a5d3-a7373eb706e8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a16ffdac-79e9-3a72-9cc2-26b926ff349f'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a19c6dec-d1ef-3dfa-8e97-6871a9a5e669'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a2a9cda7-9dd0-4a39-b422-f45298906dd8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a3f36ce8-73ad-38a8-9073-16558ed96158'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a5a6f52b-e9e0-39b8-8cf6-9e5f4cb7e258'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a65f41ac-79d1-373e-8212-e030d7a2290e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a7bbf899-f764-3025-91ee-43b59036b5d0'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a92767f6-04ba-3c3f-b7e8-3551f19346b6'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'a945fa6e-b056-4eec-b684-cf42e461d64c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ab92ef07-03ba-3f2c-8568-0805e78fad4d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'abc1487f-7ac2-3aed-b04d-105a47d73e16'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'acb7676c-2874-3e55-b74a-0aa3144f9362'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ad1dac87-cd0a-350c-8848-4f1fc289cb3a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ae1e393b-8ec0-3060-b98c-945b00f012c1'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'aec504f6-5f16-3830-ab89-122a01e43efb'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'af44fff2-0c47-3785-b610-c950776f117a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b1989cfb-9f7e-32fd-b93d-679cf5940c48'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b1f08696-54fa-458d-9a6b-af614db865e6'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b2473da9-b49b-38b8-996d-a682ae82cae2'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b28303de-9da9-3c1b-bf30-49b5fad9e452'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b297cf0c-23c3-34a8-9cdf-586650be58fd'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b5e65e84-a1e1-3a02-a74f-8e6a9c0b2ad6'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b77bffdd-d035-368c-a735-a37ca4640331'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b84a7e1e-2ed1-3f04-80d0-d7f5ed16245b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b8d4fe11-af72-3603-adae-44d0524e0857'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b8e26d9b-b07b-45b7-a2dc-5320a8934416'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b94df422-b76f-3d10-91ef-83dc99967b51'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'b9f02930-d0e3-3144-92bf-1babde3b17d8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'bb15f4ab-42e1-4f4a-8e48-3a3fb9d90155'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   'bea8ee06-61e8-4770-abce-6ed950985dfe'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'beb8d1f8-7819-321d-a32d-ab3884121e7b'): array([[  2.60670898e-09]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c0f39d6f-dd5a-4465-9dee-b0c5f897d175'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c17215a3-b80a-3372-810c-ccc92b97d3ef'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c266520e-f671-3990-99dd-057fa51ebfe6'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c32bea0d-1d42-36dd-aeac-9a7b16696eba'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c39ddc68-60d8-32e9-a0ce-05125d213c0d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c5294e60-47a2-3ba3-bd8d-12cec538bb7a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c56bfea1-912d-468f-ba43-bef7c14c8c1e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c6424dad-5233-328c-9752-b5a2378726be'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c7024325-1fdf-3d70-b078-a34cc49c6db6'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c76abb6e-4dff-3c0f-b3d9-80be0f80ec3e'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'c9eaca71-6924-483f-9e86-51265bc0e9ef'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ca0d7b64-6044-3a7c-af04-ae23b94edb7b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ce9fd979-2f96-3b4f-b09a-94df06fb3feb'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd022cb79-66cc-3668-bfd6-dc2549d6179b'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd340bcfb-77bb-34f2-8052-b598a2cdf17e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd40062f6-9cad-3324-84dd-d8f194a5005d'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd4e91995-843c-380f-9b1d-e73eb87989d3'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd512585c-a3ff-3bd4-8854-3d23c14926c0'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd73cbb05-f4f8-3e7c-be7b-1226f429335b'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd78b41a7-b3f3-328f-9e55-0a9836c86c6e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd84c58f8-bc2a-3fed-badd-2a35ec5e4c6a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'd9c3f006-e25d-3beb-98c1-ed5cc01ce96c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'de7f555b-1fed-4087-b06e-5fb145ca33eb'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'debe7510-db87-4df7-bf4c-cfb3a622edb1'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'df74eba0-aca1-3b76-982f-16bebb424870'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'df77647b-d3ea-3476-a665-4d435343ff5d'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e0065ac9-4578-3e8d-9338-fd99a299ae46'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e0241436-ad0b-40ab-90f8-db4fd79f4e8c'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e07f3eae-2be2-4768-bb89-11e5bf4c743e'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e0e6bb44-1b7b-4d85-a3f8-1ee6a1e983d4'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e273a57d-19bd-3a0e-abc7-d6e32bc320dd'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e30bc01a-26c4-33dc-90b1-2976a9dd2785'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e329aa39-56b8-3015-abd0-efba8fae94cb'): array([[ 0.00089165]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e51e9393-0c77-3bd0-897c-1e3a4729196a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e6bf7393-ca27-36b6-89d0-0c155afe959a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e86c6358-1283-31b1-af5d-6bf05fc58ff8'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e8e6e8f7-373e-3381-b6cf-bb6d4ddb2d76'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'e9649289-4111-3ec4-80fd-770952c30c49'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'ea46e7e8-e9b6-31ac-be23-52f09bf73782'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'eba958f5-ffe1-3f4b-8f2c-8bc7b5a9b275'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'eba9b309-7926-37da-a4c5-0d4c2ef894f9'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f1a90356-cac4-3eb4-8619-eabe3d45c696'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f1bc0318-5825-3ea8-b36a-53c0b602c412'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f1bdb3e1-1235-4939-a4a0-6383caa42c63'): array([[ 0.00056224]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f1ca67fc-fd5c-3179-aeb9-c689f7a8a2af'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f31750b0-268a-4d18-b694-8e79e91aff86'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f4ed16d1-aacb-344f-ab16-aeb44de80128'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f7baa589-bb9c-36c2-8ac2-4e23874315b5'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f835e4b9-3073-4547-ab20-ba20886fd6a3'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f838aec9-cb26-4597-bb6f-478cdf32e32a'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'f87edd21-d830-3d32-aeee-e69320033ccd'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'fc1c42ce-a759-49fa-b987-f1ec5e503db1'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'fe0acd60-3ddc-11dd-ae59-0050c2490048'): array([[ 0.]]),
#  ('Water availability, human health, GLO, with uncert',
#   'feae94ff-e17a-3b3a-af20-6a50b822c273'): array([[ 0.00056224]])}

# %% [markdown]
# Bounds and cdf seems to be valid
