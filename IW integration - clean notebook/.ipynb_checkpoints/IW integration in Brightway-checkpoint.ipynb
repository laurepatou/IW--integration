# %% [markdown]
# # IW+ integration for regionalized and not regionalized impact categories

# %%
import brightway2 as bw
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python
import csv
import stats_arrays

# %%
bw.projects.set_current('iw_integration')

# %% [markdown]
# ## Cleaning all previous versions of IW integration in the project

# %%
def impact_method_delete(impact_method_name):
    
    impact_method=bw.Method(impact_method_name)
    impact_method.deregister()
    del impact_method
    
    return;

# %%
ic_name_to_delete=[ic_name for ic_name in bw.methods if 'IMPACTWorld+' in str(ic_name)]
len(ic_name_to_delete)
# Out:
# 54

# %%
for ic_name in ic_name_to_delete:
    impact_method_delete(ic_name)

# %%
ic_name_to_delete=[ic_name for ic_name in bw.methods if 'IMPACTWorld+' in str(ic_name)]
len(ic_name_to_delete)
# Out:
# 0

# %% [markdown]
# ## Load impact method from csv file

# %%
path_to_input_csv=r'D:\Dropbox (MAGI)\IMPACT World+\Brightway-Implementation\IW integration\csv file input for BW2\All IC.csv'
iw_olca_uncert = csv.DictReader(open(path_to_input_csv, "r"), delimiter=";")
iw_olca_uncert_list=[cf for cf in iw_olca_uncert]
iw_olca_uncert_dict={(cf['impact_cat_name'],cf['ef_UUID']):cf for cf in iw_olca_uncert_list}
iw_olca_uncert_dict
# Out:
# {('Freshwater acidification',
#   '9990b51b-7023-4700-bca0-1a32ef921f74'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '1.846715481'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000424631'),
#               ('uncert_param2', '1.846715481'),
#               ('uncert_param3', '1645.674497'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '9990b51b-7023-4700-bca0-1a32ef921f74'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '1.846715481'),
#               ('IW_Sample_CF_Variance', '45.17071068'),
#               ('IW_Sample_CF_Std dev', '6.72091591'),
#               ('IW_Sample_CF_Min', '0.000424631'),
#               ('IW_Sample_CF_Max', '1645.674497'),
#               ('beta_param_min', '0.000424631'),
#               ('beta_param_max', '1645.674497'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '0f440cc0-0f74-446d-99d6-8ff0e97a2444'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '1.846715481'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000424631'),
#               ('uncert_param2', '1.846715481'),
#               ('uncert_param3', '1645.674497'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '0f440cc0-0f74-446d-99d6-8ff0e97a2444'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '1.846715481'),
#               ('IW_Sample_CF_Variance', '45.17071068'),
#               ('IW_Sample_CF_Std dev', '6.72091591'),
#               ('IW_Sample_CF_Min', '0.000424631'),
#               ('IW_Sample_CF_Max', '1645.674497'),
#               ('beta_param_min', '0.000424631'),
#               ('beta_param_max', '1645.674497'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '2b50f643-216a-412b-a0e5-5946867aa2ed'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '1.846715481'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000424631'),
#               ('uncert_param2', '1.846715481'),
#               ('uncert_param3', '1645.674497'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '2b50f643-216a-412b-a0e5-5946867aa2ed'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '1.846715481'),
#               ('IW_Sample_CF_Variance', '45.17071068'),
#               ('IW_Sample_CF_Std dev', '6.72091591'),
#               ('IW_Sample_CF_Min', '0.000424631'),
#               ('IW_Sample_CF_Max', '1645.674497'),
#               ('beta_param_min', '0.000424631'),
#               ('beta_param_max', '1645.674497'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '1.846715481'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000424631'),
#               ('uncert_param2', '1.846715481'),
#               ('uncert_param3', '1645.674497'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '1.846715481'),
#               ('IW_Sample_CF_Variance', '45.17071068'),
#               ('IW_Sample_CF_Std dev', '6.72091591'),
#               ('IW_Sample_CF_Min', '0.000424631'),
#               ('IW_Sample_CF_Max', '1645.674497'),
#               ('beta_param_min', '0.000424631'),
#               ('beta_param_max', '1645.674497'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '1.846715481'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000424631'),
#               ('uncert_param2', '1.846715481'),
#               ('uncert_param3', '1645.674497'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '1.846715481'),
#               ('IW_Sample_CF_Variance', '45.17071068'),
#               ('IW_Sample_CF_Std dev', '6.72091591'),
#               ('IW_Sample_CF_Min', '0.000424631'),
#               ('IW_Sample_CF_Max', '1645.674497'),
#               ('beta_param_min', '0.000424631'),
#               ('beta_param_max', '1645.674497'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '0e0f75b3-2de4-4fbd-aee5-e0406b593ea8'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonia, as N'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '2.246005314'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000516443'),
#               ('uncert_param2', '2.246005314'),
#               ('uncert_param3', '2001.49601'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '0e0f75b3-2de4-4fbd-aee5-e0406b593ea8'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '1.216216216'),
#               ('IW_Sample_CF_Mean', '2.246005314'),
#               ('IW_Sample_CF_Variance', '66.81569695'),
#               ('IW_Sample_CF_Std dev', '8.174086918'),
#               ('IW_Sample_CF_Min', '0.000516443'),
#               ('IW_Sample_CF_Max', '2001.49601'),
#               ('beta_param_min', '0.000516443'),
#               ('beta_param_max', '2001.49601'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '11f41c41-7733-49bc-b1b1-1f00fbade521'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium carbonate'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '0.652838878'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000150113'),
#               ('uncert_param2', '0.652838878'),
#               ('uncert_param3', '581.7681736'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '11f41c41-7733-49bc-b1b1-1f00fbade521'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.353513514'),
#               ('IW_Sample_CF_Mean', '0.652838878'),
#               ('IW_Sample_CF_Variance', '5.645065212'),
#               ('IW_Sample_CF_Std dev', '2.375934598'),
#               ('IW_Sample_CF_Min', '0.000150113'),
#               ('IW_Sample_CF_Max', '581.7681736'),
#               ('beta_param_min', '0.000150113'),
#               ('beta_param_max', '581.7681736'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'd40b90a8-c469-41ec-b5ea-f80386859a82'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium carbonate'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.652838878'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000150113'),
#               ('uncert_param2', '0.652838878'),
#               ('uncert_param3', '581.7681736'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'd40b90a8-c469-41ec-b5ea-f80386859a82'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.353513514'),
#               ('IW_Sample_CF_Mean', '0.652838878'),
#               ('IW_Sample_CF_Variance', '5.645065212'),
#               ('IW_Sample_CF_Std dev', '2.375934598'),
#               ('IW_Sample_CF_Min', '0.000150113'),
#               ('IW_Sample_CF_Max', '581.7681736'),
#               ('beta_param_min', '0.000150113'),
#               ('beta_param_max', '581.7681736'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium carbonate'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '0.652838878'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000150113'),
#               ('uncert_param2', '0.652838878'),
#               ('uncert_param3', '581.7681736'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '15c4a3e0-bd82-4acd-a8fd-58aba60dd9fc'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.353513514'),
#               ('IW_Sample_CF_Mean', '0.652838878'),
#               ('IW_Sample_CF_Variance', '5.645065212'),
#               ('IW_Sample_CF_Std dev', '2.375934598'),
#               ('IW_Sample_CF_Min', '0.000150113'),
#               ('IW_Sample_CF_Max', '581.7681736'),
#               ('beta_param_min', '0.000150113'),
#               ('beta_param_max', '581.7681736'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '73ec59d7-a227-407f-963a-fd9c61b4d172'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium carbonate'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '0.652838878'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000150113'),
#               ('uncert_param2', '0.652838878'),
#               ('uncert_param3', '581.7681736'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '73ec59d7-a227-407f-963a-fd9c61b4d172'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.353513514'),
#               ('IW_Sample_CF_Mean', '0.652838878'),
#               ('IW_Sample_CF_Variance', '5.645065212'),
#               ('IW_Sample_CF_Std dev', '2.375934598'),
#               ('IW_Sample_CF_Min', '0.000150113'),
#               ('IW_Sample_CF_Max', '581.7681736'),
#               ('beta_param_min', '0.000150113'),
#               ('beta_param_max', '581.7681736'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'c36f35d1-e815-4c85-8686-1a2d21264a2c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium carbonate'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.652838878'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000150113'),
#               ('uncert_param2', '0.652838878'),
#               ('uncert_param3', '581.7681736'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'c36f35d1-e815-4c85-8686-1a2d21264a2c'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.353513514'),
#               ('IW_Sample_CF_Mean', '0.652838878'),
#               ('IW_Sample_CF_Variance', '5.645065212'),
#               ('IW_Sample_CF_Std dev', '2.375934598'),
#               ('IW_Sample_CF_Min', '0.000150113'),
#               ('IW_Sample_CF_Max', '581.7681736'),
#               ('beta_param_min', '0.000150113'),
#               ('beta_param_max', '581.7681736'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'e3edc996-b5bb-4465-b9e4-29eb368ab0e0'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium nitrate'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.392095378'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.392095378'),
#               ('uncert_param3', '46.03801918'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'e3edc996-b5bb-4465-b9e4-29eb368ab0e0'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.490613267'),
#               ('IW_Sample_CF_Mean', '0.392121583'),
#               ('IW_Sample_CF_Variance', '0.439687228'),
#               ('IW_Sample_CF_Std dev', '0.663089155'),
#               ('IW_Sample_CF_Min', '0.001180505'),
#               ('IW_Sample_CF_Max', '46.03801918'),
#               ('beta_param_min', '0.001180505'),
#               ('beta_param_max', '46.03801918'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '887bfb8e-44de-4de0-b47d-bc49db8adec1'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium, ion'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '1.746893022'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000401678'),
#               ('uncert_param2', '1.746893022'),
#               ('uncert_param3', '1556.719119'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '887bfb8e-44de-4de0-b47d-bc49db8adec1'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.945945946'),
#               ('IW_Sample_CF_Mean', '1.746893022'),
#               ('IW_Sample_CF_Variance', '40.41937223'),
#               ('IW_Sample_CF_Std dev', '6.357623159'),
#               ('IW_Sample_CF_Min', '0.000401678'),
#               ('IW_Sample_CF_Max', '1556.719119'),
#               ('beta_param_min', '0.000401678'),
#               ('beta_param_max', '1556.719119'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'e1d913d8-214c-4957-b3e5-36ccc50f3724'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium, ion'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '1.746893022'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000401678'),
#               ('uncert_param2', '1.746893022'),
#               ('uncert_param3', '1556.719119'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'e1d913d8-214c-4957-b3e5-36ccc50f3724'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.945945946'),
#               ('IW_Sample_CF_Mean', '1.746893022'),
#               ('IW_Sample_CF_Variance', '40.41937223'),
#               ('IW_Sample_CF_Std dev', '6.357623159'),
#               ('IW_Sample_CF_Min', '0.000401678'),
#               ('IW_Sample_CF_Max', '1556.719119'),
#               ('beta_param_min', '0.000401678'),
#               ('beta_param_max', '1556.719119'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '615c56b4-3328-43b3-b1cd-feb6b6a5d99c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium, ion'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '1.746893022'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000401678'),
#               ('uncert_param2', '1.746893022'),
#               ('uncert_param3', '1556.719119'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '615c56b4-3328-43b3-b1cd-feb6b6a5d99c'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.945945946'),
#               ('IW_Sample_CF_Mean', '1.746893022'),
#               ('IW_Sample_CF_Variance', '40.41937223'),
#               ('IW_Sample_CF_Std dev', '6.357623159'),
#               ('IW_Sample_CF_Min', '0.000401678'),
#               ('IW_Sample_CF_Max', '1556.719119'),
#               ('beta_param_min', '0.000401678'),
#               ('beta_param_max', '1556.719119'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'e1f2ab0a-6d4e-4705-9e8c-db67155d14f6'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium, ion'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '1.746893022'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000401678'),
#               ('uncert_param2', '1.746893022'),
#               ('uncert_param3', '1556.719119'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'e1f2ab0a-6d4e-4705-9e8c-db67155d14f6'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.945945946'),
#               ('IW_Sample_CF_Mean', '1.746893022'),
#               ('IW_Sample_CF_Variance', '40.41937223'),
#               ('IW_Sample_CF_Std dev', '6.357623159'),
#               ('IW_Sample_CF_Min', '0.000401678'),
#               ('IW_Sample_CF_Max', '1556.719119'),
#               ('beta_param_min', '0.000401678'),
#               ('beta_param_max', '1556.719119'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '08a91e70-3ddc-11dd-954d-0050c2490048'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Ammonium, ion'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '1.746893022'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0.000401678'),
#               ('uncert_param2', '1.746893022'),
#               ('uncert_param3', '1556.719119'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '08a91e70-3ddc-11dd-954d-0050c2490048'),
#               ('IW_ef', 'NH3'),
#               ('Stoechiometric_ratio', '0.945945946'),
#               ('IW_Sample_CF_Mean', '1.746893022'),
#               ('IW_Sample_CF_Variance', '40.41937223'),
#               ('IW_Sample_CF_Std dev', '6.357623159'),
#               ('IW_Sample_CF_Min', '0.000401678'),
#               ('IW_Sample_CF_Max', '1556.719119'),
#               ('beta_param_min', '0.000401678'),
#               ('beta_param_max', '1556.719119'),
#               ('beta_param_alpha', '0.074258037'),
#               ('beta_param_beta', '66.11494813'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '15ca802b-f541-44aa-bd33-35560a053193'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '15ca802b-f541-44aa-bd33-35560a053193'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'cbd70647-6237-462a-9d01-d197a8b08506'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'cbd70647-6237-462a-9d01-d197a8b08506'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '205617ae-ebc5-4245-8df6-8710d5d40615'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '205617ae-ebc5-4245-8df6-8710d5d40615'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '0e9e6b81-0a68-4350-8368-566c083bd3e0'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '0e9e6b81-0a68-4350-8368-566c083bd3e0'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '5e7cf95c-9cc3-4479-89af-55377b3db99c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '5e7cf95c-9cc3-4479-89af-55377b3db99c'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'e8c30bb3-92cc-41c8-acf3-281095e570cc'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate compounds'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'e8c30bb3-92cc-41c8-acf3-281095e570cc'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '65bff69f-3b58-457c-bb21-45ad200b04e2'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrate compounds'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.592144041'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.592144041'),
#               ('uncert_param3', '69.52680448'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '65bff69f-3b58-457c-bb21-45ad200b04e2'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.740926158'),
#               ('IW_Sample_CF_Mean', '0.592183615'),
#               ('IW_Sample_CF_Variance', '1.002801858'),
#               ('IW_Sample_CF_Std dev', '1.001399949'),
#               ('IW_Sample_CF_Min', '0.001782803'),
#               ('IW_Sample_CF_Max', '69.52680448'),
#               ('beta_param_min', '0.001782803'),
#               ('beta_param_max', '69.52680448'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitric acid'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '0.584142094'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.584142094'),
#               ('uncert_param3', '68.58725307'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '37d014cb-8c2d-4c98-ab5c-2d4550822c2f'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.730913642'),
#               ('IW_Sample_CF_Mean', '0.584181134'),
#               ('IW_Sample_CF_Variance', '0.975882232'),
#               ('IW_Sample_CF_Std dev', '0.987867517'),
#               ('IW_Sample_CF_Min', '0.001758711'),
#               ('IW_Sample_CF_Max', '68.58725307'),
#               ('beta_param_min', '0.001758711'),
#               ('beta_param_max', '68.58725307'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitric acid'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.584142094'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.584142094'),
#               ('uncert_param3', '68.58725307'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '0d1d9119-44bf-4c8e-a878-cdc78fd888ae'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.730913642'),
#               ('IW_Sample_CF_Mean', '0.584181134'),
#               ('IW_Sample_CF_Variance', '0.975882232'),
#               ('IW_Sample_CF_Std dev', '0.987867517'),
#               ('IW_Sample_CF_Min', '0.001758711'),
#               ('IW_Sample_CF_Max', '68.58725307'),
#               ('beta_param_min', '0.001758711'),
#               ('beta_param_max', '68.58725307'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '2e493ad7-ff7f-47b8-9966-1d67e0323386'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitric acid'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '0.584142094'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.584142094'),
#               ('uncert_param3', '68.58725307'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '2e493ad7-ff7f-47b8-9966-1d67e0323386'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.730913642'),
#               ('IW_Sample_CF_Mean', '0.584181134'),
#               ('IW_Sample_CF_Variance', '0.975882232'),
#               ('IW_Sample_CF_Std dev', '0.987867517'),
#               ('IW_Sample_CF_Min', '0.001758711'),
#               ('IW_Sample_CF_Max', '68.58725307'),
#               ('beta_param_min', '0.001758711'),
#               ('beta_param_max', '68.58725307'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '1aa538b9-51eb-49fe-8904-de34e58945c7'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitric acid'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '0.584142094'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.584142094'),
#               ('uncert_param3', '68.58725307'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '1aa538b9-51eb-49fe-8904-de34e58945c7'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.730913642'),
#               ('IW_Sample_CF_Mean', '0.584181134'),
#               ('IW_Sample_CF_Variance', '0.975882232'),
#               ('IW_Sample_CF_Std dev', '0.987867517'),
#               ('IW_Sample_CF_Min', '0.001758711'),
#               ('IW_Sample_CF_Max', '68.58725307'),
#               ('beta_param_min', '0.001758711'),
#               ('beta_param_max', '68.58725307'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'dc084330-5108-4d9c-a7ed-eb3345507f13'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitric acid'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.584142094'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.584142094'),
#               ('uncert_param3', '68.58725307'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'dc084330-5108-4d9c-a7ed-eb3345507f13'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '0.730913642'),
#               ('IW_Sample_CF_Mean', '0.584181134'),
#               ('IW_Sample_CF_Variance', '0.975882232'),
#               ('IW_Sample_CF_Std dev', '0.987867517'),
#               ('IW_Sample_CF_Min', '0.001758711'),
#               ('IW_Sample_CF_Max', '68.58725307'),
#               ('beta_param_min', '0.001758711'),
#               ('beta_param_max', '68.58725307'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '9af58019-22ff-4278-8f48-8e94b49aae5c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrite'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '9af58019-22ff-4278-8f48-8e94b49aae5c'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'b7ba3697-434d-4f47-91a1-f5b924871d92'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrite'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'b7ba3697-434d-4f47-91a1-f5b924871d92'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'f37a3611-f6a5-4141-8d16-6eac6a1e9a52'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrite'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'f37a3611-f6a5-4141-8d16-6eac6a1e9a52'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'd9945575-a965-4bf3-9cd7-584263172abd'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrogen dioxide'),
#               ('flow_category_subcompart', 'high population density'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', 'd9945575-a965-4bf3-9cd7-584263172abd'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '003697f1-54e9-409e-8179-23a95e99e4d7'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrogen dioxide'),
#               ('flow_category_subcompart', 'low population density'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '003697f1-54e9-409e-8179-23a95e99e4d7'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '9fb048e8-b1c4-4b1a-b536-5467d511f75a'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrogen dioxide'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '9fb048e8-b1c4-4b1a-b536-5467d511f75a'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '4490af97-53d7-4849-aa85-34b5a50e516b'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrogen dioxide'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '4490af97-53d7-4849-aa85-34b5a50e516b'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   '0b7e10a8-6ca0-4a50-a39b-f2a019cb3610'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Freshwater acidification'),
#               ('flow_name', 'Nitrogen dioxide'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '0.799194406'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0.799194406'),
#               ('uncert_param3', '93.83769727'),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '0b7e10a8-6ca0-4a50-a39b-f2a019cb3610'),
#               ('IW_ef', 'NOx'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0.799247818'),
#               ('IW_Sample_CF_Variance', '1.826691782'),
#               ('IW_Sample_CF_Std dev', '1.35155162'),
#               ('IW_Sample_CF_Min', '0.002406182'),
#               ('IW_Sample_CF_Max', '93.83769727'),
#               ('beta_param_min', '0.002406182'),
#               ('beta_param_max', '93.83769727'),
#               ('beta_param_alpha', '0.336155493'),
#               ('beta_param_beta', '39.24918627'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Freshwater acidification',
#   'ca31b010-acd3-4736-a76c-e4a900ae4809'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
# ...
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to urban, green area'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '276c95b8-3eb7-42e9-9bb7-f8125e33f486'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name',
#                'Transformation, to urban/industrial fallow (non-use)'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '276c95b8-3eb7-42e9-9bb7-f8125e33f486'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to water bodies'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', 'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to water bodies, artificial'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '426e316e-db90-40ec-9f45-fa08e6db160c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to water bodies, artificial'),
#               ('flow_category_subcompart', 'unspecified resource'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '426e316e-db90-40ec-9f45-fa08e6db160c'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to water courses, artificial'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '7e2b64d5-3c75-4adf-88a6-d54b4bb46d3c'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to water courses, artificial'),
#               ('flow_category_subcompart', 'unspecified resource'),
#               ('CF_formula', '168.8913863'),
#               ('uncert_type_name', 'triangle'),
#               ('uncert_param1', '166.2035984'),
#               ('uncert_param2', '168.8913863'),
#               ('uncert_param3', '183.7061033'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '7e2b64d5-3c75-4adf-88a6-d54b4bb46d3c'),
#               ('IW_ef', 'Artificial areas'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '168.8913863'),
#               ('IW_Sample_CF_Variance', '39.81881693'),
#               ('IW_Sample_CF_Std dev', '6.310215284'),
#               ('IW_Sample_CF_Min', '166.2035984'),
#               ('IW_Sample_CF_Max', '183.7061033'),
#               ('beta_param_min', '166.2035984'),
#               ('beta_param_max', '183.7061033'),
#               ('beta_param_alpha', '1.88E-15'),
#               ('beta_param_beta', '1.03E-14'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '9a0fe971-083d-4a5c-a12d-4f69882818e2'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to wetland, coastal (non-use)'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '0'),
#               ('uncert_type_name', 'none'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0'),
#               ('uncert_param3', '0'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '9a0fe971-083d-4a5c-a12d-4f69882818e2'),
#               ('IW_ef', 'Forest/Grassland, not used'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0'),
#               ('IW_Sample_CF_Variance', '0'),
#               ('IW_Sample_CF_Std dev', '0'),
#               ('IW_Sample_CF_Min', '0'),
#               ('IW_Sample_CF_Max', '0'),
#               ('beta_param_min', '0'),
#               ('beta_param_max', '0'),
#               ('beta_param_alpha', '0'),
#               ('beta_param_beta', '0'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Land transformation, biodiversity',
#   '56d0a956-0af8-4093-8504-a08b27dd2a68'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Land transformation, biodiversity'),
#               ('flow_name', 'Transformation, to wetland, inland (non-use)'),
#               ('flow_category_subcompart', 'land'),
#               ('CF_formula', '0'),
#               ('uncert_type_name', 'none'),
#               ('uncert_param1', '0'),
#               ('uncert_param2', '0'),
#               ('uncert_param3', '0'),
#               ('CF_per_unit_name', 'm2'),
#               ('ef_UUID', '56d0a956-0af8-4093-8504-a08b27dd2a68'),
#               ('IW_ef', 'Forest/Grassland, not used'),
#               ('Stoechiometric_ratio', '1'),
#               ('IW_Sample_CF_Mean', '0'),
#               ('IW_Sample_CF_Variance', '0'),
#               ('IW_Sample_CF_Std dev', '0'),
#               ('IW_Sample_CF_Min', '0'),
#               ('IW_Sample_CF_Max', '0'),
#               ('beta_param_min', '0'),
#               ('beta_param_max', '0'),
#               ('beta_param_alpha', '0'),
#               ('beta_param_beta', '0'),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Global warming, long-term, ecosystem',
#   '467a7c34-1352-4793-b50f-e8c96e47058e'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Global warming, long-term, ecosystem'),
#               ('flow_name',
#                '1-Propanol, 3,3,3-trifluoro-2,2-bis(trifluoromethyl)-, HFE-7100'),
#               ('flow_category_subcompart', 'unspecified air'),
#               ('CF_formula', '6.68'),
#               ('uncert_type_name', 'None'),
#               ('uncert_param1', ''),
#               ('uncert_param2', ''),
#               ('uncert_param3', ''),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '467a7c34-1352-4793-b50f-e8c96e47058e'),
#               ('IW_ef', ''),
#               ('Stoechiometric_ratio', ''),
#               ('IW_Sample_CF_Mean', ''),
#               ('IW_Sample_CF_Variance', ''),
#               ('IW_Sample_CF_Std dev', ''),
#               ('IW_Sample_CF_Min', ''),
#               ('IW_Sample_CF_Max', ''),
#               ('beta_param_min', ''),
#               ('beta_param_max', ''),
#               ('beta_param_alpha', ''),
#               ('beta_param_beta', ''),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Global warming, long-term, ecosystem',
#   '5200a790-7832-4cfe-a1b9-56be351db475'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Global warming, long-term, ecosystem'),
#               ('flow_name',
#                '1-Propanol, 3,3,3-trifluoro-2,2-bis(trifluoromethyl)-, HFE-7100'),
#               ('flow_category_subcompart',
#                'low population density, long-term'),
#               ('CF_formula', '6.68'),
#               ('uncert_type_name', 'None'),
#               ('uncert_param1', ''),
#               ('uncert_param2', ''),
#               ('uncert_param3', ''),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '5200a790-7832-4cfe-a1b9-56be351db475'),
#               ('IW_ef', ''),
#               ('Stoechiometric_ratio', ''),
#               ('IW_Sample_CF_Mean', ''),
#               ('IW_Sample_CF_Variance', ''),
#               ('IW_Sample_CF_Std dev', ''),
#               ('IW_Sample_CF_Min', ''),
#               ('IW_Sample_CF_Max', ''),
#               ('beta_param_min', ''),
#               ('beta_param_max', ''),
#               ('beta_param_alpha', ''),
#               ('beta_param_beta', ''),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ('Global warming, long-term, ecosystem',
#   '48b0b2ef-7c80-414e-9d0a-6d54de9cbcb3'): OrderedDict([('impact_method_name',
#                'IMPACTWorld+ (Default_Recommended_Endpoint 1_36)'),
#               ('impact_cat_name', 'Global warming, long-term, ecosystem'),
#               ('flow_name',
#                '1-Propanol, 3,3,3-trifluoro-2,2-bis(trifluoromethyl)-, HFE-7100'),
#               ('flow_category_subcompart',
#                'lower stratosphere + upper troposphere'),
#               ('CF_formula', '6.68'),
#               ('uncert_type_name', 'None'),
#               ('uncert_param1', ''),
#               ('uncert_param2', ''),
#               ('uncert_param3', ''),
#               ('CF_per_unit_name', 'kg'),
#               ('ef_UUID', '48b0b2ef-7c80-414e-9d0a-6d54de9cbcb3'),
#               ('IW_ef', ''),
#               ('Stoechiometric_ratio', ''),
#               ('IW_Sample_CF_Mean', ''),
#               ('IW_Sample_CF_Variance', ''),
#               ('IW_Sample_CF_Std dev', ''),
#               ('IW_Sample_CF_Min', ''),
#               ('IW_Sample_CF_Max', ''),
#               ('beta_param_min', ''),
#               ('beta_param_max', ''),
#               ('beta_param_alpha', ''),
#               ('beta_param_beta', ''),
#               ('CF_unit', 'PDF.m2.yr')]),
#  ...}

# %% [markdown]
# ## Creating uncertainty dictionaries for each CFs.
#
# The priority order for the choice of distribution is :
# - 4 params Beta distribution if alpha and beta positive or No distribution if specified
# - if alpha and beta negative, Triangular distribution with moment method
# - if mode_triangular<minimum, Bounded Normal with moment method (no problem with negative CFs)

# %%
from stats_arrays import MCRandomNumberGenerator, UncertaintyBase

def uncert_dict_triang_moment_method(sample_min,sample_mean,sample_max):
    
    mode = 3 * sample_mean - sample_min - sample_max
    
    if mode < sample_min:
        uncert_dict={'amount': sample_mean,
                'uncertainty type': stats_arrays.NoUncertainty.id};
    else:
        uncert_dict={'amount': sample_mean,
                'loc': mode,
                'maximum': sample_max,
                'minimum': sample_min,
                'uncertainty type': stats_arrays.TriangularUncertainty.id};
        
    return uncert_dict;


# Work if the distribution is defined in the core BW code
def test_distrib(ID,uncert_dict):
    params_distrib = UncertaintyBase.from_dicts(uncert_dict)
    mcrng_distrib = MCRandomNumberGenerator(params_distrib)
    try:
        mcrng_distrib.next()
        return;
    except:
        tuple_error=(ID,uncert_dict)
        return tuple_error;

# %%
def create_uncert_dict_bw(iw_olca_uncert_dict):

    iw_uncert_dict_bw={}
    iw_uncert_beta_distrib={}
    iw_uncert_none_distrib={}
    iw_uncert_triang_distrib={}
    iw_uncert_normal_distrib={}

    list_error_generalized_beta=[]
    list_error_triang=[]
    list_error_normal=[]

    i=0

    id_4_params_beta_distrib=14

    for cf in iw_olca_uncert_dict:

        i=i+1

        amount=float(iw_olca_uncert_dict[cf]['CF_formula'])
        uncert_type=iw_olca_uncert_dict[cf]['uncert_type_name']

        #CF with no uncertainty
        if uncert_type.lower()=="none":
            uncert_dict=amount
            iw_uncert_dict_bw[cf]=uncert_dict
            iw_uncert_none_distrib[cf]=uncert_dict
            continue
        else:        
            alpha=float(iw_olca_uncert_dict[cf]['beta_param_alpha'])
            beta=float(iw_olca_uncert_dict[cf]['beta_param_beta'])
            minimum=float(iw_olca_uncert_dict[cf]['beta_param_min'])
            maximum=float(iw_olca_uncert_dict[cf]['beta_param_max'])
            mean=float(iw_olca_uncert_dict[cf]['IW_Sample_CF_Mean'])
            variance=float(iw_olca_uncert_dict[cf]['IW_Sample_CF_Variance'])
            mode_triang = 3 * mean - minimum - maximum

        #Try to fit a beta distribution with 4 params
        if alpha>0 and beta>0:
            uncert_dict={'amount': amount,
                              'loc': alpha, 
                              'shape': beta, 
                              'maximum': maximum,
                              'minimum': minimum,
                              'uncertainty type': id_4_params_beta_distrib,
                         'uncertainty_type': id_4_params_beta_distrib}
            iw_uncert_dict_bw[cf]=uncert_dict
            iw_uncert_beta_distrib[cf]=uncert_dict
            #if test_distrib(cf,uncert_dict)!= None:
            #    list_error_generalized_beta.append(test_distrib(cf,uncert_dict))
            continue

        #else try to fit with a triangular distrib
        elif mode_triang >= minimum:
            uncert_dict=uncert_dict_triang_moment_method(minimum,mean,maximum)
            iw_uncert_dict_bw[cf]=uncert_dict
            iw_uncert_triang_distrib[cf]=uncert_dict
            #if test_distrib(cf,uncert_dict)!= None:
            #    list_error_triang.append(test_distrib(cf,uncert_dict))
            continue

        #else fit with a normal distrib
        else:
            uncert_dict={'amount': amount,
                              'loc': mean, 
                              'scale': np.sqrt(np.abs(variance)), 
                              'maximum': maximum,
                              'minimum': minimum,
                              'uncertainty type': stats_arrays.NormalUncertainty.id}
            iw_uncert_dict_bw[cf]=uncert_dict
            iw_uncert_normal_distrib[cf]=uncert_dict
            #if test_distrib(cf,uncert_dict)!= None:
            #    list_error_normal.append(test_distrib(cf,uncert_dict))

    return iw_uncert_dict_bw;

# %%
iw_uncert_dict_bw=create_uncert_dict_bw(iw_olca_uncert_dict)
iw_uncert_dict_bw
# Out:
# {('Freshwater acidification',
#   '9990b51b-7023-4700-bca0-1a32ef921f74'): {'amount': 1.846715481, 'loc': 0.074258037, 'maximum': 1645.674497, 'minimum': 0.000424631, 'shape': 66.11494813, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Freshwater acidification',
#   '0f440cc0-0f74-446d-99d6-8ff0e97a2444'): {'amount': 1.846715481, 'loc': 0.074258037, 'maximum': 1645.674497, 'minimum': 0.000424631, 'shape': 66.11494813, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Freshwater acidification',
#   '2b50f643-216a-412b-a0e5-5946867aa2ed'): {'amount': 1.846715481, 'loc': 0.074258037, 'maximum': 1645.674497, 'minimum': 0.000424631, 'shape': 66.11494813, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Freshwater acidification',
#   '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'): {'amount': 1.846715481, 'loc': 0.074258037, 'maximum': 1645.674497, 'minimum': 0.000424631, 'shape': 66.11494813, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Freshwater acidification',
#   '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'): {'amount': 1.846715481, 'loc': 0.074258037, 'maximum': 1645.674497, 'minimum': 0.000424631, 'shape': 66.11494813, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Freshwater acidification',
#   
 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Marine eutrophication',
#   '2b50f643-216a-412b-a0e5-5946867aa2ed'): {'amount': 0.70894827, 'loc': 0.384752002, 'maximum': 6.519409187, 'minimum': 0.000215439, 'shape': 3.154343033, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Marine eutrophication',
#   '8494ed3c-0416-4aa5-b100-51a2b2bcadbd'): {'amount': 0.70894827, 'loc': 0.384752002, 'maximum': 6.519409187, 'minimum': 0.000215439, 'shape': 3.154343033, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Marine eutrophication',
#   '87883a4e-1e3e-4c9d-90c0-f1bea36f8014'): {'amount': 0.70894827, 'loc': 0.384752002, 'maximum': 6.519409187, 'minimum': 0.000215439, 'shape': 3.154343033, 'uncertainty type': 14, 'uncertainty_type': 14},
#  ('Marine eutrophication', 'a6fa3c5f-5323-487e-afba-12740ca8ea70'): 7.07,
#  ('Marine eutrophication', '4b81a3e2-b3fc-4e2f-81aa-5a68d11084c8'): 7.07,
#  ('Marine eutrophication', '90b08e70-9da2-4e91-a18c-73def7cf2b94'): 7.07,
#  ('Marine eutrophication', 'f3b31b38-bc7b-4054-99ea-0180796d5c5b'): 0.0,
#  ('Marine eutrophication', 'a858cb45-50f3-46c6-abd6-f801ba201f53'): 0.0,
#  ('Marine eutrophication', 'ebcf2be7-e222-412d-a59e-5b5f13334a35'): 7.07,
#  ('Marine eutrophication', '08a91e70-3ddc-11dd-954c-0050c2490048'): 10.1,
#  ('Marine eutrophication', '64b758fe-fbf2-4bdb-85f6-eab48e2ad2e4'): 7.07,
#  ('Marine eutrophication', '51b06290-9a7f-4750-86bc-d1db0dd503a7'): 7.07,
#  ('Marine eutrophication', '63e78926-8549-11e0-9d78-0800200c9a66'): 7.07,
# ...
#   'loc': 0.412114166,
#   'maximum': 216.064678,
#   'minimum': -10.21539016,
#   'shape': 1.466040838,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'fe5274f9-2436-43eb-8f30-3815c71cd46f'): {'amount': 39.43611433,
#   'loc': 0.412114166,
#   'maximum': 216.064678,
#   'minimum': -10.21539016,
#   'shape': 1.466040838,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '90c3df57-a55d-4fb0-a0e6-25afc15b384a'): {'amount': 39.43611433,
#   'loc': 0.412114166,
#   'maximum': 216.064678,
#   'minimum': -10.21539016,
#   'shape': 1.466040838,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'c288611e-07e0-4b5f-b667-51aeb99bec18'): {'amount': 39.43611433,
#   'loc': 0.412114166,
#   'maximum': 216.064678,
#   'minimum': -10.21539016,
#   'shape': 1.466040838,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '5aa2c010-fe60-4176-9731-1df76e317f75'): {'amount': 22.66000569,
#   'loc': 4.02e-16,
#   'maximum': 62.9329279,
#   'minimum': 17.86073994,
#   'shape': 3.37e-15,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '6e02ccfc-9eb5-4a51-be9a-870c1087c833'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'bc55a5b7-5a07-4ba7-87af-6f374d79ef06'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'a487b7db-318a-46ff-8e52-2837fab777ad'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'ecdb040b-aae3-495b-804c-e6b3d6f687ff'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '59df4945-6ee2-4ea6-9ef7-36c4f4b478f6'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'db6f90ef-27fc-41a8-a541-07efdce1fab5'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '93ac2969-a4e9-49b5-8b97-5cbc6b9b2601'): {'amount': 22.63665981,
#   'loc': 3.81e-16,
#   'maximum': 41.67505986,
#   'minimum': 8.310179922,
#   'shape': 5.07e-16,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   
): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '0ee752cd-5b6b-458d-b660-3e45a6798413'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '88e8456c-dc23-4bb4-aed5-a4186a2fbf77'): {'amount': 37.34469997,
#   'loc': 0.188369003,
#   'maximum': 91.41197914,
#   'minimum': 0.493290004,
#   'shape': 0.27636933,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'e3c1224d-1958-4fbb-b0e3-91943e5975c7'): {'amount': 37.34469997,
#   'loc': 0.188369003,
#   'maximum': 91.41197914,
#   'minimum': 0.493290004,
#   'shape': 0.27636933,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '512a5356-8059-4772-a43f-42e3c4f3d299'): {'amount': 159.166675,
#   'loc': 0.057658156,
#   'maximum': 315.786837,
#   'minimum': 32.06385025,
#   'shape': 0.071048222,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '2299398e-0846-4290-bcab-09bda2e61ee3'): {'amount': 159.166675,
#   'loc': 0.057658156,
#   'maximum': 315.786837,
#   'minimum': 32.06385025,
#   'shape': 0.071048222,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'fa4d4851-3cab-48a0-a2e4-d3e047323eb6'): {'amount': 159.166675,
#   'loc': 0.057658156,
#   'maximum': 315.786837,
#   'minimum': 32.06385025,
#   'shape': 0.071048222,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '606a2f32-d407-4346-ae57-eeef28d9d33f'): 0.0,
#  ('Land transformation, biodiversity',
#   '66f25f1d-1898-4827-bcbb-ca82f15c4d02'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '1ba33265-7100-47b7-b9ed-1f1a74fbb141'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '55beee8d-d04e-4307-bb0e-4e113dc07ee7'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '366ece56-e09c-4acd-b615-aaedd9bbe777'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '61f0fa44-2c1a-40ef-8332-d8efe9a6ab56'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '276c95b8-3eb7-42e9-9bb7-f8125e33f486'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '426e316e-db90-40ec-9f45-fa08e6db160c'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '090e9aa9-a9a9-4878-9634-3ad0ba7fbc91'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '7e2b64d5-3c75-4adf-88a6-d54b4bb46d3c'): {'amount': 168.8913863,
#   'loc': 1.88e-15,
#   'maximum': 183.7061033,
#   'minimum': 166.2035984,
#   'shape': 1.03e-14,
#   'uncertainty type': 14,
#   'uncertainty_type': 14},
#  ('Land transformation, biodiversity',
#   '9a0fe971-083d-4a5c-a12d-4f69882818e2'): 0.0,
#  ('Land transformation, biodiversity',
#   '56d0a956-0af8-4093-8504-a08b27dd2a68'): 0.0,
#  ('Global warming, long-term, ecosystem',
#   '467a7c34-1352-4793-b50f-e8c96e47058e'): 6.68,
#  ('Global warming, long-term, ecosystem',
#   '5200a790-7832-4cfe-a1b9-56be351db475'): 6.68,
#  ('Global warming, long-term, ecosystem',
#   '48b0b2ef-7c80-414e-9d0a-6d54de9cbcb3'): 6.68,
#  ...}

# %%
len(iw_uncert_dict_bw)
# Out:
# 2417

# %%
uncert_dicts_list=[iw_uncert_dict_bw[CF_name] for CF_name in iw_uncert_dict_bw.keys()]
set([dico['uncertainty type'] for dico in uncert_dicts_list if type(dico)==dict])
# Out:
# {14}

# %% [markdown]
# ## Create new impact methods

# %%
def impact_method_create(impact_method_name,impact_method_metadata,impact_method_CF_list):
    
    impact_method=bw.Method(impact_method_name)
    impact_method.register(**impact_method_metadata)
    impact_method.write(impact_method_CF_list)
    
    return impact_method;


def create_CF_dict(unit_to_ic_names,iw_olca_uncert_dict,iw_uncert_dict_bw):
    
    #unit_to_ic_names={'DALY':'Human Health','PDF.m2.yr':'Ecosystem Quality'}

    # Get all impact category names and metadata from olca dictionary 
    midpoint_name_list=[]
    endpoint_name_list=[]
    impact_cat_name_list=[]
    impact_cat_metadata_dict={}
    CF_list=[]

    for cf in iw_olca_uncert_dict:

        # Create all impact category names
        impact_methodology_name=iw_olca_uncert_dict[cf]['impact_method_name']
        midpoint_name=iw_olca_uncert_dict[cf]['impact_cat_name']
        endpoint_name=unit_to_ic_names[iw_olca_uncert_dict[cf]['CF_unit']]
        impact_cat_name=(impact_methodology_name,endpoint_name,midpoint_name)
        midpoint_name_list=list(set(midpoint_name_list)|set([midpoint_name]))
        endpoint_name_list=list(set(endpoint_name_list)|set([endpoint_name]))
        impact_cat_name_list=list(set(impact_cat_name_list)|set([impact_cat_name]))

        # Create metadata for all impact category names
        impact_cat_metadata={'description':'IMPACT World+ version as in openLCA, global default version, endpoint, 4 params beta distributions as uncertainty when possible',
                              'filename': 'All IC.csv',
                              'CF unit': iw_olca_uncert_dict[cf]['CF_unit'],
                              'Per elementary flow unit': iw_olca_uncert_dict[cf]['CF_per_unit_name']}   
        impact_cat_metadata_dict[impact_cat_name]=impact_cat_metadata

        # Create list of CF for all impact category names
        CF={('biosphere3', iw_olca_uncert_dict[cf]['ef_UUID']):(impact_cat_name,iw_uncert_dict_bw[cf])}
        CF_list.append(CF)

    CF_dict={}

    for ic in impact_cat_name_list:
        CF_dict[ic]=[]


    for cf in CF_list:
        for ef in cf:
            ef_to_add=(ef,cf[ef][1])
            CF_dict[cf[ef][0]].append(ef_to_add)


    return CF_dict,impact_cat_name_list,impact_cat_metadata_dict;


def create_impact_methods_from_dict(CF_dict,impact_cat_name_list,impact_cat_metadata_dict):
    for ic in impact_cat_name_list:
        impact_method_name=ic
        impact_method_metadata=impact_cat_metadata_dict[ic]
        impact_method_CF=CF_dict[ic]

        impact_method_create(impact_method_name,impact_method_metadata,impact_method_CF)
        
    return;

# %%
unit_to_ic_names={'DALY':'Human Health','PDF.m2.yr':'Ecosystem Quality'}
CF_dict,impact_cat_name_list,impact_cat_metadata_dict=create_CF_dict(unit_to_ic_names,iw_olca_uncert_dict,iw_uncert_dict_bw)
create_impact_methods_from_dict(CF_dict,impact_cat_name_list,impact_cat_metadata_dict)

# %%
ic_name_IW=[ic_name for ic_name in bw.methods if 'IMPACTWorld+' in str(ic_name)]
ic_name_IW
# Out:
# [('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Global warming, short-term, ecosystem'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Freshwater eutrophication'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Marine eutrophication'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Marine acidification, long-term'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Marine acidification, short-term'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Human Health',
#   'Water availability, human health'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Thermally polluted water'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Global warming, long-term, ecosystem'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Water availability, ter. ecosystem'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Water availability, fre. ecosystem'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Land transformation, biodiversity'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Ionizing radiation, fre. ecosystem'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Land occupation, biodiversity'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Terrestrial acidification'),
#  ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)',
#   'Ecosystem Quality',
#   'Freshwater acidification')]

# %% [markdown]
# ## Testing new impact methods

# %%
##Function for basic LCA calculation for multiple impact categories and multiple activities
#setup_name='all elementary flows with IW'
#list_fu_tuple = [(act,1)]
#list_methods_name = IW

def calc_MultiLCA(setup_name,list_fu_tuple,list_methods_name):
    
    list_functional_units_dict = [{act[0].key:act[1]} for act in list_fu_tuple]
    
    bw.calculation_setups[setup_name] = {'inv':list_functional_units_dict, 'ia':list_methods_name}
    myMultiLCA = bw.MultiLCA(setup_name)
    myMultiLCA.results.shape
    myMultiLCA.results
    
    act_names_list=[act[0]['name'] for act in list_fu_tuple]
    
    dataframe=pd.DataFrame(index=list_methods_name, columns=[act_names_list], data=myMultiLCA.results.T)
    
    all_results=myMultiLCA.results.T
   
    
    return dataframe,list_methods_name,all_results;


##Function for Monte with multiple impact categories, 1 activity
#list_methods_name = IW_with_uncert
#fu_tuple = (act,1)
#iterations = 10

def MC_multi_impact(fu_tuple,list_methods_name,iterations):
    
    MC_results_dict={}
    fu_dict={fu_tuple[0]:fu_tuple[1]}
    
    for ic in list_methods_name:
        print(ic)
        MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
        scores = [next(MC_results_per_IC) for _ in range(iterations)]
        MC_results_dict[ic]=scores
    
    return MC_results_dict;

##Function for Monte Carlo, one impact category, one activity
def MC_one_IC(imp_cat_name,act,fu,iterations):
    myFirstMonteCarlo = bw.MonteCarloLCA({act:fu},imp_cat_name)
    scores = [next(myFirstMonteCarlo) for _ in range(iterations)]
    return scores,

# %%
DB_eiv33=bw.Database('ecoinvent 3.3 cutoff without uncertainty')
act=DB_eiv33.random()

# %% [markdown]
# Test for basic calculation

# %%
setup_name='Test random act with IW'
list_fu_tuple = [(act,1)]
list_methods_name = ic_name_IW

dataframe,list_methods_name,all_results=calc_MultiLCA(setup_name,list_fu_tuple,list_methods_name)
dataframe
# Out:
#                                                     impact extrusion of aluminium, 2 strokes
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              2.626573e-01
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              2.488015e-04
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              4.059172e-03
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              1.904254e-01
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              2.067117e-02
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              9.875178e-04
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              3.887045e-06
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              7.952360e-01
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              1.174769e-04
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              1.548277e-05
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              2.935153e-02
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              1.577357e-15
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              3.109212e-02
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              8.315694e-02
# (IMPACTWorld+ (Default_Recommended_Endpoint 1_3...                              1.293343e-02

# %%
list_scores=[score[0] for score in all_results]
basic_calc_scores=dict(zip(list_methods_name,list_scores))
basic_calc_scores={ic_name[2]:basic_calc_scores[ic_name] for ic_name in basic_calc_scores.keys()}
basic_calc_scores
# Out:
# {'Freshwater acidification': 0.012933428772939404,
#  'Freshwater eutrophication': 0.00024880154919447542,
#  'Global warming, long-term, ecosystem': 0.79523601197319738,
#  'Global warming, short-term, ecosystem': 0.26265731712511486,
#  'Ionizing radiation, fre. ecosystem': 1.5773568635359316e-15,
#  'Land occupation, biodiversity': 0.031092119469258089,
#  'Land transformation, biodiversity': 0.029351527395162946,
#  'Marine acidification, long-term': 0.19042535712505257,
#  'Marine acidification, short-term': 0.02067117418796087,
#  'Marine eutrophication': 0.0040591723563885591,
#  'Terrestrial acidification': 0.083156938966197178,
#  'Thermally polluted water': 3.8870446983740925e-06,
#  'Water availability, fre. ecosystem': 1.5482767167945529e-05,
#  'Water availability, human health': 0.00098751777208230546,
#  'Water availability, ter. ecosystem': 0.00011747688235280342}

# %% [markdown]
# Test on Monte Carlo simulation

# %%
import numpy as np
from stats_arrays import *
from scipy import stats


class FourParamBetaUncertainty(UncertaintyBase):

    """
4 PARAM BETA DISTRIBUTIONS
The 4 parameters Beta distribution has the probability distribution function:

The :math:`\\alpha` parameter is ``loc``, and :math:`\\beta` is ``shape``. 
By default, the Beta distribution is defined from 0 to 1; the upper bound can be rescaled with the ``maximum`` parameter
and the lower bound with the ``minimum`` parameter.

Wikipedia: `Beta distribution <http://en.wikipedia.org/wiki/Beta_distribution>`_
    """
    id = 14
    description = "Four Parameters Beta uncertainty"

    @classmethod
    def validate(cls, params):
        scale_param=params['maximum']-params['minimum']
        if (params['loc'] > 0).sum() != params.shape[0]:
            raise InvalidParamsError("Real, positive alpha values are" +
                                     " required for Beta uncertainties.")
        if (params['shape'] > 0).sum() != params.shape[0]:
            raise InvalidParamsError("Real, positive beta values are" +
                                     " required for Beta uncertainties.")
        if (scale_param <= 0).sum():
            raise InvalidParamsError("Scale value must be positive or NaN")

    @classmethod
    def random_variables(cls, params, size, seeded_random=None,
                         transform=False):
        scale_param = params['maximum'] - params['minimum']
        if not seeded_random:
            seeded_random = np.random
        scale = scale_param
        scale[np.isnan(scale)] = 1
        return (params['minimum'].reshape((-1, 1)) + scale.reshape((-1, 1)) * 
                seeded_random.beta(params['loc'], params['shape'], size=(size,params.shape[0])).T)

    @classmethod
    def cdf(cls, params, vector):
        vector = cls.check_2d_inputs(params, vector)
        results = zeros(vector.shape)
        scale_param=params['maximum']-params['minimum']
        scale = scale_param
        scale[np.isnan(scale)] = 1
        for row in range(params.shape[0]):
            results[row, :] = stats.beta.cdf(vector[row, :],
                                             params['loc'][row], params['shape'][row],
                                             loc=params['minimum'][row],
                                             scale=scale[row])
        return results

    @classmethod
    def ppf(cls, params, percentages):
        percentages = cls.check_2d_inputs(params, percentages)
        results = zeros(percentages.shape)
        scale_param=params['maximum']-params['minimum']
        scale = scale_param
        scale[np.isnan(scale)] = 1
        for row in range(percentages.shape[0]):
            results[row, :] = stats.beta.ppf(percentages[row, :],
                                             params['loc'][row], params['shape'][row],
                                             loc=params['minimum'][row],
                                             scale=scale[row])
        return results

    @classmethod
    def statistics(cls, params):
        alpha = float(params['loc'])
        beta = float(params['shape'])
        mini = float(params['minimum'])
        maxi = float(params['maximum'])
        # scale = 1 if isnan(params['maximum'])[0] else float(params['maximum'])
        if alpha <= 1 or beta <= 1:
            mode = "Undefined"
        else:
            mode = mini + (maxi-mini) * (alpha - 1) / (alpha + beta - 2)
        return {
            'mean': mini + (maxi-mini) * alpha / (alpha + beta),
            'mode': mode,
            'median': "Not Implemented",
            'lower': mini,
            'upper': maxi
        }

    @classmethod
    def pdf(cls, params, xs=None):
        scale_param=params['maximum']-params['minimum']
        scale = 1 if np.isnan(scale_param)[0] else float(scale_param)
        if xs is None:
            xs = arange(0, scale, scale / cls.default_number_points_in_pdf)
        ys = stats.beta.pdf(xs, params['loc'], params['shape'],
                            loc=params['minimum'],
                            scale=scale)
        return xs, ys.reshape(ys.shape[1])
    
uncertainty_choices.add(FourParamBetaUncertainty)
print (FourParamBetaUncertainty in uncertainty_choices)
# Out:
# True

# %%
list_methods_name = ic_name_IW
fu_tuple = (act,1)
iterations = 100

scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
#scores
# Out:
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Global warming, short-term, ecosystem')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Freshwater eutrophication')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Marine eutrophication')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Marine acidification, long-term')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Marine acidification, short-term')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Human Health', 'Water availability, human health')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Thermally polluted water')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Global warming, long-term, ecosystem')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Water availability, ter. ecosystem')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Water availability, fre. ecosystem')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Land transformation, biodiversity')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Ionizing radiation, fre. ecosystem')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Land occupation, biodiversity')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Terrestrial acidification')
# ('IMPACTWorld+ (Default_Recommended_Endpoint 1_36)', 'Ecosystem Quality', 'Freshwater acidification')

# %%
scores_mean={ic_name[2]:np.mean(scores[ic_name]) for ic_name in scores.keys()}
pd.DataFrame(list(scores_mean.items()), columns=['Impact category', 'MC mean'])
# Out:
#                           Impact category       MC mean
# 0   Global warming, short-term, ecosystem  2.626573e-01
# 1               Freshwater eutrophication  8.417511e-08
# 2                   Marine eutrophication  4.196836e-03
# 3         Marine acidification, long-term  1.904254e-01
# 4        Marine acidification, short-term  2.067117e-02
# 5        Water availability, human health  1.094227e-03
# 6                Thermally polluted water  3.887045e-06
# 7    Global warming, long-term, ecosystem  7.952360e-01
# 8      Water availability, ter. ecosystem  1.174769e-04
# 9      Water availability, fre. ecosystem  1.548277e-05
# 10      Land transformation, biodiversity -1.330972e-02
# 11     Ionizing radiation, fre. ecosystem  1.577357e-15
# 12          Land occupation, biodiversity  2.872214e-02
# 13              Terrestrial acidification  8.275380e-02
# 14               Freshwater acidification  6.267333e-03

# %%
{ic_name:(basic_calc_scores[ic_name]-scores_mean[ic_name])/basic_calc_scores[ic_name] for ic_name in basic_calc_scores.keys()}
# Out:
# {'Freshwater acidification': 0.51541594353913323,
#  'Freshwater eutrophication': 0.99966167769275527,
#  'Global warming, long-term, ecosystem': -2.7921849813375291e-16,
#  'Global warming, short-term, ecosystem': -2.1134439291030869e-16,
#  'Ionizing radiation, fre. ecosystem': 0.0,
#  'Land occupation, biodiversity': 0.076224316335518696,
#  'Land transformation, biodiversity': 1.4534593126393736,
#  'Marine acidification, long-term': -1.457556705402516e-16,
#  'Marine acidification, short-term': -5.0351957567668215e-16,
#  'Marine eutrophication': -0.033914239374839651,
#  'Terrestrial acidification': 0.0048478717862274678,
#  'Thermally polluted water': 4.3582362076186302e-16,
#  'Water availability, fre. ecosystem': 0.0,
#  'Water availability, human health': -0.108058205659416,
#  'Water availability, ter. ecosystem': -2.3072670783632508e-16}
