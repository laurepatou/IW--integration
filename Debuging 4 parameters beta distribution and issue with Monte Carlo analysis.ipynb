# %%
import brightway2 as bw
import os               # to use "operating system dependent functionality"
import numpy as np      # "the fundamental package for scientific computing with Python"
import pandas as pd     # "high-performance, easy-to-use data structures and data analysis tools" for Python
import csv
import stats_arrays
import scipy as sp
import pandas as pd
import pickle

# %%
bw.projects.set_current('4 param distrib')

# %%
bw.bw2setup()
# Out:
# Creating default biosphere
#
# Applying strategy: normalize_units
# Writing activities to SQLite3 database:
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Applying strategy: drop_unspecified_subcategories
# Applied 2 strategies in 0.01 seconds
# Title: Writing activities to SQLite3 database:
#   Started: 08/17/2017 11:49:00
#   Finished: 08/17/2017 11:49:01
#   Total time elapsed: 00:00:00
#   CPU %: 70.200000
#   Memory %: 1.280258
# Created database: biosphere3
# Creating default LCIA methods
#
# Applying strategy: normalize_units
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applied 4 strategies in 1.26 seconds
# Wrote 718 LCIA methods with 178008 characterization factors
# Creating core data migrations

# %% [markdown]
# # Creating new distribution: 4 parameter beta distribution

# %%
from numpy import *
from stats_arrays import *


class FourParamBetaUncertainty(UncertaintyBase):

    """
4 PARAM BETA DISTRIBUTIONS
The 4 parameters Beta distribution has the probability distribution function:

The :math:`\\alpha` parameter is ``loc``, and :math:`\\beta` is ``shape``. 
By default, the Beta distribution is defined from 0 to 1; the upper bound can be rescaled with the ``maximum`` parameter
and the lower bound with the ``minimum`` parameter.

Wikipedia: `Beta distribution <http://en.wikipedia.org/wiki/Beta_distribution>`_
    """
    id = 14
    description = "Four Parameters Beta uncertainty"

    @classmethod
    def validate(cls, params):
        scale_param=params['maximum']-params['minimum']
        if (params['loc'] > 0).sum() != params.shape[0]:
            raise InvalidParamsError("Real, positive alpha values are" +
                                     " required for Beta uncertainties.")
        if (params['shape'] > 0).sum() != params.shape[0]:
            raise InvalidParamsError("Real, positive beta values are" +
                                     " required for Beta uncertainties.")
        if (scale_param <= 0).sum():
            raise InvalidParamsError("Scale value must be positive or NaN")

    @classmethod
    def random_variables(cls, params, size, seeded_random=None,
                         transform=False):
        scale_param=params['maximum']-params['minimum']
        if not seeded_random:
            seeded_random = random
        scale = scale_param
        scale[isnan(scale)] = 1
        return scale.reshape((-1, 1)) * seeded_random.beta(params['loc'],params['shape'],size=(size,params.shape[0])).T + params['minimum']

    @classmethod
    def cdf(cls, params, vector):
        vector = cls.check_2d_inputs(params, vector)
        results = zeros(vector.shape)
        scale_param=params['maximum']-params['minimum']
        scale = scale_param
        scale[isnan(scale)] = 1
        for row in range(params.shape[0]):
            results[row, :] = stats.beta.cdf(vector[row, :],
                                             params['loc'][row], params['shape'][row],
                                             loc=params['minimum'][row],
                                             scale=scale[row])
        return results

    @classmethod
    def ppf(cls, params, percentages):
        percentages = cls.check_2d_inputs(params, percentages)
        results = zeros(percentages.shape)
        scale_param=params['maximum']-params['minimum']
        scale = scale_param
        scale[isnan(scale)] = 1
        for row in range(percentages.shape[0]):
            results[row, :] = stats.beta.ppf(percentages[row, :],
                                             params['loc'][row], params['shape'][row],
                                             loc=params['minimum'][row],
                                             scale=scale[row])
        return results

    @classmethod
    def statistics(cls, params):
        alpha = float(params['loc'])
        beta = float(params['shape'])
        mini = float(params['minimum'])
        maxi = float(params['maximum'])
        # scale = 1 if isnan(params['maximum'])[0] else float(params['maximum'])
        if alpha <= 1 or beta <= 1:
            mode = "Undefined"
        else:
            mode = mini + (maxi-mini) * (alpha - 1) / (alpha + beta - 2)
        return {
            'mean': mini + (maxi-mini) * alpha / (alpha + beta),
            'mode': mode,
            'median': "Not Implemented",
            'lower': mini,
            'upper': maxi
        }

    @classmethod
    def pdf(cls, params, xs=None):
        scale_param=params['maximum']-params['minimum']
        scale = 1 if isnan(scale_param)[0] else float(scale_param)
        if xs is None:
            xs = arange(0, scale, scale / cls.default_number_points_in_pdf)
        ys = stats.beta.pdf(xs, params['loc'], params['shape'],
                            loc=params['minimum'],
                            scale=scale)
        return xs, ys.reshape(ys.shape[1])

# %%
uncertainty_choices.add(FourParamBetaUncertainty)
print (FourParamBetaUncertainty in uncertainty_choices)
# Out:
# True

# %% [markdown]
# # Importing impact method with uncertain CF using 4 param beta distribution

# %%
def pickle_load(file_path_root,file_name):
    
    complete_file_path=file_path_root+'\\'+file_name+'.p'
    
    return pickle.load( open( complete_file_path, "rb" ) );

# %%
file_path_root=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Pickle Python object saved'
file_name='ic_with_errors_ID14'

ic_with_errors_ID14=pickle_load(file_path_root,file_name)

# %%
ic_with_errors_ID14
# Out:
# {('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater eutrophication, GLO, with uncert ID14'): [(('biosphere3',
#     'fc0b5c85-3b49-42c2-a3fd-db7e57b696e3'),
#    {'amount': 0.079709586,
#     'loc': 0.000441333,
#     'maximum': 1063.722071,
#     'minimum': 1.22919e-07,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'c8a80a68-83a7-4453-97f4-082ee1b60c71'), 0.0),
#   (('biosphere3', 'f012d2d5-ebb4-4531-8285-0b98af3dcbd4'), 0.0),
#   (('biosphere3', '4ab486b5-7102-4a88-a7fd-3e7b42e0e2e2'),
#    {'amount': 11.08687883,
#     'loc': 0.000441333,
#     'maximum': 147954.0699,
#     'minimum': 1.70969e-05,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '503ccbc4-8697-46e7-9a9b-beee17d4cdec'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4574cd53-77cc-4540-827b-5736dda9c4d7'),
#    {'amount': 0.079709586,
#     'loc': 0.000441333,
#     'maximum': 1063.722071,
#     'minimum': 1.22919e-07,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b3cfad3f-b7da-490b-a491-8507a1bb7c4b'),
#    {'amount': 0.079709586,
#     'loc': 0.000441333,
#     'maximum': 1063.722071,
#     'minimum': 1.22919e-07,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b2631209-8374-431e-b7d5-56c96c6b6d79'),
#    {'amount': 11.08687883,
#     'loc': 0.000441333,
#     'maximum': 147954.0699,
#     'minimum': 1.70969e-05,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2d4b8ec1-8d53-4e62-8a11-ebc45909b02e'),
#    {'amount': 11.08687883,
#     'loc': 0.000441333,
#     'maximum': 147954.0699,
#     'minimum': 1.70969e-05,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '7ae398c8-8532-11e0-9d78-0800200c9a66'),
#    {'amount': 11.08687883,
#     'loc': 0.000441333,
#     'maximum': 147954.0699,
#     'minimum': 1.70969e-05,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '1727b41d-377e-43cd-bc01-9eaba946eccb'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2a89246a-8408-4775-a6db-7c33656f1469'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b1fca66f-8e83-469a-a7b5-018e14d5d545'), 0.0),
#   (('biosphere3', '76b09afe-52b9-4ecc-b97a-00b49ad8ed1a'), 0.0),
#   (('biosphere3', '4a5a08f6-51ab-41e7-809a-13d70b509740'),
#    {'amount': 3.514468127,
#     'loc': 0.000441333,
#     'maximum': 46900.47314,
#     'minimum': 5.41961e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '8d33cd5f-c365-44b8-bb70-a211d5bb15dd'),
#    {'amount': 0.079709586,
#     'loc': 0.000441333,
#     'maximum': 1063.722071,
#     'minimum': 1.22919e-07,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b2c8d9ab-da12-445f-bf52-eeca64a96fd6'),
#    {'amount': 0.079709586,
#     'loc': 0.000441333,
#     'maximum': 1063.722071,
#     'minimum': 1.22919e-07,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'ec76fb5c-b402-416b-825c-53e074fe7525'), 0.0),
#   (('biosphere3', 'ad62c648-1af8-4805-bbfb-64c6361eb9f6'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'a87680bc-ecde-471a-88bb-6bc7482a62cf'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'a8fea8cf-9b09-49fc-aa58-5a732494a2a0'), 0.0),
#   (('biosphere3', '490b267b-f429-4d9a-ac79-224e37fb4d58'), 0.0),
#   (('biosphere3', 'c8791f3c-3c4a-4278-91c0-483797d14da2'),
#    {'amount': 3.623163017,
#     'loc': 0.000441333,
#     'maximum': 48351.00323,
#     'minimum': 5.58723e-06,
#     'shape': 5.889147648,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '
-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'a4c4b2e8-7611-4690-b00f-80789d4eb9fe'),
#    {'amount': 0.159934864,
#     'loc': 0.585175339,
#     'maximum': 0.58,
#     'minimum': 0.01,
#     'shape': 1.639456974,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'de202ed0-bde5-42f5-9f74-c1d4018ec798'),
#    {'amount': 0.658108776,
#     'loc': 0.186602425,
#     'maximum': 0.76,
#     'minimum': 0.54,
#     'shape': 0.160979989,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'f6169139-e846-45d7-8195-2fdfc7a188c7'), 0.0),
#   (('biosphere3', '379ba5c9-5c3a-43d0-8e2d-605ad9c39e46'),
#    {'amount': 0.41535659,
#     'loc': 5.79674e-16,
#     'maximum': 0.5,
#     'minimum': 0.4,
#     'shape': 3.19508e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'dbeb09ff-e091-443e-b1f0-6176289dad0c'), 0.0),
#   (('biosphere3', '9a290e90-6d97-46af-8387-589f197aa868'), 0.0),
#   (('biosphere3', '0d6e367d-0c4c-4f6d-9bff-9b370a182ff1'),
#    {'amount': 0.658108776,
#     'loc': 0.186602425,
#     'maximum': 0.76,
#     'minimum': 0.54,
#     'shape': 0.160979989,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4ce71e21-8f14-48da-b9e5-4743e5f3c0ab'),
#    {'amount': 0.41535659,
#     'loc': 5.79674e-16,
#     'maximum': 0.5,
#     'minimum': 0.4,
#     'shape': 3.19508e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '64f2cbe7-791b-4d4b-bd13-f0c142922738'),
#    {'amount': 0.41535659,
#     'loc': 5.79674e-16,
#     'maximum': 0.5,
#     'minimum': 0.4,
#     'shape': 3.19508e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4f243941-fdd0-42e9-90d4-3a5b0a352c5b'),
#    {'amount': 0.658108776,
#     'loc': 0.186602425,
#     'maximum': 0.76,
#     'minimum': 0.54,
#     'shape': 0.160979989,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '012ee35c-c4e1-4759-9f62-e1a7a8504f8c'),
#    {'amount': 0.159934864,
#     'loc': 0.585175339,
#     'maximum': 0.58,
#     'minimum': 0.01,
#     'shape': 1.639456974,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '69dfa439-8e4e-4cae-bb0c-85a8aa8b9a73'),
#    {'amount': 0.41535659,
#     'loc': 5.79674e-16,
#     'maximum': 0.5,
#     'minimum': 0.4,
#     'shape': 3.19508e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b8300190-a242-11e0-8264-0800200c9a66'),
#    {'amount': 0.658108776,
#     'loc': 0.186602425,
#     'maximum': 0.76,
#     'minimum': 0.54,
#     'shape': 0.160979989,
#     'uncertainty type': 14,
#     'uncertainty_type': 14})],
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land transformation, biodiversity, GLO, with uncert ID14'): [(('biosphere3',
#     '99127c79-69f5-4046-a298-3f842c68d62b'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'e97b784a-ec09-4b1b-9f14-cc0ce9799c9e'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '00d15dd1-8517-49dd-933d-e7db77e9d342'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '99801a43-d476-4055-8d97-fb7c4ae173d4'),
#    {'amount': -37.34469997,
#     'loc': 0.27636933,
#     'maximum': -0.493290004,
#     'minimum': -91.41197914,
#     'shape': 0.188369003,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4e1715ba-f7fc-4732-a317-c25ca01f7b20'), 0.0),
#   (('biosphere3', 'a8e39acd-6e7f-4d43-973b-37e6b7c00037'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'bd6d11e8-eb49-4664-b065-7bcf9c888053'),
#    {'amount': -159.166675,
#     'loc': 0.071048222,
#     'maximum': -32.06385025,
#     'minimum': -315.786837,
#     'shape': 0.057658156,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'ec242c43-095c-4b42-8907-e0f13573f0a4'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '31e3aeb5-dae5-4a33-8038-a616442906c3'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '24dec894-971b-4315-9401-b35153387e0b'), 0.0),
#   (('biosphere3', 'a42347d2-09f1-405e-95dd-bf6ac03765d8'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '0e1c3d27-fb97-457a-a5d0-a324e7043402'),
#    {'amount': -37.34469997,
#     'loc': 0.27636933,
#     'maximum': -0.493290004,
#     'minimum': -91.41197914,
#     'shape': 0.188369003,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '00907a61-b501-4f47-b688-1dc2b51d48c1'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '97ad7d9b-eca1-4b54-8b31-9db2527f8518'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '64d99cb5-3b4f-4195-b86f-c5f45b4dcd19'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'c9025e62-8e16-4ff8-87b7-b212d79e2ff5'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'f1211810-39f3-49bd-826f-310dbe82950c'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '8d59bb59-b416-41c2-adab-bba044237346'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b3041d25-8a56-49f4-947a-32f04f488174'), 0.0),
#   (('biosphere3', '55d84221-b351-45c5-baa9-a08a9f62b04f'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4624deff-2016-41d4-b2bf-3db8dab88779'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
# ...
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4b420f19-0421-461e-a0b6-7efbf580089b'),
#    {'amount': -159.166675,
#     'loc': 0.071048222,
#     'maximum': -32.06385025,
#     'minimum': -315.786837,
#     'shape': 0.057658156,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'c8b1dd70-8a13-47c2-bbcf-b075a720de7f'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '178463a8-4cb3-4a8b-90d6-e360c6a68f38'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '17a5a406-333f-4b9e-8852-c2de50bc9585'),
#    {'amount': -23.08479162,
#     'loc': 1.28164767,
#     'maximum': 0.0,
#     'minimum': -62.46007511,
#     'shape': 0.751399527,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '66f25f1d-1898-4827-bcbb-ca82f15c4d02'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2cb441cd-8d2e-4e5c-a208-48c4fa005c41'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '43c8b65e-8551-37da-9f00-7fedc95fe17d'),
#    {'amount': -159.166675,
#     'loc': 0.071048222,
#     'maximum': -32.06385025,
#     'minimum': -315.786837,
#     'shape': 0.057658156,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '9f10b83a-5b75-48dd-a103-2d27a2c8a6cb'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'ab1be93d-4439-4a05-8588-d4fe2e177871'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'd264f35c-7f48-47d8-885b-057bdafa04a3'),
#    {'amount': 37.34469997,
#     'loc': 0.188369003,
#     'maximum': 91.41197914,
#     'minimum': 0.493290004,
#     'shape': 0.27636933,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '91a067cc-543a-4d73-a0c0-feb1f8935756'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'ca6db37c-1592-4468-8a0f-ec35ca8b5c76'), 0.0),
#   (('biosphere3', 'e5649dff-b5d1-4e51-9b70-dccd8675f445'), 0.0),
#   (('biosphere3', '45698560-88a6-41b7-bc82-2037b6b1e005'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2299398e-0846-4290-bcab-09bda2e61ee3'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'a05e1875-52e9-48f0-890f-d0f9bcdde127'),
#    {'amount': -39.43611433,
#     'loc': 1.466040838,
#     'maximum': 10.21539016,
#     'minimum': -216.064678,
#     'shape': 0.412114166,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '6e02ccfc-9eb5-4a51-be9a-870c1087c833'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '84b65d8f-2edd-4ddd-8f68-ca28d1c681b0'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '92138f4d-5e83-41fb-a202-6d59c36d5231'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '0775d4c9-2c91-4a0d-a4a7-1c6b96e47ea4'),
#    {'amount': 37.34469997,
#     'loc': 0.188369003,
#     'maximum': 91.41197914,
#     'minimum': 0.493290004,
#     'shape': 0.27636933,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'a55659bb-d9f2-4904-a2ad-489cd484cf70'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '345281db-4ed3-e458-5ead-00003fdd1e9a'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '5a022658-5189-4504-bb60-fc21e49c3004'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'fa815715-eeb2-4cfc-b006-0e5877bd5932'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'c288611e-07e0-4b5f-b667-51aeb99bec18'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b5d37ef1-0d36-4c00-8a38-54bbdc5e1eda'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '54d80309-72da-4786-abf7-06b68526d8c9'), 0.0),
#   (('biosphere3', '7de6ab99-8e96-4b7b-ae4b-861200c73843'),
#    {'amount': -39.43611433,
#     'loc': 1.466040838,
#     'maximum': 10.21539016,
#     'minimum': -216.064678,
#     'shape': 0.412114166,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '34f9fc3a-0406-4a90-b85f-7df531350944'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '3abec56e-98ea-44d2-b91d-7ae9bcd2141d'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2e002771-9f22-43e3-9990-f06f8235700b'),
#    {'amount': -22.66000569,
#     'loc': 3.37282e-15,
#     'maximum': -17.86073994,
#     'minimum': -62.9329279,
#     'shape': 4.01935e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '73cba245-5969-4076-8490-75a236073196'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '4d233a72-7c81-4e2c-bf71-74bde3abe3da'), 0.0),
#   (('biosphere3', '258ade11-47cc-48fd-b49f-767a2f123cd6'),
#    {'amount': 23.08479162,
#     'loc': 0.751399527,
#     'maximum': 62.46007511,
#     'minimum': 0.0,
#     'shape': 1.28164767,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '631d9552-1190-4edf-abc9-319139c90bd4'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '3f8e24d7-3d44-4a47-870f-9e3e74decca4'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '7a16b680-6d9a-4db3-a23e-0ec64aca5995'),
#    {'amount': 39.43611433,
#     'loc': 0.412114166,
#     'maximum': 216.064678,
#     'minimum': -10.21539016,
#     'shape': 1.466040838,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'ef4e5109-025b-4786-860e-9dcc2db701a0'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '67055318-bad9-420f-ae31-9ba54456518d'),
#    {'amount': -159.166675,
#     'loc': 0.071048222,
#     'maximum': -32.06385025,
#     'minimum': -315.786837,
#     'shape': 0.057658156,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '54b82481-32a3-4e82-bac7-1df475dbc80c'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '15dfd6d6-08f1-4053-a917-6ef6130d7b16'),
#    {'amount': -39.43611433,
#     'loc': 1.466040838,
#     'maximum': 10.21539016,
#     'minimum': -216.064678,
#     'shape': 0.412114166,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'f988c6c1-830d-4f77-a7e2-0c943c606d94'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '0cab58d3-f449-48d4-94bd-ec09d19736d6'),
#    {'amount': 37.34469997,
#     'loc': 0.188369003,
#     'maximum': 91.41197914,
#     'minimum': 0.493290004,
#     'shape': 0.27636933,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '1a568858-efa8-4c2a-b46e-82b6e66b6072'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '43c326df-fae0-4e31-a1f2-5a9dcf3f2244'),
#    {'amount': 37.34469997,
#     'loc': 0.188369003,
#     'maximum': 91.41197914,
#     'minimum': 0.493290004,
#     'shape': 0.27636933,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '1e033b47-5e2f-4fd4-acc3-df3e2e3e56a5'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'dbcfb8d9-9146-4c0d-8f89-cfd5a3951959'),
#    {'amount': -159.166675,
#     'loc': 0.071048222,
#     'maximum': -32.06385025,
#     'minimum': -315.786837,
#     'shape': 0.057658156,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '5c8177fc-addc-4756-baaa-4af492c0427b'),
#    {'amount': 23.08479162,
#     'loc': 0.751399527,
#     'maximum': 62.46007511,
#     'minimum': 0.0,
#     'shape': 1.28164767,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'd10b390c-9d0c-4f59-b31d-3d0d70e77a35'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'f71cd9e1-0ad0-4e10-85a6-73e7465bf749'), 0.0),
#   (('biosphere3', '8b03ce87-7aec-4106-8f9f-752c6174fda3'),
#    {'amount': -37.34469997,
#     'loc': 0.27636933,
#     'maximum': -0.493290004,
#     'minimum': -91.41197914,
#     'shape': 0.188369003,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '276c95b8-3eb7-42e9-9bb7-f8125e33f486'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '46b8b2fd-eb2a-413d-bc39-e7dc18a420ef'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '2f5a81ae-2a76-4807-8d8d-a4be0c11acfa'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'aa6a298f-893f-449d-8573-39f32fd43fe5'),
#    {'amount': -37.34469997,
#     'loc': 0.27636933,
#     'maximum': -0.493290004,
#     'minimum': -91.41197914,
#     'shape': 0.188369003,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b3467d07-32c2-4b74-b2d3-31525437fc1a'), 0.0),
#   (('biosphere3', 'd1707523-ac5e-4145-9676-386da2a30a7c'),
#    {'amount': 159.166675,
#     'loc': 0.057658156,
#     'maximum': 315.786837,
#     'minimum': 32.06385025,
#     'shape': 0.071048222,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'fbe76292-b1ff-4efe-8ac6-3a36c4f3c900'),
#    {'amount': -37.34469997,
#     'loc': 0.27636933,
#     'maximum': -0.493290004,
#     'minimum': -91.41197914,
#     'shape': 0.188369003,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'fa288b80-6ef1-4e80-b534-5c2e5c492fd8'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '07a366fe-1c9e-4651-ad1a-1da666316417'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '56d0a956-0af8-4093-8504-a08b27dd2a68'), 0.0),
#   (('biosphere3', 'd73b27a2-81bd-4264-baa5-ce4aca3545be'),
#    {'amount': 168.8913863,
#     'loc': 1.87542e-15,
#     'maximum': 183.7061033,
#     'minimum': 166.2035984,
#     'shape': 1.0337e-14,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '6edca93b-8430-49b7-876c-d9bf66dde443'), 0.0),
#   (('biosphere3', 'fe91efc5-25ce-4316-b0d1-43173a755777'),
#    {'amount': -22.63665981,
#     'loc': 5.06805e-16,
#     'maximum': -8.310179922,
#     'minimum': -41.67505986,
#     'shape': 3.81373e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', '5aa2c010-fe60-4176-9731-1df76e317f75'),
#    {'amount': 22.66000569,
#     'loc': 4.01935e-16,
#     'maximum': 62.9329279,
#     'minimum': 17.86073994,
#     'shape': 3.37282e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'c1513682-45ad-444e-afb5-27c660714e88'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'cdbfd224-21fe-457e-a47d-26a525965051'),
#    {'amount': 37.34469997,
#     'loc': 0.188369003,
#     'maximum': 91.41197914,
#     'minimum': 0.493290004,
#     'shape': 0.27636933,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'bc55a5b7-5a07-4ba7-87af-6f374d79ef06'),
#    {'amount': 22.63665981,
#     'loc': 3.81373e-16,
#     'maximum': 41.67505986,
#     'minimum': 8.310179922,
#     'shape': 5.06805e-16,
#     'uncertainty type': 14,
#     'uncertainty_type': 14}),
#   (('biosphere3', 'b93fac73-b3b1-4825-b1db-c129d404d3f3'),
#    {'amount': -168.8913863,
#     'loc': 1.0337e-14,
#     'maximum': -166.2035984,
#     'minimum': -183.7061033,
#     'shape': 1.87542e-15,
#     'uncertainty type': 14,
#     'uncertainty_type': 14})]}

# %%
def impact_method_create(impact_method_name,impact_method_metadata,impact_method_CF_list):
    
    impact_method=bw.Method(impact_method_name)
    impact_method.register(**impact_method_metadata)
    impact_method.write(impact_method_CF_list)
    
    return impact_method;

# %%
for ic_name in ic_with_errors_ID14:
    
    impact_method_name=ic_name
    impact_method_metadata={}
    impact_method_CF_list=ic_with_errors_ID14[ic_name]

    impact_method_create(impact_method_name,impact_method_metadata,impact_method_CF_list)

# %%
ic_names_to_test=[ic_name for ic_name in bw.methods if 'with uncert ID14' in str(ic_name)]
ic_names_to_test
# Out:
# [('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Freshwater eutrophication, GLO, with uncert ID14'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land transformation, biodiversity, GLO, with uncert ID14'),
#  ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017',
#   'Ecosystem Quality',
#   'Land occupation, biodiversity, GLO, with uncert ID14')]

# %% [markdown]
# # Creating database containing one activity with all elementary flows in BW2

# %% [markdown]
# Create a database with an activity with all elementary flows with quantity = 1

# %%
DB_test=bw.Database("For test")
DB_test.register()

all_ef_act=DB_test.new_activity("All elementary flows")
all_ef_act['name']="All elementary flows"
all_ef_act.save()

elem_flow_DB=bw.Database('biosphere3')

all_ef_act=DB_test.get("All elementary flows")

for ef in elem_flow_DB:
    new_exc=all_ef_act.new_exchange(amount=1.0,input= ef.key,type='biosphere')
    new_exc.save()
    
all_ef_act.save()

# %%
all_exchanges=[exc for exc in all_ef_act.exchanges()]
len(all_exchanges)
# Out:
# 4029

# %%
DB_test=bw.Database("For test_test for export")
DB_test.register()

all_ef_act=DB_test.new_activity("All elementary flows")
all_ef_act['name']="All elementary flows"
all_ef_act.save()

elem_flow_DB=bw.Database('biosphere3')

all_ef_act=DB_test.get("All elementary flows")

for ef in elem_flow_DB:
    new_exc=all_ef_act.new_exchange(amount=1.0,input= ef.key,type='biosphere')
    new_exc.save()
    
all_ef_act.save()

# %%
file_path_root=r'C:\bw2-python\Notebook - tutorial\IW+ integration\Pickle Python object saved'
object_name_to_save=[DB_test]
file_name='DB_test for export'

bw.BW2Package.export_objs(object_name_to_save,file_name,file_path_root)
# Out:
# 'C:\\bw2-python\\Notebook - tutorial\\IW+ integration\\Pickle Python object saved\\DB_test-for-export.8cf01e09eb138502b3d2248afc2de82c.bw2package'

# %% [markdown]
# # Monte Carlo calculation

# %%
#list_methods_name = IW_with_uncert
#fu_tuple = (act,1)
#iterations = 10

def MC_multi_impact(fu_tuple,list_methods_name,iterations):
    
    MC_results_dict={}
    fu_dict={fu_tuple[0]:fu_tuple[1]}
    
    for ic in list_methods_name:
        print(ic)
        MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
        scores = [next(MC_results_per_IC) for _ in range(iterations)]
        MC_results_dict[ic]=scores
    
    return MC_results_dict;

# %%
DB_test=bw.Database("For test")
act=DB_test.get("All elementary flows")

list_methods_name = ic_names_to_test
fu_tuple = (act,1)
iterations = 10

scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
scores
# Out:
# ('IMPACTWorld+ - Endpoint - only with spatial variability - Four param beta integration - update august 15th 2017', 'Ecosystem Quality', 'Freshwater eutrophication, GLO, with uncert ID14')
# ---------------------------------------------------------------------------
# MaximumIterationsError                    Traceback (most recent call last)
# <ipython-input-39-9414852477fb> in <module>()
#       6 iterations = 10
#       7
# ----> 8 scores=MC_multi_impact(fu_tuple,list_methods_name,iterations)
#       9 scores
#
# <ipython-input-31-eeb51539d7b1> in MC_multi_impact(fu_tuple, list_methods_name, iterations)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# <ipython-input-31-eeb51539d7b1> in <listcomp>(.0)
#      11         print(ic)
#      12         MC_results_per_IC = bw.MonteCarloLCA(fu_dict,ic)
# ---> 13         scores = [next(MC_results_per_IC) for _ in range(iterations)]
#      14         MC_results_dict[ic]=scores
#      15
#
# C:\bw2-python\envs\bw2\lib\site-packages\bw2calc\monte_carlo.py in __next__(self)
#      95         self.rebuild_biosphere_matrix(self.bio_rng.next())
#      96         if self.lcia:
# ---> 97             self.rebuild_characterization_matrix(self.cf_rng.next())
#      98         if self.weighting:
#      99             self.weighting_value = self.weighting_rng.next()
#
# C:\bw2-python\envs\bw2\lib\site-packages\stats_arrays\random.py in next(self)
#     181                 1,
#     182                 self.random,
# --> 183                 self.maximum_iterations
#     184             )
#     185             if len(random_data.shape) == 2:
#
# C:\bw2-python\envs\bw2\lib\site-packages\stats_arrays\distributions\base.py in bounded_random_variables(cls, params, size, seeded_random, maximum_iterations)
#     210             counter += 1
#     211             if counter >= maximum_iterations:
# --> 212                 raise MaximumIterationsError
#     213         return data
#     214
#
# MaximumIterationsError:
